# %%
import pandas as pd
import numpy as np

# %%
def list_of_chars(input:str)->list:
    '''Splits an AoC input into respective lines, and then splits 
    each line into a list of characters

    Args:
      input: str
        The AoC input as a string
    
    Returns:
      a list where each element is a line in the input
    '''
    input = input.splitlines()
    for idx, inp in enumerate(input):
        input[idx] = [char for char in inp]

    return input

# %%
# opening the file in read mode 
my_file = open("input.txt", "r") 
  
# reading the file 
data = my_file.read().split('\n')
data_list = [[char for char in row] for row in data]

# %%
test_str = """.|...\\....
|.-.\\.....
.....|-...
........|.
..........
.........\\
..../.\\\\..
.-.-/..|..
.|....-|.\\
..//.|...."""

# %%
test = list_of_chars(test_str)

# %%
test
# Out:
# [['.', '|', '.', '.', '.', '\\', '.', '.', '.', '.'],
#  ['|', '.', '-', '.', '\\', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '|', '-', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '|', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.'],
#  ['.', '.', '.', '.', '.', '.', '.', '.', '.', '\\'],
#  ['.', '.', '.', '.', '/', '.', '\\', '\\', '.', '.'],
#  ['.', '-', '.', '-', '/', '.', '.', '|', '.', '.'],
#  ['.', '|', '.', '.', '.', '.', '-', '|', '.', '\\'],
#  ['.', '.', '/', '/', '.', '|', '.', '.', '.', '.']]

# %%
input_data = data_list
start_row = 0
start_col = 0
direction = "Right"
energised_dict = {}

# %%
def advance_beam(row, col, direction, input_data, energised_dict):
    """
    move the beam forward based on the current direction and the character faced

        :param int row: what is the current row position
        :param int col: what is the current col position
        :param str direction: what is the current direction
        :param list of lists input_data: dataset of chars split into list of lists
        :param dict energised_dict: dictionary of all coordinates and direction it was crossed in - utilised once for each start coord

        :returns dict energised_dict: dictionary of all coordinates and direction it was crossed in - utilised once for each start coord
    """

    if (row >= 0) & (row <= len(input_data)-1) & (col >= 0) & (col <= len(input_data[0])-1):
        char = input_data[row][col]
        #print(row, col, char)
        if (row, col) in energised_dict:
            if energised_dict[(row, col)] == direction:
                print(f"Route repeated at {row}, {col} with direction of {direction}")
                stop = True
            else:
                stop = False
        else:
            stop = False
        if stop == False:
            energised_dict[(row, col)] = direction
            if direction == "Right":
                if char == "\\":
                    advance_beam(row+1, col, "Down", input_data, energised_dict)
                if (char == "-") | (char == "."):
                    advance_beam(row, col+1, "Right", input_data, energised_dict)
                if char == "/":
                    advance_beam(row-1, col, "Up", input_data, energised_dict)
                if char == "|":
                    advance_beam(row-1, col, "Up", input_data, energised_dict)
                    advance_beam(row+1, col, "Down", input_data, energised_dict)
            elif direction == "Left":
                if char == "\\":
                    advance_beam(row-1, col, "Up", input_data, energised_dict)
                if (char == "-") | (char == "."):
                    advance_beam(row, col-1, "Left", input_data, energised_dict)
                if char == "/":
                    advance_beam(row+1, col, "Down", input_data, energised_dict)
                if char == "|":
                    advance_beam(row-1, col, "Up", input_data, energised_dict)
                    advance_beam(row+1, col, "Down", input_data, energised_dict)
            elif direction == "Up":
                if char == "\\":
                    advance_beam(row, col-1, "Left", input_data, energised_dict)
                if char == "-":
                    advance_beam(row, col-1, "Left", input_data, energised_dict)
                    advance_beam(row, col+1, "Right", input_data, energised_dict)
                if char == "/":
                    advance_beam(row, col+1, "Right", input_data, energised_dict)
                if (char == "|") | (char == "."):
                    advance_beam(row-1, col, "Up", input_data, energised_dict)
            elif direction == "Down":
                if char == "\\":
                    advance_beam(row, col+1, "Right", input_data, energised_dict)
                if char == "-":
                    advance_beam(row, col-1, "Left", input_data, energised_dict)
                    advance_beam(row, col+1, "Right", input_data, energised_dict)
                if char == "/":
                    advance_beam(row, col-1, "Left", input_data, energised_dict)
                if (char == "|") | (char == "."):
                    advance_beam(row+1, col, "Down", input_data, energised_dict)
    else:
        print(f"Beam left grid at {row}, {col}")
    
    return energised_dict

# %%
def get_num_energised(row, col, direction):
    """
    input a start point and direction and count the num energised tiles for that config

        :param int row: what is the current row position
        :param int col: what is the current col position
        :param str direction: what is the current direction

        :return str config: Concatenated string of row start,col start and direction start
        :return int num_energised: Sum of energised nodes for this config
    """
    print(f"Running for {row},{col} start in {direction} direction")
    energised_dict = {}
    #print(energised_dict)
    temp_data = data_list.copy()
    energised_dict = advance_beam(row, col, direction, temp_data, energised_dict)
    #print(energised_dict)
    num_energised = len(set(energised_dict.keys()))
    config = f"{row}_{col}_{direction}"

    return config, num_energised

# %%
# Set config min and max values
min_row = 0
min_col = 0
max_row = len(data_list)
max_col = len(data_list[0])

# %%
"""loop over all cols and check energised list for min and max row,
then loop over all rows and check energised list for min and max cols.
Append all results and the config to a summary dict"""
summary_dict = {}
for i in range(min_row, max_row):
    config, num_energised = get_num_energised(i, min_col, "Right")
    summary_dict[config] = num_energised
    config, num_energised = get_num_energised(i, max_col, "Left")
    summary_dict[config] = num_energised
for i in range(min_col, max_col):
    config, num_energised = get_num_energised(min_row, i, "Down")
    summary_dict[config] = num_energised
    config, num_energised = get_num_energised(max_row, i, "Up")
    summary_dict[config] = num_energised
# Out:
# Running for 0,0 start in Right direction
# Beam left grid at -1, 13
# Beam left grid at 20, -1
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 48, 71 with direction of Left
# Route repeated at 20, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Route repeated at 39, 38 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 42, 74 with direction of Up
# Route repeated at 31, 64 with direction of Up
# Route repeated at 48, 71 with direction of Left
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 97, 42 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 39, 40 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Route repeated at 47, 40 with direction of Up
# Route repeated at 49, 40 with direction of Down
# Route repeated at 26, 14 with direction of Left
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Beam left grid at 73, -1
# Route repeated at 91, 49 with direction of Left
# Route repeated at 55, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Beam left grid at -1, 94
# Route repeated at 50, 79 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 16, 48 with direction of Left
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 53, 79 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Route repeated at 72, 57 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 73, 58 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 45, 66 with direction of Left
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 108 with direction of Right
# Route repeated at 40, 80 with direction of Right
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 73, 58 with direction of Left
# Route repeated at 77, 88 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 66 with direction of Left
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 92 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 44, 56 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 44, 74 with direction of Down
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 60 with direction of Right
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Route repeated at 100, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 65, 68 with direction of Right
# Route repeated at 70, 72 with direction of Down
# Route repeated at 45, 95 with direction of Right
# Route repeated at 19, 52 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Route repeated at 72, 50 with direction of Down
# Route repeated at 51, 41 with direction of Down
# Route repeated at 15, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 31, 37 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 53, 44 with direction of Down
# Route repeated at 72, 42 with direction of Down
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Route repeated at 48, 49 with direction of Left
# Running for 0,110 start in Left direction
# Beam left grid at 0, 110
# Running for 1,0 start in Right direction
# Beam left grid at 0, -1
# Beam left grid at -1, 13
# Beam left grid at 20, -1
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 48, 71 with direction of Left
# Route repeated at 20, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Route repeated at 39, 38 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 42, 74 with direction of Up
# Route repeated at 31, 64 with direction of Up
# Route repeated at 48, 71 with direction of Left
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 97, 42 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 39, 40 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Route repeated at 47, 40 with direction of Up
# Route repeated at 49, 40 with direction of Down
# Route repeated at 26, 14 with direction of Left
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Beam left grid at 73, -1
# Route repeated at 91, 49 with direction of Left
# Route repeated at 55, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Beam left grid at -1, 94
# Route repeated at 50, 79 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 16, 48 with direction of Left
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 53, 79 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Route repeated at 72, 57 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 73, 58 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 45, 66 with direction of Left
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 108 with direction of Right
# Route repeated at 40, 80 with direction of Right
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 73, 58 with direction of Left
# Route repeated at 77, 88 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 66 with direction of Left
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 92 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 44, 56 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 44, 74 with direction of Down
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 60 with direction of Right
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Route repeated at 100, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 65, 68 with direction of Right
# Route repeated at 70, 72 with direction of Down
# Route repeated at 45, 95 with direction of Right
# Route repeated at 19, 52 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Route repeated at 72, 50 with direction of Down
# Route repeated at 51, 41 with direction of Down
# Route repeated at 15, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 31, 37 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 53, 44 with direction of Down
# Route repeated at 72, 42 with direction of Down
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Route repeated at 48, 49 with direction of Left
# Running for 1,110 start in Left direction
# Beam left grid at 1, 110
# Running for 2,0 start in Right direction
# Beam left grid at -1, 16
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 48, 71 with direction of Left
# Route repeated at 20, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 42, 74 with direction of Up
# Route repeated at 31, 64 with direction of Up
# Route repeated at 48, 71 with direction of Left
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 32, 33 with direction of Left
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 39, 38 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Route repeated at 47, 40 with direction of Up
# Route repeated at 49, 40 with direction of Down
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Route repeated at 97, 42 with direction of Up
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 15, 53 with direction of Up
# Route repeated at 57, 53 with direction of Down
# Route repeated at 31, 47 with direction of Left
# Route repeated at 44, 55 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 50, 79 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at 73, -1
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 40, 41 with direction of Up
# Route repeated at 51, 41 with direction of Down
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Route repeated at 72, 42 with direction of Down
# Route repeated at 91, 49 with direction of Left
# Route repeated at 15, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Beam left grid at -1, 94
# Route repeated at 44, 74 with direction of Down
# Route repeated at 8, 83 with direction of Right
# Route repeated at 16, 48 with direction of Left
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 53, 79 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Route repeated at 72, 57 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 53, 44 with direction of Down
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 73, 58 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 45, 66 with direction of Left
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 108 with direction of Right
# Route repeated at 40, 80 with direction of Right
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 73, 58 with direction of Left
# Route repeated at 77, 88 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 66 with direction of Left
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 92 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 60 with direction of Right
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Route repeated at 100, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 65, 68 with direction of Right
# Route repeated at 70, 72 with direction of Down
# Route repeated at 45, 95 with direction of Right
# Route repeated at 19, 52 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Route repeated at 72, 50 with direction of Down
# Route repeated at 32, 39 with direction of Right
# Running for 2,110 start in Left direction
# Beam left grid at 2, 110
# Running for 3,0 start in Right direction
# Beam left grid at 0, -1
# Beam left grid at -1, 13
# Beam left grid at 20, -1
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 48, 71 with direction of Left
# Route repeated at 20, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Route repeated at 39, 38 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 42, 74 with direction of Up
# Route repeated at 31, 64 with direction of Up
# Route repeated at 48, 71 with direction of Left
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 97, 42 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 39, 40 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Route repeated at 47, 40 with direction of Up
# Route repeated at 49, 40 with direction of Down
# Route repeated at 26, 14 with direction of Left
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Beam left grid at 73, -1
# Route repeated at 91, 49 with direction of Left
# Route repeated at 55, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Beam left grid at -1, 94
# Route repeated at 50, 79 with direction of Right
# Route repeated at 8, 83 with direction of Right
# Route repeated at 16, 48 with direction of Left
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 53, 79 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Route repeated at 72, 57 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 73, 58 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 45, 66 with direction of Left
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 108 with direction of Right
# Route repeated at 40, 80 with direction of Right
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 73, 58 with direction of Left
# Route repeated at 77, 88 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 66 with direction of Left
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 92 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 44, 56 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 44, 74 with direction of Down
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 60 with direction of Right
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Route repeated at 100, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 65, 68 with direction of Right
# Route repeated at 70, 72 with direction of Down
# Route repeated at 45, 95 with direction of Right
# Route repeated at 19, 52 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Route repeated at 72, 50 with direction of Down
# Route repeated at 51, 41 with direction of Down
# Route repeated at 15, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 31, 37 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 53, 44 with direction of Down
# Route repeated at 72, 42 with direction of Down
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Route repeated at 48, 49 with direction of Left
# Running for 3,110 start in Left direction
# Beam left grid at 3, 110
# Running for 4,0 start in Right direction
# Beam left grid at -1, 70
# Beam left grid at -1, 56
# Beam left grid at -1, 69
# Beam left grid at -1, 75
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 106 with direction of Right
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Route repeated at 47, 40 with direction of Up
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 41, 74 with direction of Up
# Route repeated at 20, 64 with direction of Up
# Route repeated at 33, 64 with direction of Down
# Route repeated at 9, 82 with direction of Up
# Route repeated at 16, 48 with direction of Left
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 19, 52 with direction of Down
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 79
# Route repeated at 39, 40 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 41, 57 with direction of Up
# Route repeated at 43, 57 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 15, 53 with direction of Up
# Route repeated at 57, 53 with direction of Down
# Route repeated at 31, 45 with direction of Left
# Route repeated at 44, 55 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 50, 80 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 15, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Beam left grid at -1, 94
# Beam left grid at 59, -1
# Beam left grid at 52, -1
# Route repeated at 63, 17 with direction of Up
# Beam left grid at 110, 20
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 60 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 63, 17 with direction of Up
# Route repeated at 78, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 50, 44 with direction of Up
# Route repeated at 53, 44 with direction of Down
# Beam left grid at 73, -1
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Route repeated at 73, 94 with direction of Up
# Route repeated at 73, 58 with direction of Left
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Route repeated at 58, 15 with direction of Up
# Route repeated at 64, 15 with direction of Down
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Route repeated at 97, 42 with direction of Up
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Route repeated at 72, 50 with direction of Down
# Route repeated at 49, 40 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 40, 41 with direction of Up
# Route repeated at 51, 41 with direction of Down
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Route repeated at 72, 42 with direction of Down
# Route repeated at 91, 49 with direction of Left
# Route repeated at 72, 57 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Route repeated at 70, 72 with direction of Down
# Route repeated at 48, 71 with direction of Left
# Route repeated at 30, 64 with direction of Up
# Route repeated at 49, 103 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 54, 79 with direction of Up
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 77, 86 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Route repeated at 99, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 63 with direction of Left
# Route repeated at 65, 68 with direction of Right
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 91 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 66 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Route repeated at 40, 80 with direction of Right
# Route repeated at 44, 74 with direction of Down
# Route repeated at 8, 83 with direction of Right
# Route repeated at 11, 82 with direction of Down
# Running for 4,110 start in Left direction
# Beam left grid at 4, 110
# Running for 5,0 start in Right direction
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 48, 71 with direction of Left
# Route repeated at 20, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Route repeated at 39, 38 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 42, 74 with direction of Up
# Route repeated at 31, 64 with direction of Up
# Route repeated at 48, 71 with direction of Left
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 73, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Route repeated at 97, 42 with direction of Up
# Route repeated at 68, 62 with direction of Up
# ...
# Route repeated at 9, 73 with direction of Up
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 19, 52 with direction of Down
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Route repeated at 12, 101 with direction of Left
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 55, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Beam left grid at -1, 94
# Route repeated at 83, 79 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Route repeated at 73, 94 with direction of Up
# Route repeated at 73, 58 with direction of Left
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Route repeated at 69, 50 with direction of Up
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 15, 53 with direction of Up
# Route repeated at 74, 57 with direction of Down
# Route repeated at 31, 45 with direction of Left
# Route repeated at 44, 55 with direction of Left
# Route repeated at 43, 74 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 53, 44 with direction of Down
# Beam left grid at 73, -1
# Route repeated at 92, 79 with direction of Down
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Route repeated at 40, 80 with direction of Right
# Route repeated at 50, 80 with direction of Right
# Route repeated at 58, 15 with direction of Up
# Route repeated at 64, 15 with direction of Down
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Route repeated at 97, 42 with direction of Up
# Route repeated at 81, 40 with direction of Up
# Beam left grid at 23, -1
# Route repeated at 72, 50 with direction of Down
# Route repeated at 49, 40 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 40, 41 with direction of Up
# Route repeated at 51, 41 with direction of Down
# Route repeated at 61, 61 with direction of Left
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Route repeated at 72, 42 with direction of Down
# Route repeated at 91, 49 with direction of Left
# Route repeated at 15, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Route repeated at 15, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 66 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 60 with direction of Right
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Route repeated at 15, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at 24, 110
# Route repeated at 70, 72 with direction of Down
# Route repeated at 48, 71 with direction of Left
# Route repeated at 30, 64 with direction of Up
# Route repeated at 49, 103 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 54, 79 with direction of Up
# Route repeated at 73, 81 with direction of Right
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 77, 86 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Route repeated at 99, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 46, 109 with direction of Up
# Route repeated at 102, 106 with direction of Down
# Beam left grid at 85, 110
# Route repeated at 65, 63 with direction of Left
# Route repeated at 65, 68 with direction of Right
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 91 with direction of Right
# Route repeated at 37, 100 with direction of Right
# Beam left grid at 9, 110
# Route repeated at 12, 103 with direction of Right
# Running for 110,102 start in Up direction
# Beam left grid at 110, 102
# Running for 0,103 start in Down direction
# Beam left grid at 4, 110
# Running for 110,103 start in Up direction
# Beam left grid at 110, 103
# Running for 0,104 start in Down direction
# Beam left grid at 0, 110
# Beam left grid at 5, 110
# Beam left grid at 7, 110
# Running for 110,104 start in Up direction
# Beam left grid at 110, 104
# Running for 0,105 start in Down direction
# Beam left grid at -1, 89
# Beam left grid at -1, 82
# Running for 110,105 start in Up direction
# Beam left grid at 110, 105
# Running for 0,106 start in Down direction
# Beam left grid at 0, 110
# Beam left grid at 5, 110
# Running for 110,106 start in Up direction
# Beam left grid at 110, 106
# Running for 0,107 start in Down direction
# Beam left grid at 13, 110
# Running for 110,107 start in Up direction
# Beam left grid at 110, 107
# Running for 0,108 start in Down direction
# Beam left grid at 44, -1
# Beam left grid at -1, 63
# Beam left grid at -1, 21
# Beam left grid at -1, 64
# Beam left grid at -1, 87
# Beam left grid at -1, 66
# Beam left grid at 64, 110
# Route repeated at 62, 38 with direction of Left
# Beam left grid at -1, 53
# Beam left grid at -1, 11
# Beam left grid at 15, -1
# Beam left grid at 26, -1
# Beam left grid at -1, 72
# Route repeated at 67, 72 with direction of Up
# Route repeated at 77, 79 with direction of Up
# Beam left grid at 97, 110
# Route repeated at 79, 82 with direction of Right
# Route repeated at 47, 101 with direction of Left
# Route repeated at 47, 106 with direction of Right
# Route repeated at 7, 21 with direction of Up
# Route repeated at 21, 63 with direction of Right
# Route repeated at 47, 40 with direction of Up
# Beam left grid at 54, -1
# Beam left grid at 37, -1
# Beam left grid at 48, -1
# Beam left grid at 88, -1
# Beam left grid at 110, 23
# Beam left grid at 110, 22
# Route repeated at 67, 27 with direction of Left
# Route repeated at 67, 34 with direction of Right
# Route repeated at 67, 29 with direction of Right
# Route repeated at 87, 22 with direction of Down
# Route repeated at 41, 74 with direction of Up
# Route repeated at 20, 64 with direction of Up
# Route repeated at 33, 64 with direction of Down
# Route repeated at 10, 84 with direction of Left
# Beam left grid at -1, 108
# Beam left grid at -1, 98
# Beam left grid at 16, 110
# Beam left grid at 66, 110
# Beam left grid at 41, 110
# Beam left grid at 52, -1
# Beam left grid at 59, -1
# Route repeated at 58, 15 with direction of Up
# Route repeated at 77, 14 with direction of Left
# Route repeated at 62, 59 with direction of Right
# Beam left grid at 65, -1
# Beam left grid at 60, -1
# Beam left grid at 101, -1
# Route repeated at 87, 27 with direction of Up
# Route repeated at 105, 23 with direction of Down
# Route repeated at 45, 25 with direction of Up
# Route repeated at 76, 25 with direction of Down
# Beam left grid at 110, 9
# Beam left grid at 110, 20
# Route repeated at 64, 15 with direction of Down
# Beam left grid at -1, 4
# Beam left grid at 103, -1
# Beam left grid at 110, 2
# Route repeated at 39, 40 with direction of Left
# Route repeated at 39, 42 with direction of Right
# Route repeated at 41, 57 with direction of Up
# Route repeated at 43, 57 with direction of Down
# Route repeated at 69, 50 with direction of Up
# Beam left grid at 110, 45
# Route repeated at 88, 38 with direction of Up
# Route repeated at 15, 53 with direction of Up
# Route repeated at 57, 53 with direction of Down
# Route repeated at 31, 47 with direction of Left
# Route repeated at 44, 55 with direction of Left
# Route repeated at 42, 74 with direction of Up
# Route repeated at 50, 79 with direction of Right
# Route repeated at 32, 84 with direction of Left
# Route repeated at 32, 86 with direction of Right
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 45 with direction of Right
# Beam left grid at 73, -1
# Route repeated at 77, 39 with direction of Left
# Route repeated at 77, 41 with direction of Right
# Beam left grid at 23, -1
# Route repeated at 72, 50 with direction of Down
# Route repeated at 49, 40 with direction of Down
# Beam left grid at 35, -1
# Route repeated at 77, 16 with direction of Right
# Route repeated at 34, 30 with direction of Right
# Route repeated at 35, 20 with direction of Left
# Route repeated at 35, 41 with direction of Right
# Beam left grid at 23, 110
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 17 with direction of Up
# Route repeated at 74, 17 with direction of Down
# Beam left grid at 39, -1
# Route repeated at 71, 17 with direction of Up
# Route repeated at 77, 17 with direction of Down
# Route repeated at 81, 40 with direction of Up
# Route repeated at 97, 42 with direction of Up
# Route repeated at 68, 62 with direction of Up
# Route repeated at 92, 79 with direction of Down
# Route repeated at 103, 74 with direction of Left
# Beam left grid at 110, 90
# Beam left grid at 110, 52
# Route repeated at 93, 80 with direction of Right
# Beam left grid at -1, 33
# Beam left grid at -1, 20
# Beam left grid at 55, -1
# Route repeated at 16, 48 with direction of Left
# Route repeated at 16, 50 with direction of Right
# Beam left grid at -1, 93
# Route repeated at 40, 41 with direction of Up
# Route repeated at 51, 41 with direction of Down
# Route repeated at 50, 57 with direction of Up
# Route repeated at 63, 68 with direction of Down
# Route repeated at 13, 20 with direction of Up
# Route repeated at 50, 17 with direction of Down
# Beam left grid at 92, -1
# Beam left grid at 110, 33
# Route repeated at 70, 42 with direction of Up
# Route repeated at 72, 42 with direction of Down
# Route repeated at 91, 49 with direction of Left
# Route repeated at 15, 53 with direction of Up
# Route repeated at 88, 62 with direction of Down
# Route repeated at 63, 68 with direction of Down
# Route repeated at 89, 38 with direction of Up
# Route repeated at 94, 38 with direction of Down
# Route repeated at 91, 57 with direction of Left
# Route repeated at 91, 59 with direction of Right
# Beam left grid at 51, 110
# Beam left grid at 110, 91
# Beam left grid at -1, 45
# Route repeated at 9, 43 with direction of Up
# Route repeated at 16, 50 with direction of Right
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 86 with direction of Right
# Beam left grid at -1, 79
# Route repeated at 50, 44 with direction of Up
# Route repeated at 53, 44 with direction of Down
# Beam left grid at -1, 91
# Beam left grid at -1, 58
# Route repeated at 37, 98 with direction of Left
# Beam left grid at 37, 110
# Beam left grid at 9, 110
# Beam left grid at 12, 110
# Beam left grid at 15, 110
# Beam left grid at 36, 110
# Beam left grid at 29, 110
# Route repeated at 16, 75 with direction of Up
# Route repeated at 18, 75 with direction of Down
# Route repeated at 72, 57 with direction of Up
# Route repeated at 87, 62 with direction of Right
# Route repeated at 37, 98 with direction of Left
# Route repeated at 37, 100 with direction of Right
# Route repeated at 45, 66 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Beam left grid at 24, 110
# Route repeated at 70, 72 with direction of Down
# Route repeated at 48, 71 with direction of Left
# Route repeated at 30, 64 with direction of Up
# Route repeated at 49, 106 with direction of Left
# Beam left grid at 49, 110
# Beam left grid at 110, 73
# Route repeated at 10, 73 with direction of Up
# Route repeated at 40, 65 with direction of Left
# Route repeated at 40, 67 with direction of Right
# Beam left grid at -1, 94
# Route repeated at 68, 62 with direction of Up
# Route repeated at 85, 79 with direction of Down
# Route repeated at 73, 94 with direction of Up
# Route repeated at 73, 58 with direction of Left
# Beam left grid at 100, 110
# Beam left grid at 110, 98
# Route repeated at 77, 86 with direction of Left
# Route repeated at 73, 94 with direction of Up
# Route repeated at 54, 43 with direction of Left
# Route repeated at 54, 81 with direction of Right
# Beam left grid at 27, 110
# Beam left grid at 62, 110
# Route repeated at 87, 80 with direction of Up
# Route repeated at 100, 99 with direction of Right
# Route repeated at 99, 91 with direction of Up
# Route repeated at 105, 91 with direction of Down
# Route repeated at 46, 109 with direction of Up
# Beam left grid at 110, 106
# Beam left grid at 85, 110
# Route repeated at 65, 63 with direction of Left
# Route repeated at 65, 68 with direction of Right
# Beam left grid at 99, 110
# Route repeated at 49, 108 with direction of Right
# Route repeated at 41, 89 with direction of Left
# Route repeated at 41, 92 with direction of Right
# Beam left grid at 37, 110
# Route repeated at 102, 106 with direction of Down
# Route repeated at 36, 58 with direction of Up
# Route repeated at 38, 58 with direction of Down
# Route repeated at 12, 73 with direction of Down
# Route repeated at 10, 98 with direction of Up
# Route repeated at 15, 85 with direction of Up
# Route repeated at 10, 84 with direction of Left
# Route repeated at 10, 87 with direction of Right
# Route repeated at 43, 57 with direction of Down
# Beam left grid at 42, 110
# Route repeated at 45, 67 with direction of Left
# Route repeated at 45, 95 with direction of Right
# Route repeated at 45, 95 with direction of Right
# Route repeated at 64, 66 with direction of Down
# Route repeated at 31, 36 with direction of Left
# Route repeated at 31, 52 with direction of Right
# Route repeated at 31, 49 with direction of Right
# Route repeated at 62, 40 with direction of Right
# Beam left grid at 57, 110
# Route repeated at 40, 78 with direction of Left
# Route repeated at 40, 80 with direction of Right
# Route repeated at 44, 74 with direction of Down
# Route repeated at 8, 83 with direction of Right
# Route repeated at 9, 43 with direction of Up
# Route repeated at 19, 52 with direction of Down
# Beam left grid at 11, 110
# Route repeated at 53, 79 with direction of Up
# Route repeated at 73, 81 with direction of Right
# Running for 110,108 start in Up direction
# Beam left grid at 110, 108
# Running for 0,109 start in Down direction
# Beam left grid at 3, 110
# Running for 110,109 start in Up direction
# Beam left grid at 110, 109

# %%
# Find the max value from the summary list
max(summary_dict.values())
# Out:
# 8089

# %%
# Find the config based on the max value in the summary list
print(list(summary_dict.keys())[list(summary_dict.values()).index(max(summary_dict.values()))])
# Out:
# 0_83_Down
