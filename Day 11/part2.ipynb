# %%
import pandas as pd
import numpy as np

# %%
# opening the file in read mode 
my_file = open("input.txt", "r") 
  
# reading the file 
data = my_file.read() 
  
# split on ('\n')
data_list = data.split("\n")

# %%
data_list
# Out:
# ['...................#.....#...............#......................#......................#...................#...........................#....',
#  '..................................................#................................................#..............#.........................',
#  '......#.....#.................#..............................................................#..............................................',
#  '......................................................#..................#.....#............................................................',
#  '.....................................................................................#.....................................#................',
#  '.#............................................................................................................#.............................',
# ...

# %%
test = """...#......
.......#..
#.........
..........
......#...
.#........
.........#
..........
.......#..
#...#.....""".split("\n")

# %%
test
# Out:
# ['...#......',
#  '.......#..',
#  '#.........',
#  '..........',
#  '......#...',
#  '.#........',
#  '.........#',
#  '..........',
#  '.......#..',
#  '#...#.....']

# %%
len(data_list[0])
# Out:
# 140

# %%
len(data_list)
# Out:
# 140

# %%
#data_list = test

# %%
ignore_list = []
for i in range(len(data_list[0])):
    if (data_list[i] == "."*len(data_list[0])) & (i not in ignore_list):
        print(f"Adding row due to row {i}")
        data_list.insert(i, "."*len(data_list[0]))
        ignore_list.append(i+1)

ignore_list_col = []
for i in range(len(data_list)):
    temp_list = []
    for data in data_list:
        temp_list.append(data[i])
    #print(f"Col {i+1} has following values {temp_list}")
    #print(all(char == "." for char in temp_list))
    if (all(char == "." for char in temp_list)) & (i not in ignore_list_col):
        print(f"Adding data to {i+1} column")
        for row in range(len(data_list)):
            data_list[row] = data_list[row][:i+1] + "." + data_list[row][i+1:]
        ignore_list_col.append(i+1)
# Out:
# Adding row due to row 17
# Adding row due to row 28
# Adding row due to row 71
# Adding row due to row 80
# Adding row due to row 97
# Adding row due to row 101
# Adding data to 16 column
# Adding data to 55 column
# Adding data to 63 column
# Adding data to 76 column
# Adding data to 93 column
# Adding data to 100 column

# %%
"""offset = 0
for i in range(len(data_list[0])):
    if (data_list[i+offset] == "."*len(data_list[0])):
        print(f"Adding rows due to row {i+offset}")
        for num in range(1000000):
            data_list.insert(i+offset+num, "."*len(data_list[0]))
            #print(f"Adding row here: {i+offset+num}")
        offset += 1000000

offset = 0
for i in range(len(data_list)):
    temp_list = []
    for data in data_list:
        temp_list.append(data[i+offset])
    #print(f"Col {i+1} has following values {temp_list}")
    #print(all(char == "." for char in temp_list))
    if (all(char == "." for char in temp_list)):
        print(f"Adding columns due to {i+offset} column")
        for row in range(len(data_list)):
            data_list[row] = data_list[row][:i+offset+1] + ("."*1000000) + data_list[row][i+offset+1:]
            offset += 1000000

for col_add in add_cols:
    print(f"Adding data to {col_add} column")
    for i in range(len(data_list)):
        data_list[i] = data_list[i][:col_add+1] + "." + data_list[i][col_add+1:]"""
# Out:
# 'offset = 0\nfor i in range(len(data_list[0])):\n    if (data_list[i+offset] == "."*len(data_list[0])):\n        print(f"Adding rows due to row {i+offset}")\n        for num in range(1000000):\n            data_list.insert(i+offset+num, "."*len(data_list[0]))\n            #print(f"Adding row here: {i+offset+num}")\n        offset += 1000000\n\noffset = 0\nfor i in range(len(data_list)):\n    temp_list = []\n    for data in data_list:\n        temp_list.append(data[i+offset])\n    #print(f"Col {i+1} has following values {temp_list}")\n    #print(all(char == "." for char in temp_list))\n    if (all(char == "." for char in temp_list)):\n        print(f"Adding columns due to {i+offset} column")\n        for row in range(len(data_list)):\n            data_list[row] = data_list[row][:i+offset+1] + ("."*1000000) + data_list[row][i+offset+1:]\n            offset += 1000000\n\nfor col_add in add_cols:\n    print(f"Adding data to {col_add} column")\n    for i in range(len(data_list)):\n       
# ...

# %%
data_list
# Out:
# ['....................#.....#...............#........................#.......................#.....................#...........................#....',
#  '...................................................#.....................................................#..............#.........................',
#  '......#.....#..................#..................................................................#...............................................',
#  '........................................................#....................#.....#..............................................................',
#  '.........................................................................................#.......................................#................',
#  '.#..................................................................................................................#.............................',
# ...

# %%
galaxy_list = []
# rows
for i in range(len(data_list)):
    #cols
    for j in range(len(data_list[0])):
        if data_list[i][j] == "#":
            galaxy_list.append((i, j))

# %%
checked_list = []
distances_list = []
for location in galaxy_list:
    for second_location in galaxy_list:
        if (location != second_location) & (second_location not in checked_list):
            distance = abs(second_location[0] - location[0]) + abs(second_location[1] - location[1])
            for i in ignore_list:
                if i in range(min(second_location[0]+1,location[0]+1),max(second_location[0],location[0])):
                    distance += 999998
            for i in ignore_list_col:
                if i in range(min(second_location[1]+1,location[1]+1),max(second_location[1],location[1])):
                    distance += 999998
            distances_list.append(distance)
    checked_list.append(location)

# %%
sum(distances_list)
# Out:
# 504715068438

# %%
len(checked_list)
# Out:
# 451
