# %%
import pandas as pd

# %%
# opening the file in read mode 
my_file = open("input.txt", "r") 
  
# reading the file 
data = my_file.read() 
  
# split on ('\n')
data_list = data.split("\n")

# %%
data_list = [[*data] for data in data_list]

# %%
data_dict = {}
for idx, data in enumerate(data_list):
    data_dict[idx] = data

# %%
for idx, data in enumerate(data_dict.values()):
    if "S" in data:
        list_idx = data.index("S")
        dict_idx = idx
        break
    else:
        pass

# %%
print(f"The entry point was in row {dict_idx} and column {list_idx}")
# Out:
# The entry point was in row 22 and column 91

# %%
north_list = ["|", "7", "F"]
south_list = ["|", "J", "L"]
west_list = ["-", "F", "L"]
east_list = ["-", "J", "7"]

# %%
up = dict_idx - 1
down = dict_idx + 1
left = list_idx - 1
right = list_idx + 1

route_dicts = {}

if data_dict[up][list_idx] in north_list:
    route_dicts["North"] = [(up, list_idx)]
if data_dict[down][list_idx] in south_list:
    route_dicts["South"] = [(down, list_idx)]
if data_dict[dict_idx][left] in west_list:
    route_dicts["West"] = [(dict_idx, left)]
if data_dict[dict_idx][right] in east_list:
    route_dicts["East"] = [(dict_idx, right)]

# %%
route_dicts
# Out:
# {'North': [(21, 91)], 'West': [(22, 90)]}

# %%
def move_further(row, col, idx, complete, num_steps):
    up = row - 1
    down = row + 1
    left = col - 1
    right = col + 1

    if (data_dict[row][col] in south_list) & (data_dict[up][col] in north_list) & ((up, col) not in route_dicts[idx]):
        for i in route_dicts.keys():
            if (up, col) in route_dicts[i]:
                complete = True
                print(f"Finished in {num_steps} steps")
        route_dicts[idx].append((up, col))
    elif (data_dict[row][col] in north_list) & (data_dict[down][col] in south_list)  & ((down, col) not in route_dicts[idx]):
        for i in route_dicts.keys():
            if (down, col) in route_dicts[i]:
                complete = True
                print(f"Finished in {num_steps} steps")
        route_dicts[idx].append((down, col))
    elif (data_dict[row][col] in east_list) & (data_dict[row][left] in west_list) & ((row, left) not in route_dicts[idx]):
        for i in route_dicts.keys():
            if (row, left) in route_dicts[i]:
                complete = True
                print(f"Finished in {num_steps} steps")
        route_dicts[idx].append((row, left))
    elif (data_dict[row][col] in west_list) & (data_dict[row][right] in east_list) & ((row, right) not in route_dicts[idx]):
        for i in route_dicts.keys():
            if (row, right) in route_dicts[i]:
                complete = True
                print(f"Finished in {num_steps} steps")
        route_dicts[idx].append((row, right))
    else:
        raise ValueError(f"No route found at {row}, {col}")
    
    return complete

# %%
complete = False
num_steps = 1
while complete == False:
    num_steps += 1
    for i in route_dicts.keys():
        complete = move_further(route_dicts[i][-1][0], route_dicts[i][-1][1], i, complete, num_steps)
        print(f"{num_steps} steps taken with {i} route at {route_dicts[i][-1]}")
        #print(route_dicts)
    #print(num_steps)
# Out:
# 2 steps taken with North route at (21, 90)
# 2 steps taken with West route at (22, 89)
# 3 steps taken with North route at (21, 89)
# 3 steps taken with West route at (23, 89)
# 4 steps taken with North route at (20, 89)
# 4 steps taken with West route at (23, 90)
# 5 steps taken with North route at (20, 90)
# 5 steps taken with West route at (23, 91)
# 6 steps taken with North route at (19, 90)
# 6 steps taken with West route at (24, 91)
# 7 steps taken with North route at (19, 89)
# 7 steps taken with West route at (24, 90)
# 8 steps taken with North route at (18, 89)
# 8 steps taken with West route at (24, 89)
# 9 steps taken with North route at (18, 90)
# 9 steps taken with West route at (25, 89)
# 10 steps taken with North route at (18, 91)
# 10 steps taken with West route at (25, 90)
# 11 steps taken with North route at (18, 92)
# 11 steps taken with West route at (25, 91)
# 12 steps taken with North route at (18, 93)
# 12 steps taken with West route at (26, 91)
# 13 steps taken with North route at (19, 93)
# 13 steps taken with West route at (27, 91)
# 14 steps taken with North route at (19, 92)
# 14 steps taken with West route at (27, 92)
# 15 steps taken with North route at (19, 91)
# 15 steps taken with West route at (26, 92)
# 16 steps taken with North route at (20, 91)
# 16 steps taken with West route at (25, 92)
# 17 steps taken with North route at (20, 92)
# 17 steps taken with West route at (25, 93)
# 18 steps taken with North route at (21, 92)
# 18 steps taken with West route at (26, 93)
# 19 steps taken with North route at (22, 92)
# 19 steps taken with West route at (27, 93)
# 20 steps taken with North route at (23, 92)
# 20 steps taken with West route at (28, 93)
# 21 steps taken with North route at (24, 92)
# 21 steps taken with West route at (29, 93)
# 22 steps taken with North route at (24, 93)
# 22 steps taken with West route at (29, 92)
# 23 steps taken with North route at (23, 93)
# 23 steps taken with West route at (30, 92)
# 24 steps taken with North route at (22, 93)
# 24 steps taken with West route at (30, 93)
# 25 steps taken with North route at (21, 93)
# 25 steps taken with West route at (31, 93)
# 26 steps taken with North route at (20, 93)
# 26 steps taken with West route at (32, 93)
# 27 steps taken with North route at (20, 94)
# 27 steps taken with West route at (33, 93)
# 28 steps taken with North route at (21, 94)
# 28 steps taken with West route at (33, 94)
# 29 steps taken with North route at (22, 94)
# 29 steps taken with West route at (33, 95)
# 30 steps taken with North route at (23, 94)
# 30 steps taken with West route at (34, 95)
# 31 steps taken with North route at (24, 94)
# 31 steps taken with West route at (35, 95)
# 32 steps taken with North route at (24, 95)
# 32 steps taken with West route at (35, 94)
# 33 steps taken with North route at (25, 95)
# 33 steps taken with West route at (34, 94)
# 34 steps taken with North route at (25, 94)
# 34 steps taken with West route at (34, 93)
# 35 steps taken with North route at (26, 94)
# 35 steps taken with West route at (35, 93)
# 36 steps taken with North route at (27, 94)
# 36 steps taken with West route at (36, 93)
# 37 steps taken with North route at (28, 94)
# 37 steps taken with West route at (36, 94)
# 38 steps taken with North route at (29, 94)
# 38 steps taken with West route at (36, 95)
# 39 steps taken with North route at (30, 94)
# 39 steps taken with West route at (37, 95)
# 40 steps taken with North route at (31, 94)
# 40 steps taken with West route at (37, 94)
# 41 steps taken with North route at (32, 94)
# 41 steps taken with West route at (37, 93)
# 42 steps taken with North route at (32, 95)
# 42 steps taken with West route at (38, 93)
# 43 steps taken with North route at (31, 95)
# 43 steps taken with West route at (38, 94)
# 44 steps taken with North route at (30, 95)
# 44 steps taken with West route at (39, 94)
# 45 steps taken with North route at (29, 95)
# 45 steps taken with West route at (39, 95)
# 46 steps taken with North route at (29, 96)
# 46 steps taken with West route at (39, 96)
# 47 steps taken with North route at (30, 96)
# 47 steps taken with West route at (40, 96)
# 48 steps taken with North route at (30, 97)
# 48 steps taken with West route at (40, 97)
# 49 steps taken with North route at (31, 97)
# 49 steps taken with West route at (40, 98)
# 50 steps taken with North route at (31, 96)
# 50 steps taken with West route at (41, 98)
# 51 steps taken with North route at (32, 96)
# 51 steps taken with West route at (41, 97)
# 52 steps taken with North route at (33, 96)
# 52 steps taken with West route at (41, 96)
# 53 steps taken with North route at (34, 96)
# 53 steps taken with West route at (42, 96)
# 54 steps taken with North route at (35, 96)
# 54 steps taken with West route at (42, 97)
# 55 steps taken with North route at (36, 96)
# 55 steps taken with West route at (43, 97)
# 56 steps taken with North route at (37, 96)
# 56 steps taken with West route at (43, 98)
# 57 steps taken with North route at (38, 96)
# 57 steps taken with West route at (43, 99)
# 58 steps taken with North route at (38, 97)
# 58 steps taken with West route at (44, 99)
# 59 steps taken with North route at (37, 97)
# 59 steps taken with West route at (44, 98)
# 60 steps taken with North route at (36, 97)
# 60 steps taken with West route at (44, 97)
# 61 steps taken with North route at (35, 97)
# 61 steps taken with West route at (45, 97)
# 62 steps taken with North route at (34, 97)
# 62 steps taken with West route at (45, 98)
# 63 steps taken with North route at (33, 97)
# 63 steps taken with West route at (46, 98)
# 64 steps taken with North route at (32, 97)
# 64 steps taken with West route at (46, 97)
# 65 steps taken with North route at (32, 98)
# 65 steps taken with West route at (46, 96)
# 66 steps taken with North route at (33, 98)
# 66 steps taken with West route at (45, 96)
# 67 steps taken with North route at (34, 98)
# 67 steps taken with West route at (44, 96)
# 68 steps taken with North route at (35, 98)
# 68 steps taken with West route at (43, 96)
# 69 steps taken with North route at (36, 98)
# 69 steps taken with West route at (43, 95)
# 70 steps taken with North route at (36, 99)
# 70 steps taken with West route at (42, 95)
# 71 steps taken with North route at (35, 99)
# 71 steps taken with West route at (41, 95)
# 72 steps taken with North route at (34, 99)
# 72 steps taken with West route at (40, 95)
# 73 steps taken with North route at (33, 99)
# 73 steps taken with West route at (40, 94)
# 74 steps taken with North route at (32, 99)
# 74 steps taken with West route at (41, 94)
# 75 steps taken with North route at (31, 99)
# 75 steps taken with West route at (42, 94)
# 76 steps taken with North route at (31, 98)
# 76 steps taken with West route at (43, 94)
# 77 steps taken with North route at (30, 98)
# 77 steps taken with West route at (44, 94)
# 78 steps taken with North route at (29, 98)
# 78 steps taken with West route at (44, 95)
# 79 steps taken with North route at (29, 97)
# 79 steps taken with West route at (45, 95)
# 80 steps taken with North route at (28, 97)
# 80 steps taken with West route at (45, 94)
# 81 steps taken with North route at (28, 98)
# 81 steps taken with West route at (45, 93)
# 82 steps taken with North route at (27, 98)
# 82 steps taken with West route at (44, 93)
# 83 steps taken with North route at (27, 97)
# 83 steps taken with West route at (43, 93)
# 84 steps taken with North route at (27, 96)
# 84 steps taken with West route at (43, 92)
# 85 steps taken with North route at (28, 96)
# 85 steps taken with West route at (42, 92)
# 86 steps taken with North route at (28, 95)
# 86 steps taken with West route at (42, 93)
# 87 steps taken with North route at (27, 95)
# 87 steps taken with West route at (41, 93)
# 88 steps taken with North route at (26, 95)
# 88 steps taken with West route at (41, 92)
# 89 steps taken with North route at (26, 96)
# 89 steps taken with West route at (40, 92)
# 90 steps taken with North route at (26, 97)
# 90 steps taken with West route at (40, 93)
# 91 steps taken with North route at (25, 97)
# 91 steps taken with West route at (39, 93)
# 92 steps taken with North route at (25, 96)
# 92 steps taken with West route at (39, 92)
# 93 steps taken with North route at (24, 96)
# 93 steps taken with West route at (38, 92)
# 94 steps taken with North route at (23, 96)
# 94 steps taken with West route at (37, 92)
# 95 steps taken with North route at (23, 95)
# 95 steps taken with West route at (36, 92)
# 96 steps taken with North route at (22, 95)
# 96 steps taken with West route at (35, 92)
# 97 steps taken with North route at (22, 96)
# 97 steps taken with West route at (34, 92)
# 98 steps taken with North route at (21, 96)
# 98 steps taken with West route at (33, 92)
# 99 steps taken with North route at (21, 95)
# 99 steps taken with West route at (32, 92)
# 100 steps taken with North route at (20, 95)
# 100 steps taken with West route at (31, 92)
# 101 steps taken with North route at (20, 96)
# 101 steps taken with West route at (31, 91)
# 102 steps taken with North route at (19, 96)
# 102 steps taken with West route at (31, 90)
# 103 steps taken with North route at (19, 97)
# 103 steps taken with West route at (32, 90)
# 104 steps taken with North route at (18, 97)
# 104 steps taken with West route at (32, 91)
# 105 steps taken with North route at (17, 97)
# 105 steps taken with West route at (33, 91)
# 106 steps taken with North route at (17, 96)
# 106 steps taken with West route at (33, 90)
# 107 steps taken with North route at (18, 96)
# 107 steps taken with West route at (34, 90)
# 108 steps taken with North route at (18, 95)
# 108 steps taken with West route at (34, 91)
# 109 steps taken with North route at (19, 95)
# 109 steps taken with West route at (35, 91)
# 110 steps taken with North route at (19, 94)
# 110 steps taken with West route at (36, 91)
# 111 steps taken with North route at (18, 94)
# 111 steps taken with West route at (37, 91)
# 112 steps taken with North route at (17, 94)
# 112 steps taken with West route at (38, 91)
# 113 steps taken with North route at (17, 95)
# 113 steps taken with West route at (39, 91)
# 114 steps taken with North route at (16, 95)
# 114 steps taken with West route at (39, 90)
# 115 steps taken with North route at (16, 96)
# 115 steps taken with West route at (38, 90)
# 116 steps taken with North route at (15, 96)
# 116 steps taken with West route at (37, 90)
# 117 steps taken with North route at (15, 95)
# 117 steps taken with West route at (37, 89)
# 118 steps taken with North route at (15, 94)
# 118 steps taken with West route at (36, 89)
# 119 steps taken with North route at (14, 94)
# 119 steps taken with West route at (36, 90)
# 120 steps taken with North route at (14, 95)
# 120 steps taken with West route at (35, 90)
# 121 steps taken with North route at (14, 96)
# 121 steps taken with West route at (35, 89)
# 122 steps taken with North route at (14, 97)
# 122 steps taken with West route at (34, 89)
# 123 steps taken with North route at (13, 97)
# 123 steps taken with West route at (33, 89)
# 124 steps taken with North route at (13, 96)
# 124 steps taken with West route at (33, 88)
# 125 steps taken with North route at (12, 96)
# 125 steps taken with West route at (34, 88)
# 126 steps taken with North route at (12, 95)
# 126 steps taken with West route at (35, 88)
# 127 steps taken with North route at (13, 95)
# 127 steps taken with West route at (36, 88)
# 128 steps taken with North route at (13, 94)
# 128 steps taken with West route at (36, 87)
# 129 steps taken with North route at (12, 94)
# 129 steps taken with West route at (35, 87)
# 130 steps taken with North route at (11, 94)
# 130 steps taken with West route at (34, 87)
# 131 steps taken with North route at (11, 95)
# 131 steps taken with West route at (33, 87)
# 132 steps taken with North route at (10, 95)
# 132 steps taken with West route at (32, 87)
# 133 steps taken with North route at (10, 94)
# 133 steps taken with West route at (32, 88)
# 134 steps taken with North route at (10, 93)
# 134 steps taken with West route at (32, 89)
# 135 steps taken with North route at (9, 93)
# 135 steps taken with West route at (31, 89)
# 136 steps taken with North route at (9, 92)
# 136 steps taken with West route at (31, 88)
# 137 steps taken with North route at (8, 92)
# 137 steps taken with West route at (30, 88)
# 138 steps taken with North route at (7, 92)
# 138 steps taken with West route at (30, 89)
# 139 steps taken with North route at (7, 91)
# 139 steps taken with West route at (30, 90)
# 140 steps taken with North route at (7, 90)
# 140 steps taken with West route at (30, 91)
# 141 steps taken with North route at (6, 90)
# 141 steps taken with West route at (29, 91)
# 142 steps taken with North route at (6, 91)
# 142 steps taken with West route at (28, 91)
# 143 steps taken with North route at (6, 92)
# 143 steps taken with West route at (28, 90)
# 144 steps taken with North route at (5, 92)
# 144 steps taken with West route at (29, 90)
# 145 steps taken with North route at (5, 91)
# 145 steps taken with West route at (29, 89)
# 146 steps taken with North route at (5, 90)
# 146 steps taken with West route at (29, 88)
# 147 steps taken with North route at (4, 90)
# 147 steps taken with West route at (29, 87)
# 148 steps taken with North route at (3, 90)
# 148 steps taken with West route at (28, 87)
# 149 steps taken with North route at (3, 91)
# 149 steps taken with West route at (28, 88)
# 150 steps taken with North route at (4, 91)
# 150 steps taken with West route at (28, 89)
# 151 steps taken with North route at (4, 92)
# 151 steps taken with West route at (27, 89)
# 152 steps taken with North route at (3, 92)
# 152 steps taken with West route at (27, 90)
# 153 steps taken with North route at (2, 92)
# 153 steps taken with West route at (26, 90)
# 154 steps taken with North route at (2, 93)
# 154 steps taken with West route at (26, 89)
# 155 steps taken with North route at (3, 93)
# 155 steps taken with West route at (26, 88)
# 156 steps taken with North route at (3, 94)
# 156 steps taken with West route at (27, 88)
# 157 steps taken with North route at (4, 94)
# 157 steps taken with West route at (27, 87)
# 158 steps taken with North route at (4, 93)
# 158 steps taken with West route at (26, 87)
# 159 steps taken with North route at (5, 93)
# 159 steps taken with West route at (25, 87)
# 160 steps taken with North route at (6, 93)
# 160 steps taken with West route at (24, 87)
# 161 steps taken with North route at (6, 94)
# 161 steps taken with West route at (24, 88)
# 162 steps taken with North route at (7, 94)
# 162 steps taken with West route at (23, 88)
# 163 steps taken with North route at (7, 93)
# 163 steps taken with West route at (23, 87)
# 164 steps taken with North route at (8, 93)
# 164 steps taken with West route at (22, 87)
# 165 steps taken with North route at (8, 94)
# 165 steps taken with West route at (22, 88)
# 166 steps taken with North route at (9, 94)
# 166 steps taken with West route at (21, 88)
# 167 steps taken with North route at (9, 95)
# 167 steps taken with West route at (20, 88)
# 168 steps taken with North route at (8, 95)
# 168 steps taken with West route at (20, 87)
# 169 steps taken with North route at (7, 95)
# 169 steps taken with West route at (21, 87)
# 170 steps taken with North route at (6, 95)
# 170 steps taken with West route at (21, 86)
# 171 steps taken with North route at (5, 95)
# 171 steps taken with West route at (22, 86)
# 172 steps taken with North route at (5, 96)
# 172 steps taken with West route at (23, 86)
# 173 steps taken with North route at (6, 96)
# 173 steps taken with West route at (24, 86)
# 174 steps taken with North route at (6, 97)
# 174 steps taken with West route at (25, 86)
# 175 steps taken with North route at (7, 97)
# 175 steps taken with West route at (26, 86)
# 176 steps taken with North route at (7, 96)
# 176 steps taken with West route at (26, 85)
# 177 steps taken with North route at (8, 96)
# 177 steps taken with West route at (27, 85)
# 178 steps taken with North route at (8, 97)
# 178 steps taken with West route at (27, 86)
# 179 steps taken with North route at (8, 98)
# 179 steps taken with West route at (28, 86)
# 180 steps taken with North route at (7, 98)
# 180 steps taken with West route at (29, 86)
# 181 steps taken with North route at (6, 98)
# 181 steps taken with West route at (29, 85)
# 182 steps taken with North route at (5, 98)
# 182 steps taken with West route at (30, 85)
# 183 steps taken with North route at (5, 99)
# 183 steps taken with West route at (30, 86)
# 184 steps taken with North route at (6, 99)
# 184 steps taken with West route at (30, 87)
# 185 steps taken with North route at (7, 99)
# 185 steps taken with West route at (31, 87)
# 186 steps taken with North route at (8, 99)
# 186 steps taken with West route at (31, 86)
# 187 steps taken with North route at (9, 99)
# 187 steps taken with West route at (32, 86)
# 188 steps taken with North route at (10, 99)
# 188 steps taken with West route at (33, 86)
# 189 steps taken with North route at (10, 98)
# 189 steps taken with West route at (34, 86)
# 190 steps taken with North route at (9, 98)
# 190 steps taken with West route at (35, 86)
# 191 steps taken with North route at (9, 97)
# 191 steps taken with West route at (36, 86)
# 192 steps taken with North route at (9, 96)
# 192 steps taken with West route at (37, 86)
# 193 steps taken with North route at (10, 96)
# 193 steps taken with West route at (37, 87)
# 194 steps taken with North route at (11, 96)
# 194 steps taken with West route at (38, 87)
# 195 steps taken with North route at (11, 97)
# 195 steps taken with West route at (38, 88)
# 196 steps taken with North route at (12, 97)
# 196 steps taken with West route at (38, 89)
# 197 steps taken with North route at (12, 98)
# 197 steps taken with West route at (39, 89)
# 198 steps taken with North route at (13, 98)
# 198 steps taken with West route at (40, 89)
# 199 steps taken with North route at (14, 98)
# 199 steps taken with West route at (40, 90)
# 200 steps taken with North route at (15, 98)
# 200 steps taken with West route at (40, 91)
# 201 steps taken with North route at (15, 97)
# 201 steps taken with West route at (41, 91)
# 202 steps taken with North route at (16, 97)
# 202 steps taken with West route at (41, 90)
# 203 steps taken with North route at (16, 98)
# 203 steps taken with West route at (41, 89)
# 204 steps taken with North route at (17, 98)
# 204 steps taken with West route at (42, 89)
# 205 steps taken with North route at (18, 98)
# 205 steps taken with West route at (43, 89)
# 206 steps taken with North route at (19, 98)
# 206 steps taken with West route at (43, 90)
# 207 steps taken with North route at (20, 98)
# 207 steps taken with West route at (42, 90)
# 208 steps taken with North route at (20, 97)
# 208 steps taken with West route at (42, 91)
# 209 steps taken with North route at (21, 97)
# 209 steps taken with West route at (43, 91)
# 210 steps taken with North route at (22, 97)
# 210 steps taken with West route at (44, 91)
# 211 steps taken with North route at (23, 97)
# 211 steps taken with West route at (45, 91)
# 212 steps taken with North route at (24, 97)
# 212 steps taken with West route at (45, 92)
# 213 steps taken with North route at (24, 98)
# 213 steps taken with West route at (46, 92)
# 214 steps taken with North route at (23, 98)
# 214 steps taken with West route at (46, 91)
# 215 steps taken with North route at (22, 98)
# 215 steps taken with West route at (47, 91)
# 216 steps taken with North route at (22, 99)
# 216 steps taken with West route at (47, 90)
# 217 steps taken with North route at (23, 99)
# 217 steps taken with West route at (47, 89)
# 218 steps taken with North route at (24, 99)
# 218 steps taken with West route at (48, 89)
# 219 steps taken with North route at (25, 99)
# 219 steps taken with West route at (49, 89)
# 220 steps taken with North route at (25, 98)
# 220 steps taken with West route at (50, 89)
# 221 steps taken with North route at (26, 98)
# 221 steps taken with West route at (51, 89)
# 222 steps taken with North route at (26, 99)
# 222 steps taken with West route at (51, 88)
# 223 steps taken with North route at (27, 99)
# 223 steps taken with West route at (52, 88)
# 224 steps taken with North route at (28, 99)
# 224 steps taken with West route at (53, 88)
# 225 steps taken with North route at (29, 99)
# 225 steps taken with West route at (54, 88)
# 226 steps taken with North route at (30, 99)
# 226 steps taken with West route at (55, 88)
# 227 steps taken with North route at (30, 100)
# 227 steps taken with West route at (56, 88)
# 228 steps taken with North route at (31, 100)
# 228 steps taken with West route at (57, 88)
# 229 steps taken with North route at (32, 100)
# 229 steps taken with West route at (57, 87)
# 230 steps taken with North route at (33, 100)
# 230 steps taken with West route at (56, 87)
# 231 steps taken with North route at (34, 100)
# 231 steps taken with West route at (56, 86)
# 232 steps taken with North route at (35, 100)
# 232 steps taken with West route at (56, 85)
# 233 steps taken with North route at (36, 100)
# 233 steps taken with West route at (56, 84)
# 234 steps taken with North route at (37, 100)
# 234 steps taken with West route at (56, 83)
# 235 steps taken with North route at (37, 99)
# 235 steps taken with West route at (56, 82)
# 236 steps taken with North route at (37, 98)
# 236 steps taken with West route at (57, 82)
# 237 steps taken with North route at (38, 98)
# 237 steps taken with West route at (57, 81)
# 238 steps taken with North route at (39, 98)
# 238 steps taken with West route at (56, 81)
# 239 steps taken with North route at (39, 99)
# 239 steps taken with West route at (56, 80)
# 240 steps taken with North route at (38, 99)
# 240 steps taken with West route at (55, 80)
# 241 steps taken with North route at (38, 100)
# 241 steps taken with West route at (55, 81)
# 242 steps taken with North route at (39, 100)
# 242 steps taken with West route at (55, 82)
# 243 steps taken with North route at (40, 100)
# 243 steps taken with West route at (54, 82)
# 244 steps taken with North route at (40, 99)
# 244 steps taken with West route at (54, 81)
# 245 steps taken with North route at (41, 99)
# 245 steps taken with West route at (54, 80)
# 246 steps taken with North route at (42, 99)
# 246 steps taken with West route at (53, 80)
# 247 steps taken with North route at (42, 100)
# 247 steps taken with West route at (53, 81)
# 248 steps taken with North route at (41, 100)
# 248 steps taken with West route at (53, 82)
# 249 steps taken with North route at (41, 101)
# 249 steps taken with West route at (53, 83)
# 250 steps taken with North route at (40, 101)
# 250 steps taken with West route at (53, 84)
# 251 steps taken with North route at (39, 101)
# 251 steps taken with West route at (54, 84)
# 252 steps taken with North route at (38, 101)
# 252 steps taken with West route at (54, 83)
# 253 steps taken with North route at (37, 101)
# 253 steps taken with West route at (55, 83)
# 254 steps taken with North route at (36, 101)
# 254 steps taken with West route at (55, 84)
# 255 steps taken with North route at (35, 101)
# 255 steps taken with West route at (55, 85)
# 256 steps taken with North route at (34, 101)
# 256 steps taken with West route at (55, 86)
# 257 steps taken with North route at (33, 101)
# 257 steps taken with West route at (55, 87)
# 258 steps taken with North route at (32, 101)
# 258 steps taken with West route at (54, 87)
# 259 steps taken with North route at (31, 101)
# 259 steps taken with West route at (54, 86)
# 260 steps taken with North route at (30, 101)
# 260 steps taken with West route at (54, 85)
# 261 steps taken with North route at (29, 101)
# 261 steps taken with West route at (53, 85)
# 262 steps taken with North route at (28, 101)
# 262 steps taken with West route at (53, 86)
# 263 steps taken with North route at (28, 100)
# 263 steps taken with West route at (53, 87)
# 264 steps taken with North route at (27, 100)
# 264 steps taken with West route at (52, 87)
# 265 steps taken with North route at (27, 101)
# 265 steps taken with West route at (51, 87)
# 266 steps taken with North route at (26, 101)
# 266 steps taken with West route at (50, 87)
# 267 steps taken with North route at (25, 101)
# 267 steps taken with West route at (50, 88)
# 268 steps taken with North route at (25, 100)
# 268 steps taken with West route at (49, 88)
# 269 steps taken with North route at (24, 100)
# 269 steps taken with West route at (49, 87)
# 270 steps taken with North route at (23, 100)
# 270 steps taken with West route at (49, 86)
# 271 steps taken with North route at (22, 100)
# 271 steps taken with West route at (50, 86)
# 272 steps taken with North route at (21, 100)
# 272 steps taken with West route at (51, 86)
# 273 steps taken with North route at (21, 99)
# 273 steps taken with West route at (52, 86)
# 274 steps taken with North route at (20, 99)
# 274 steps taken with West route at (52, 85)
# 275 steps taken with North route at (20, 100)
# 275 steps taken with West route at (52, 84)
# 276 steps taken with North route at (20, 101)
# 276 steps taken with West route at (51, 84)
# 277 steps taken with North route at (19, 101)
# 277 steps taken with West route at (51, 85)
# 278 steps taken with North route at (19, 100)
# 278 steps taken with West route at (50, 85)
# 279 steps taken with North route at (18, 100)
# 279 steps taken with West route at (49, 85)
# 280 steps taken with North route at (18, 99)
# 280 steps taken with West route at (49, 84)
# 281 steps taken with North route at (17, 99)
# 281 steps taken with West route at (48, 84)
# 282 steps taken with North route at (16, 99)
# 282 steps taken with West route at (48, 85)
# 283 steps taken with North route at (15, 99)
# 283 steps taken with West route at (48, 86)
# 284 steps taken with North route at (14, 99)
# 284 steps taken with West route at (48, 87)
# 285 steps taken with North route at (13, 99)
# 285 steps taken with West route at (48, 88)
# 286 steps taken with North route at (12, 99)
# 286 steps taken with West route at (47, 88)
# 287 steps taken with North route at (11, 99)
# 287 steps taken with West route at (46, 88)
# 288 steps taken with North route at (11, 100)
# 288 steps taken with West route at (46, 89)
# 289 steps taken with North route at (12, 100)
# 289 steps taken with West route at (46, 90)
# 290 steps taken with North route at (13, 100)
# 290 steps taken with West route at (45, 90)
# 291 steps taken with North route at (13, 101)
# 291 steps taken with West route at (44, 90)
# 292 steps taken with North route at (12, 101)
# 292 steps taken with West route at (44, 89)
# 293 steps taken with North route at (11, 101)
# 293 steps taken with West route at (45, 89)
# 294 steps taken with North route at (10, 101)
# 294 steps taken with West route at (45, 88)
# 295 steps taken with North route at (10, 100)
# 295 steps taken with West route at (45, 87)
# 296 steps taken with North route at (9, 100)
# 296 steps taken with West route at (46, 87)
# 297 steps taken with North route at (8, 100)
# 297 steps taken with West route at (47, 87)
# 298 steps taken with North route at (7, 100)
# 298 steps taken with West route at (47, 86)
# 299 steps taken with North route at (7, 101)
# 299 steps taken with West route at (46, 86)
# 300 steps taken with North route at (8, 101)
# 300 steps taken with West route at (45, 86)
# 301 steps taken with North route at (9, 101)
# 301 steps taken with West route at (44, 86)
# 302 steps taken with North route at (9, 102)
# 302 steps taken with West route at (44, 87)
# 303 steps taken with North route at (9, 103)
# 303 steps taken with West route at (44, 88)
# 304 steps taken with North route at (8, 103)
# 304 steps taken with West route at (43, 88)
# 305 steps taken with North route at (7, 103)
# 305 steps taken with West route at (42, 88)
# 306 steps taken with North route at (7, 102)
# 306 steps taken with West route at (41, 88)
# 307 steps taken with North route at (6, 102)
# 307 steps taken with West route at (40, 88)
# 308 steps taken with North route at (6, 101)
# 308 steps taken with West route at (39, 88)
# 309 steps taken with North route at (5, 101)
# 309 steps taken with West route at (39, 87)
# 310 steps taken with North route at (5, 102)
# 310 steps taken with West route at (40, 87)
# 311 steps taken with North route at (5, 103)
# 311 steps taken with West route at (41, 87)
# 312 steps taken with North route at (6, 103)
# 312 steps taken with West route at (42, 87)
# 313 steps taken with North route at (6, 104)
# 313 steps taken with West route at (43, 87)
# 314 steps taken with North route at (6, 105)
# 314 steps taken with West route at (43, 86)
# 315 steps taken with North route at (7, 105)
# 315 steps taken with West route at (42, 86)
# 316 steps taken with North route at (7, 104)
# 316 steps taken with West route at (41, 86)
# 317 steps taken with North route at (8, 104)
# 317 steps taken with West route at (41, 85)
# 318 steps taken with North route at (9, 104)
# 318 steps taken with West route at (40, 85)
# 319 steps taken with North route at (10, 104)
# 319 steps taken with West route at (40, 86)
# 320 steps taken with North route at (10, 103)
# 320 steps taken with West route at (39, 86)
# 321 steps taken with North route at (10, 102)
# 321 steps taken with West route at (38, 86)
# 322 steps taken with North route at (11, 102)
# 322 steps taken with West route at (38, 85)
# 323 steps taken with North route at (11, 103)
# 323 steps taken with West route at (37, 85)
# 324 steps taken with North route at (11, 104)
# 324 steps taken with West route at (36, 85)
# 325 steps taken with North route at (11, 105)
# 325 steps taken with West route at (35, 85)
# 326 steps taken with North route at (11, 106)
# 326 steps taken with West route at (34, 85)
# 327 steps taken with North route at (10, 106)
# 327 steps taken with West route at (33, 85)
# 328 steps taken with North route at (10, 105)
# 328 steps taken with West route at (32, 85)
# 329 steps taken with North route at (9, 105)
# 329 steps taken with West route at (31, 85)
# 330 steps taken with North route at (8, 105)
# 330 steps taken with West route at (31, 84)
# 331 steps taken with North route at (8, 106)
# 331 steps taken with West route at (32, 84)
# 332 steps taken with North route at (9, 106)
# 332 steps taken with West route at (33, 84)
# 333 steps taken with North route at (9, 107)
# 333 steps taken with West route at (34, 84)
# 334 steps taken with North route at (9, 108)
# 334 steps taken with West route at (35, 84)
# 335 steps taken with North route at (10, 108)
# 335 steps taken with West route at (36, 84)
# 336 steps taken with North route at (10, 107)
# 336 steps taken with West route at (37, 84)
# 337 steps taken with North route at (11, 107)
# 337 steps taken with West route at (37, 83)
# 338 steps taken with North route at (12, 107)
# 338 steps taken with West route at (38, 83)
# 339 steps taken with North route at (12, 106)
# 339 steps taken with West route at (38, 84)
# 340 steps taken with North route at (12, 105)
# 340 steps taken with West route at (39, 84)
# 341 steps taken with North route at (12, 104)
# 341 steps taken with West route at (39, 83)
# 342 steps taken with North route at (12, 103)
# 342 steps taken with West route at (40, 83)
# 343 steps taken with North route at (12, 102)
# 343 steps taken with West route at (41, 83)
# 344 steps taken with North route at (13, 102)
# 344 steps taken with West route at (41, 84)
# 345 steps taken with North route at (13, 103)
# 345 steps taken with West route at (42, 84)
# 346 steps taken with North route at (14, 103)
# 346 steps taken with West route at (42, 83)
# 347 steps taken with North route at (14, 102)
# 347 steps taken with West route at (43, 83)
# 348 steps taken with North route at (14, 101)
# 348 steps taken with West route at (43, 84)
# 349 steps taken with North route at (14, 100)
# 349 steps taken with West route at (43, 85)
# 350 steps taken with North route at (15, 100)
# 350 steps taken with West route at (44, 85)
# 351 steps taken with North route at (15, 101)
# 351 steps taken with West route at (45, 85)
# 352 steps taken with North route at (15, 102)
# 352 steps taken with West route at (46, 85)
# 353 steps taken with North route at (16, 102)
# 353 steps taken with West route at (47, 85)
# 354 steps taken with North route at (16, 101)
# 354 steps taken with West route at (47, 84)
# 355 steps taken with North route at (16, 100)
# 355 steps taken with West route at (46, 84)
# 356 steps taken with North route at (17, 100)
# 356 steps taken with West route at (45, 84)
# 357 steps taken with North route at (17, 101)
# 357 steps taken with West route at (44, 84)
# 358 steps taken with North route at (18, 101)
# 358 steps taken with West route at (44, 83)
# 359 steps taken with North route at (18, 102)
# 359 steps taken with West route at (45, 83)
# 360 steps taken with North route at (18, 103)
# 360 steps taken with West route at (46, 83)
# 361 steps taken with North route at (17, 103)
# 361 steps taken with West route at (47, 83)
# 362 steps taken with North route at (16, 103)
# 362 steps taken with West route at (47, 82)
# 363 steps taken with North route at (15, 103)
# 363 steps taken with West route at (46, 82)
# 364 steps taken with North route at (15, 104)
# 364 steps taken with West route at (45, 82)
# 365 steps taken with North route at (16, 104)
# 365 steps taken with West route at (44, 82)
# 366 steps taken with North route at (17, 104)
# 366 steps taken with West route at (43, 82)
# 367 steps taken with North route at (18, 104)
# 367 steps taken with West route at (43, 81)
# 368 steps taken with North route at (18, 105)
# 368 steps taken with West route at (42, 81)
# 369 steps taken with North route at (17, 105)
# 369 steps taken with West route at (42, 82)
# 370 steps taken with North route at (16, 105)
# 370 steps taken with West route at (41, 82)
# 371 steps taken with North route at (15, 105)
# 371 steps taken with West route at (41, 81)
# 372 steps taken with North route at (14, 105)
# 372 steps taken with West route at (40, 81)
# 373 steps taken with North route at (14, 104)
# 373 steps taken with West route at (40, 82)
# 374 steps taken with North route at (13, 104)
# 374 steps taken with West route at (39, 82)
# 375 steps taken with North route at (13, 105)
# 375 steps taken with West route at (39, 81)
# 376 steps taken with North route at (13, 106)
# 376 steps taken with West route at (38, 81)
# 377 steps taken with North route at (13, 107)
# 377 steps taken with West route at (38, 82)
# 378 steps taken with North route at (14, 107)
# 378 steps taken with West route at (37, 82)
# 379 steps taken with North route at (14, 106)
# 379 steps taken with West route at (36, 82)
# 380 steps taken with North route at (15, 106)
# 380 steps taken with West route at (36, 83)
# 381 steps taken with North route at (15, 107)
# 381 steps taken with West route at (35, 83)
# 382 steps taken with North route at (16, 107)
# 382 steps taken with West route at (34, 83)
# 383 steps taken with North route at (16, 106)
# 383 steps taken with West route at (33, 83)
# 384 steps taken with North route at (17, 106)
# 384 steps taken with West route at (32, 83)
# 385 steps taken with North route at (18, 106)
# 385 steps taken with West route at (31, 83)
# 386 steps taken with North route at (19, 106)
# 386 steps taken with West route at (30, 83)
# 387 steps taken with North route at (19, 105)
# 387 steps taken with West route at (30, 84)
# 388 steps taken with North route at (19, 104)
# 388 steps taken with West route at (29, 84)
# 389 steps taken with North route at (19, 103)
# 389 steps taken with West route at (29, 83)
# 390 steps taken with North route at (19, 102)
# 390 steps taken with West route at (28, 83)
# 391 steps taken with North route at (20, 102)
# 391 steps taken with West route at (28, 84)
# 392 steps taken with North route at (20, 103)
# 392 steps taken with West route at (27, 84)
# 393 steps taken with North route at (20, 104)
# 393 steps taken with West route at (27, 83)
# 394 steps taken with North route at (20, 105)
# 394 steps taken with West route at (26, 83)
# 395 steps taken with North route at (20, 106)
# 395 steps taken with West route at (26, 84)
# 396 steps taken with North route at (21, 106)
# 396 steps taken with West route at (25, 84)
# 397 steps taken with North route at (21, 105)
# 397 steps taken with West route at (24, 84)
# 398 steps taken with North route at (21, 104)
# 398 steps taken with West route at (24, 85)
# 399 steps taken with North route at (21, 103)
# 399 steps taken with West route at (23, 85)
# 400 steps taken with North route at (21, 102)
# 400 steps taken with West route at (23, 84)
# 401 steps taken with North route at (21, 101)
# 401 steps taken with West route at (22, 84)
# 402 steps taken with North route at (22, 101)
# 402 steps taken with West route at (22, 85)
# 403 steps taken with North route at (23, 101)
# 403 steps taken with West route at (21, 85)
# 404 steps taken with North route at (24, 101)
# 404 steps taken with West route at (21, 84)
# 405 steps taken with North route at (24, 102)
# 405 steps taken with West route at (20, 84)
# 406 steps taken with North route at (23, 102)
# 406 steps taken with West route at (20, 85)
# 407 steps taken with North route at (22, 102)
# 407 steps taken with West route at (20, 86)
# 408 steps taken with North route at (22, 103)
# 408 steps taken with West route at (19, 86)
# 409 steps taken with North route at (22, 104)
# 409 steps taken with West route at (19, 87)
# 410 steps taken with North route at (23, 104)
# 410 steps taken with West route at (19, 88)
# 411 steps taken with North route at (23, 103)
# 411 steps taken with West route at (18, 88)
# 412 steps taken with North route at (24, 103)
# 412 steps taken with West route at (18, 87)
# 413 steps taken with North route at (25, 103)
# 413 steps taken with West route at (18, 86)
# 414 steps taken with North route at (25, 102)
# 414 steps taken with West route at (17, 86)
# 415 steps taken with North route at (26, 102)
# 415 steps taken with West route at (17, 87)
# 416 steps taken with North route at (27, 102)
# 416 steps taken with West route at (17, 88)
# 417 steps taken with North route at (28, 102)
# 417 steps taken with West route at (17, 89)
# 418 steps taken with North route at (29, 102)
# 418 steps taken with West route at (17, 90)
# 419 steps taken with North route at (30, 102)
# 419 steps taken with West route at (17, 91)
# 420 steps taken with North route at (31, 102)
# 420 steps taken with West route at (17, 92)
# 421 steps taken with North route at (31, 103)
# 421 steps taken with West route at (17, 93)
# 422 steps taken with North route at (30, 103)
# 422 steps taken with West route at (16, 93)
# 423 steps taken with North route at (30, 104)
# 423 steps taken with West route at (16, 92)
# 424 steps taken with North route at (31, 104)
# 424 steps taken with West route at (16, 91)
# 425 steps taken with North route at (32, 104)
# 425 steps taken with West route at (16, 90)
# 426 steps taken with North route at (32, 103)
# 426 steps taken with West route at (16, 89)
# 427 steps taken with North route at (32, 102)
# 427 steps taken with West route at (16, 88)
# 428 steps taken with North route at (33, 102)
# 428 steps taken with West route at (16, 87)
# 429 steps taken with North route at (34, 102)
# 429 steps taken with West route at (16, 86)
# 430 steps taken with North route at (35, 102)
# 430 steps taken with West route at (15, 86)
# 431 steps taken with North route at (36, 102)
# 431 steps taken with West route at (15, 87)
# 432 steps taken with North route at (37, 102)
# 432 steps taken with West route at (15, 88)
# 433 steps taken with North route at (38, 102)
# 433 steps taken with West route at (15, 89)
# 434 steps taken with North route at (39, 102)
# 434 steps taken with West route at (14, 89)
# 435 steps taken with North route at (39, 103)
# 435 steps taken with West route at (14, 88)
# 436 steps taken with North route at (38, 103)
# 436 steps taken with West route at (13, 88)
# 437 steps taken with North route at (37, 103)
# 437 steps taken with West route at (12, 88)
# 438 steps taken with North route at (36, 103)
# 438 steps taken with West route at (12, 89)
# 439 steps taken with North route at (35, 103)
# 439 steps taken with West route at (13, 89)
# 440 steps taken with North route at (34, 103)
# 440 steps taken with West route at (13, 90)
# 441 steps taken with North route at (33, 103)
# 441 steps taken with West route at (12, 90)
# 442 steps taken with North route at (33, 104)
# 442 steps taken with West route at (12, 91)
# 443 steps taken with North route at (34, 104)
# 443 steps taken with West route at (13, 91)
# 444 steps taken with North route at (35, 104)
# 444 steps taken with West route at (13, 92)
# 445 steps taken with North route at (35, 105)
# 445 steps taken with West route at (14, 92)
# 446 steps taken with North route at (34, 105)
# 446 steps taken with West route at (14, 91)
# 447 steps taken with North route at (33, 105)
# 447 steps taken with West route at (14, 90)
# 448 steps taken with North route at (32, 105)
# 448 steps taken with West route at (15, 90)
# 449 steps taken with North route at (31, 105)
# 449 steps taken with West route at (15, 91)
# 450 steps taken with North route at (30, 105)
# 450 steps taken with West route at (15, 92)
# 451 steps taken with North route at (29, 105)
# 451 steps taken with West route at (15, 93)
# 452 steps taken with North route at (29, 104)
# 452 steps taken with West route at (14, 93)
# 453 steps taken with North route at (29, 103)
# 453 steps taken with West route at (13, 93)
# 454 steps taken with North route at (28, 103)
# 454 steps taken with West route at (12, 93)
# 455 steps taken with North route at (27, 103)
# 455 steps taken with West route at (12, 92)
# 456 steps taken with North route at (26, 103)
# 456 steps taken with West route at (11, 92)
# 457 steps taken with North route at (26, 104)
# 457 steps taken with West route at (11, 91)
# 458 steps taken with North route at (27, 104)
# 458 steps taken with West route at (11, 90)
# 459 steps taken with North route at (28, 104)
# 459 steps taken with West route at (10, 90)
# 460 steps taken with North route at (28, 105)
# 460 steps taken with West route at (10, 91)
# 461 steps taken with North route at (27, 105)
# 461 steps taken with West route at (9, 91)
# 462 steps taken with North route at (26, 105)
# 462 steps taken with West route at (9, 90)
# 463 steps taken with North route at (25, 105)
# 463 steps taken with West route at (8, 90)
# 464 steps taken with North route at (25, 104)
# 464 steps taken with West route at (8, 89)
# 465 steps taken with North route at (24, 104)
# 465 steps taken with West route at (9, 89)
# 466 steps taken with North route at (24, 105)
# 466 steps taken with West route at (10, 89)
# 467 steps taken with North route at (23, 105)
# 467 steps taken with West route at (11, 89)
# 468 steps taken with North route at (23, 106)
# 468 steps taken with West route at (11, 88)
# 469 steps taken with North route at (22, 106)
# 469 steps taken with West route at (10, 88)
# 470 steps taken with North route at (22, 107)
# 470 steps taken with West route at (9, 88)
# 471 steps taken with North route at (23, 107)
# 471 steps taken with West route at (8, 88)
# 472 steps taken with North route at (23, 108)
# 472 steps taken with West route at (7, 88)
# 473 steps taken with North route at (22, 108)
# 473 steps taken with West route at (6, 88)
# 474 steps taken with North route at (21, 108)
# 474 steps taken with West route at (6, 89)
# 475 steps taken with North route at (21, 107)
# 475 steps taken with West route at (5, 89)
# 476 steps taken with North route at (20, 107)
# 476 steps taken with West route at (5, 88)
# 477 steps taken with North route at (20, 108)
# 477 steps taken with West route at (5, 87)
# 478 steps taken with North route at (19, 108)
# 478 steps taken with West route at (6, 87)
# 479 steps taken with North route at (19, 107)
# 479 steps taken with West route at (6, 86)
# 480 steps taken with North route at (18, 107)
# 480 steps taken with West route at (6, 85)
# 481 steps taken with North route at (18, 108)
# 481 steps taken with West route at (7, 85)
# 482 steps taken with North route at (18, 109)
# 482 steps taken with West route at (7, 86)
# 483 steps taken with North route at (17, 109)
# 483 steps taken with West route at (7, 87)
# 484 steps taken with North route at (17, 108)
# 484 steps taken with West route at (8, 87)
# 485 steps taken with North route at (16, 108)
# 485 steps taken with West route at (9, 87)
# 486 steps taken with North route at (15, 108)
# 486 steps taken with West route at (9, 86)
# 487 steps taken with North route at (14, 108)
# 487 steps taken with West route at (10, 86)
# 488 steps taken with North route at (14, 109)
# 488 steps taken with West route at (10, 87)
# 489 steps taken with North route at (13, 109)
# 489 steps taken with West route at (11, 87)
# 490 steps taken with North route at (12, 109)
# 490 steps taken with West route at (12, 87)
# 491 steps taken with North route at (11, 109)
# 491 steps taken with West route at (13, 87)
# 492 steps taken with North route at (11, 110)
# 492 steps taken with West route at (14, 87)
# 493 steps taken with North route at (12, 110)
# 493 steps taken with West route at (14, 86)
# 494 steps taken with North route at (13, 110)
# 494 steps taken with West route at (13, 86)
# 495 steps taken with North route at (14, 110)
# 495 steps taken with West route at (13, 85)
# 496 steps taken with North route at (15, 110)
# 496 steps taken with West route at (14, 85)
# 497 steps taken with North route at (15, 109)
# 497 steps taken with West route at (15, 85)
# 498 steps taken with North route at (16, 109)
# 498 steps taken with West route at (16, 85)
# 499 steps taken with North route at (16, 110)
# 499 steps taken with West route at (17, 85)
# 500 steps taken with North route at (16, 111)
# 500 steps taken with West route at (18, 85)
# 501 steps taken with North route at (17, 111)
# 501 steps taken with West route at (19, 85)
# 502 steps taken with North route at (17, 110)
# 502 steps taken with West route at (19, 84)
# 503 steps taken with North route at (18, 110)
# 503 steps taken with West route at (19, 83)
# 504 steps taken with North route at (19, 110)
# 504 steps taken with West route at (18, 83)
# 505 steps taken with North route at (19, 109)
# 505 steps taken with West route at (17, 83)
# 506 steps taken with North route at (20, 109)
# 506 steps taken with West route at (17, 84)
# 507 steps taken with North route at (20, 110)
# 507 steps taken with West route at (16, 84)
# 508 steps taken with North route at (21, 110)
# 508 steps taken with West route at (16, 83)
# 509 steps taken with North route at (21, 109)
# 509 steps taken with West route at (15, 83)
# 510 steps taken with North route at (22, 109)
# 510 steps taken with West route at (15, 84)
# 511 steps taken with North route at (22, 110)
# 511 steps taken with West route at (14, 84)
# 512 steps taken with North route at (23, 110)
# 512 steps taken with West route at (14, 83)
# 513 steps taken with North route at (23, 109)
# 513 steps taken with West route at (13, 83)
# 514 steps taken with North route at (24, 109)
# 514 steps taken with West route at (12, 83)
# 515 steps taken with North route at (24, 110)
# 515 steps taken with West route at (12, 84)
# 516 steps taken with North route at (24, 111)
# 516 steps taken with West route at (12, 85)
# 517 steps taken with North route at (23, 111)
# 517 steps taken with West route at (12, 86)
# 518 steps taken with North route at (22, 111)
# 518 steps taken with West route at (11, 86)
# 519 steps taken with North route at (21, 111)
# 519 steps taken with West route at (11, 85)
# 520 steps taken with North route at (20, 111)
# 520 steps taken with West route at (10, 85)
# 521 steps taken with North route at (20, 112)
# 521 steps taken with West route at (9, 85)
# 522 steps taken with North route at (19, 112)
# 522 steps taken with West route at (9, 84)
# 523 steps taken with North route at (19, 111)
# 523 steps taken with West route at (10, 84)
# 524 steps taken with North route at (18, 111)
# 524 steps taken with West route at (11, 84)
# 525 steps taken with North route at (18, 112)
# 525 steps taken with West route at (11, 83)
# 526 steps taken with North route at (17, 112)
# 526 steps taken with West route at (10, 83)
# 527 steps taken with North route at (16, 112)
# 527 steps taken with West route at (9, 83)
# 528 steps taken with North route at (15, 112)
# 528 steps taken with West route at (8, 83)
# 529 steps taken with North route at (15, 111)
# 529 steps taken with West route at (7, 83)
# 530 steps taken with North route at (14, 111)
# 530 steps taken with West route at (7, 82)
# 531 steps taken with North route at (14, 112)
# 531 steps taken with West route at (8, 82)
# 532 steps taken with North route at (13, 112)
# 532 steps taken with West route at (9, 82)
# 533 steps taken with North route at (13, 113)
# 533 steps taken with West route at (10, 82)
# 534 steps taken with North route at (14, 113)
# 534 steps taken with West route at (10, 81)
# 535 steps taken with North route at (14, 114)
# 535 steps taken with West route at (10, 80)
# 536 steps taken with North route at (14, 115)
# 536 steps taken with West route at (9, 80)
# 537 steps taken with North route at (13, 115)
# 537 steps taken with West route at (9, 81)
# 538 steps taken with North route at (13, 116)
# 538 steps taken with West route at (8, 81)
# 539 steps taken with North route at (14, 116)
# 539 steps taken with West route at (7, 81)
# 540 steps taken with North route at (15, 116)
# 540 steps taken with West route at (7, 80)
# 541 steps taken with North route at (15, 115)
# ...
# 6859 steps taken with West route at (126, 16)
# 6860 steps taken with North route at (128, 43)
# 6860 steps taken with West route at (127, 16)
# 6861 steps taken with North route at (128, 44)
# 6861 steps taken with West route at (127, 17)
# 6862 steps taken with North route at (127, 44)
# 6862 steps taken with West route at (127, 18)
# 6863 steps taken with North route at (127, 43)
# 6863 steps taken with West route at (127, 19)
# 6864 steps taken with North route at (127, 42)
# 6864 steps taken with West route at (128, 19)
# 6865 steps taken with North route at (126, 42)
# 6865 steps taken with West route at (128, 20)
# 6866 steps taken with North route at (126, 43)
# 6866 steps taken with West route at (127, 20)
# 6867 steps taken with North route at (125, 43)
# 6867 steps taken with West route at (127, 21)
# 6868 steps taken with North route at (125, 42)
# 6868 steps taken with West route at (127, 22)
# 6869 steps taken with North route at (124, 42)
# 6869 steps taken with West route at (127, 23)
# 6870 steps taken with North route at (123, 42)
# 6870 steps taken with West route at (126, 23)
# 6871 steps taken with North route at (123, 41)
# 6871 steps taken with West route at (125, 23)
# 6872 steps taken with North route at (124, 41)
# 6872 steps taken with West route at (125, 22)
# 6873 steps taken with North route at (125, 41)
# 6873 steps taken with West route at (126, 22)
# 6874 steps taken with North route at (126, 41)
# 6874 steps taken with West route at (126, 21)
# 6875 steps taken with North route at (127, 41)
# 6875 steps taken with West route at (125, 21)
# 6876 steps taken with North route at (127, 40)
# 6876 steps taken with West route at (124, 21)
# 6877 steps taken with North route at (126, 40)
# 6877 steps taken with West route at (124, 22)
# 6878 steps taken with North route at (125, 40)
# 6878 steps taken with West route at (124, 23)
# 6879 steps taken with North route at (124, 40)
# 6879 steps taken with West route at (124, 24)
# 6880 steps taken with North route at (124, 39)
# 6880 steps taken with West route at (125, 24)
# 6881 steps taken with North route at (125, 39)
# 6881 steps taken with West route at (125, 25)
# 6882 steps taken with North route at (126, 39)
# 6882 steps taken with West route at (124, 25)
# 6883 steps taken with North route at (127, 39)
# 6883 steps taken with West route at (124, 26)
# 6884 steps taken with North route at (128, 39)
# 6884 steps taken with West route at (124, 27)
# 6885 steps taken with North route at (128, 40)
# 6885 steps taken with West route at (124, 28)
# 6886 steps taken with North route at (128, 41)
# 6886 steps taken with West route at (125, 28)
# 6887 steps taken with North route at (128, 42)
# 6887 steps taken with West route at (126, 28)
# 6888 steps taken with North route at (129, 42)
# 6888 steps taken with West route at (126, 27)
# 6889 steps taken with North route at (129, 41)
# 6889 steps taken with West route at (125, 27)
# 6890 steps taken with North route at (129, 40)
# 6890 steps taken with West route at (125, 26)
# 6891 steps taken with North route at (130, 40)
# 6891 steps taken with West route at (126, 26)
# 6892 steps taken with North route at (131, 40)
# 6892 steps taken with West route at (126, 25)
# 6893 steps taken with North route at (131, 39)
# 6893 steps taken with West route at (126, 24)
# 6894 steps taken with North route at (130, 39)
# 6894 steps taken with West route at (127, 24)
# 6895 steps taken with North route at (129, 39)
# 6895 steps taken with West route at (127, 25)
# 6896 steps taken with North route at (129, 38)
# 6896 steps taken with West route at (127, 26)
# 6897 steps taken with North route at (129, 37)
# 6897 steps taken with West route at (127, 27)
# 6898 steps taken with North route at (128, 37)
# 6898 steps taken with West route at (127, 28)
# 6899 steps taken with North route at (128, 38)
# 6899 steps taken with West route at (127, 29)
# 6900 steps taken with North route at (127, 38)
# 6900 steps taken with West route at (126, 29)
# 6901 steps taken with North route at (127, 37)
# 6901 steps taken with West route at (125, 29)
# 6902 steps taken with North route at (126, 37)
# 6902 steps taken with West route at (124, 29)
# 6903 steps taken with North route at (126, 38)
# 6903 steps taken with West route at (123, 29)
# 6904 steps taken with North route at (125, 38)
# 6904 steps taken with West route at (122, 29)
# 6905 steps taken with North route at (124, 38)
# 6905 steps taken with West route at (121, 29)
# 6906 steps taken with North route at (123, 38)
# 6906 steps taken with West route at (121, 30)
# 6907 steps taken with North route at (122, 38)
# 6907 steps taken with West route at (120, 30)
# 6908 steps taken with North route at (122, 39)
# 6908 steps taken with West route at (120, 31)
# 6909 steps taken with North route at (123, 39)
# 6909 steps taken with West route at (121, 31)
# 6910 steps taken with North route at (123, 40)
# 6910 steps taken with West route at (122, 31)
# 6911 steps taken with North route at (122, 40)
# 6911 steps taken with West route at (123, 31)
# 6912 steps taken with North route at (122, 41)
# 6912 steps taken with West route at (123, 30)
# 6913 steps taken with North route at (121, 41)
# 6913 steps taken with West route at (124, 30)
# 6914 steps taken with North route at (121, 40)
# 6914 steps taken with West route at (124, 31)
# 6915 steps taken with North route at (121, 39)
# 6915 steps taken with West route at (125, 31)
# 6916 steps taken with North route at (120, 39)
# 6916 steps taken with West route at (126, 31)
# 6917 steps taken with North route at (120, 40)
# 6917 steps taken with West route at (126, 30)
# 6918 steps taken with North route at (120, 41)
# 6918 steps taken with West route at (127, 30)
# 6919 steps taken with North route at (119, 41)
# 6919 steps taken with West route at (127, 31)
# 6920 steps taken with North route at (118, 41)
# 6920 steps taken with West route at (128, 31)
# 6921 steps taken with North route at (117, 41)
# 6921 steps taken with West route at (128, 30)
# 6922 steps taken with North route at (116, 41)
# 6922 steps taken with West route at (128, 29)
# 6923 steps taken with North route at (115, 41)
# 6923 steps taken with West route at (128, 28)
# 6924 steps taken with North route at (114, 41)
# 6924 steps taken with West route at (128, 27)
# 6925 steps taken with North route at (113, 41)
# 6925 steps taken with West route at (128, 26)
# 6926 steps taken with North route at (113, 40)
# 6926 steps taken with West route at (128, 25)
# 6927 steps taken with North route at (114, 40)
# 6927 steps taken with West route at (128, 24)
# 6928 steps taken with North route at (114, 39)
# 6928 steps taken with West route at (129, 24)
# 6929 steps taken with North route at (115, 39)
# 6929 steps taken with West route at (129, 25)
# 6930 steps taken with North route at (115, 40)
# 6930 steps taken with West route at (129, 26)
# 6931 steps taken with North route at (116, 40)
# 6931 steps taken with West route at (129, 27)
# 6932 steps taken with North route at (117, 40)
# 6932 steps taken with West route at (129, 28)
# 6933 steps taken with North route at (118, 40)
# 6933 steps taken with West route at (129, 29)
# 6934 steps taken with North route at (119, 40)
# 6934 steps taken with West route at (130, 29)
# 6935 steps taken with North route at (119, 39)
# 6935 steps taken with West route at (130, 28)
# 6936 steps taken with North route at (118, 39)
# 6936 steps taken with West route at (130, 27)
# 6937 steps taken with North route at (117, 39)
# 6937 steps taken with West route at (130, 26)
# 6938 steps taken with North route at (116, 39)
# 6938 steps taken with West route at (130, 25)
# 6939 steps taken with North route at (116, 38)
# 6939 steps taken with West route at (130, 24)
# 6940 steps taken with North route at (117, 38)
# 6940 steps taken with West route at (131, 24)
# 6941 steps taken with North route at (118, 38)
# 6941 steps taken with West route at (131, 25)
# 6942 steps taken with North route at (119, 38)
# 6942 steps taken with West route at (131, 26)
# 6943 steps taken with North route at (120, 38)
# 6943 steps taken with West route at (132, 26)
# 6944 steps taken with North route at (121, 38)
# 6944 steps taken with West route at (132, 27)
# 6945 steps taken with North route at (121, 37)
# 6945 steps taken with West route at (131, 27)
# 6946 steps taken with North route at (120, 37)
# 6946 steps taken with West route at (131, 28)
# 6947 steps taken with North route at (120, 36)
# 6947 steps taken with West route at (131, 29)
# 6948 steps taken with North route at (119, 36)
# 6948 steps taken with West route at (132, 29)
# 6949 steps taken with North route at (119, 37)
# 6949 steps taken with West route at (132, 28)
# 6950 steps taken with North route at (118, 37)
# 6950 steps taken with West route at (133, 28)
# 6951 steps taken with North route at (117, 37)
# 6951 steps taken with West route at (133, 29)
# 6952 steps taken with North route at (116, 37)
# 6952 steps taken with West route at (134, 29)
# 6953 steps taken with North route at (115, 37)
# 6953 steps taken with West route at (135, 29)
# 6954 steps taken with North route at (115, 38)
# 6954 steps taken with West route at (135, 28)
# 6955 steps taken with North route at (114, 38)
# 6955 steps taken with West route at (135, 27)
# 6956 steps taken with North route at (114, 37)
# 6956 steps taken with West route at (135, 26)
# 6957 steps taken with North route at (114, 36)
# 6957 steps taken with West route at (135, 25)
# 6958 steps taken with North route at (115, 36)
# 6958 steps taken with West route at (136, 25)
# 6959 steps taken with North route at (116, 36)
# 6959 steps taken with West route at (136, 26)
# 6960 steps taken with North route at (117, 36)
# 6960 steps taken with West route at (136, 27)
# 6961 steps taken with North route at (117, 35)
# 6961 steps taken with West route at (136, 28)
# 6962 steps taken with North route at (118, 35)
# 6962 steps taken with West route at (136, 29)
# 6963 steps taken with North route at (119, 35)
# 6963 steps taken with West route at (137, 29)
# 6964 steps taken with North route at (120, 35)
# 6964 steps taken with West route at (137, 28)
# 6965 steps taken with North route at (121, 35)
# 6965 steps taken with West route at (137, 27)
# 6966 steps taken with North route at (121, 36)
# 6966 steps taken with West route at (138, 27)
# 6967 steps taken with North route at (122, 36)
# 6967 steps taken with West route at (138, 28)
# 6968 steps taken with North route at (122, 37)
# 6968 steps taken with West route at (138, 29)
# 6969 steps taken with North route at (123, 37)
# 6969 steps taken with West route at (138, 30)
# 6970 steps taken with North route at (123, 36)
# 6970 steps taken with West route at (137, 30)
# 6971 steps taken with North route at (124, 36)
# 6971 steps taken with West route at (137, 31)
# 6972 steps taken with North route at (124, 37)
# 6972 steps taken with West route at (137, 32)
# 6973 steps taken with North route at (125, 37)
# 6973 steps taken with West route at (136, 32)
# 6974 steps taken with North route at (125, 36)
# 6974 steps taken with West route at (135, 32)
# 6975 steps taken with North route at (126, 36)
# 6975 steps taken with West route at (135, 31)
# 6976 steps taken with North route at (127, 36)
# 6976 steps taken with West route at (136, 31)
# 6977 steps taken with North route at (128, 36)
# 6977 steps taken with West route at (136, 30)
# 6978 steps taken with North route at (129, 36)
# 6978 steps taken with West route at (135, 30)
# 6979 steps taken with North route at (129, 35)
# 6979 steps taken with West route at (134, 30)
# 6980 steps taken with North route at (128, 35)
# 6980 steps taken with West route at (134, 31)
# 6981 steps taken with North route at (127, 35)
# 6981 steps taken with West route at (134, 32)
# 6982 steps taken with North route at (126, 35)
# 6982 steps taken with West route at (133, 32)
# 6983 steps taken with North route at (125, 35)
# 6983 steps taken with West route at (133, 31)
# 6984 steps taken with North route at (125, 34)
# 6984 steps taken with West route at (133, 30)
# 6985 steps taken with North route at (124, 34)
# 6985 steps taken with West route at (132, 30)
# 6986 steps taken with North route at (124, 35)
# 6986 steps taken with West route at (131, 30)
# 6987 steps taken with North route at (123, 35)
# 6987 steps taken with West route at (131, 31)
# 6988 steps taken with North route at (122, 35)
# 6988 steps taken with West route at (130, 31)
# 6989 steps taken with North route at (122, 34)
# 6989 steps taken with West route at (130, 30)
# 6990 steps taken with North route at (121, 34)
# 6990 steps taken with West route at (129, 30)
# 6991 steps taken with North route at (121, 33)
# 6991 steps taken with West route at (129, 31)
# 6992 steps taken with North route at (120, 33)
# 6992 steps taken with West route at (129, 32)
# 6993 steps taken with North route at (120, 34)
# 6993 steps taken with West route at (128, 32)
# 6994 steps taken with North route at (119, 34)
# 6994 steps taken with West route at (127, 32)
# 6995 steps taken with North route at (118, 34)
# 6995 steps taken with West route at (127, 33)
# 6996 steps taken with North route at (117, 34)
# 6996 steps taken with West route at (128, 33)
# 6997 steps taken with North route at (117, 33)
# 6997 steps taken with West route at (129, 33)
# 6998 steps taken with North route at (118, 33)
# 6998 steps taken with West route at (130, 33)
# 6999 steps taken with North route at (119, 33)
# 6999 steps taken with West route at (131, 33)
# 7000 steps taken with North route at (119, 32)
# 7000 steps taken with West route at (131, 32)
# 7001 steps taken with North route at (120, 32)
# 7001 steps taken with West route at (132, 32)
# 7002 steps taken with North route at (121, 32)
# 7002 steps taken with West route at (132, 33)
# 7003 steps taken with North route at (122, 32)
# 7003 steps taken with West route at (133, 33)
# 7004 steps taken with North route at (122, 33)
# 7004 steps taken with West route at (133, 34)
# 7005 steps taken with North route at (123, 33)
# 7005 steps taken with West route at (134, 34)
# 7006 steps taken with North route at (123, 32)
# 7006 steps taken with West route at (134, 35)
# 7007 steps taken with North route at (124, 32)
# 7007 steps taken with West route at (133, 35)
# 7008 steps taken with North route at (124, 33)
# 7008 steps taken with West route at (133, 36)
# 7009 steps taken with North route at (125, 33)
# 7009 steps taken with West route at (134, 36)
# 7010 steps taken with North route at (125, 32)
# 7010 steps taken with West route at (135, 36)
# 7011 steps taken with North route at (126, 32)
# 7011 steps taken with West route at (135, 37)
# 7012 steps taken with North route at (126, 33)
# 7012 steps taken with West route at (134, 37)
# 7013 steps taken with North route at (126, 34)
# 7013 steps taken with West route at (134, 38)
# 7014 steps taken with North route at (127, 34)
# 7014 steps taken with West route at (135, 38)
# 7015 steps taken with North route at (128, 34)
# 7015 steps taken with West route at (136, 38)
# 7016 steps taken with North route at (129, 34)
# 7016 steps taken with West route at (136, 37)
# 7017 steps taken with North route at (130, 34)
# 7017 steps taken with West route at (137, 37)
# 7018 steps taken with North route at (130, 35)
# 7018 steps taken with West route at (137, 38)
# 7019 steps taken with North route at (130, 36)
# 7019 steps taken with West route at (137, 39)
# 7020 steps taken with North route at (130, 37)
# 7020 steps taken with West route at (137, 40)
# 7021 steps taken with North route at (131, 37)
# 7021 steps taken with West route at (136, 40)
# 7022 steps taken with North route at (131, 36)
# 7022 steps taken with West route at (136, 39)
# 7023 steps taken with North route at (131, 35)
# 7023 steps taken with West route at (135, 39)
# 7024 steps taken with North route at (131, 34)
# 7024 steps taken with West route at (134, 39)
# 7025 steps taken with North route at (132, 34)
# 7025 steps taken with West route at (134, 40)
# 7026 steps taken with North route at (132, 35)
# 7026 steps taken with West route at (133, 40)
# 7027 steps taken with North route at (132, 36)
# 7027 steps taken with West route at (133, 39)
# 7028 steps taken with North route at (132, 37)
# 7028 steps taken with West route at (132, 39)
# 7029 steps taken with North route at (133, 37)
# 7029 steps taken with West route at (132, 38)
# 7030 steps taken with North route at (133, 38)
# Finished in 7030 steps
# 7030 steps taken with West route at (133, 38)

# %%
route_dicts['North'][-4:]
# Out:
# [(132, 36), (132, 37), (133, 37), (133, 38)]

# %%
route_dicts['West'][-4:]
# Out:
# [(133, 39), (132, 39), (132, 38), (133, 38)]

# %%
"""pipe_locations = route_dicts['North'] + route_dicts['West']
outcome_dict = {}

for row, dict in enumerate(data_dict.values()):
    for col, list in enumerate(dict):
        if (row, col) in pipe_locations:
            outcome = "Pipe"
        else:
            above = [row-1, col]
            above_complete = False
            below = [row+1, col]
            below_complete = False
            right = [row, col+1]
            right_complete = False
            left = [row, col-1]
            left_complete = False
            outcome = "Inside"

            while above_complete == False:
                if tuple(above) in pipe_locations:
                    above_complete = True
                    #print("Pipe Above")
                elif above[0] <= 0:
                    above_complete = True
                    outcome = "Outside"
                else:
                    above[0] -= 1
            while below_complete == False:
                if tuple(below) in pipe_locations:
                    below_complete = True
                    #print("Pipe Below")
                elif below[0] >= len(data_dict):
                    below_complete = True
                    outcome = "Outside"
                else:
                    below[0] += 1
            while right_complete == False:
                if tuple(right) in pipe_locations:
                    right_complete = True
                    #print("Pipe Right")
                elif right[1] >= len(data_dict[0]):
                    right_complete = True
                    outcome = "Outside"
                else:
                    right[1] += 1
            while left_complete == False:
                if tuple(left) in pipe_locations:
                    left_complete = True
                    #print("Pipe Left")
                elif left[1] <= 0:
                    left_complete = True
                    outcome = "Outside"
                else:
                    left[1] -= 1

        print(f"Space at row {row}, column {col} is defined as {outcome}")
        outcome_dict[(row, col)] = outcome"""
# Out:
# 'pipe_locations = route_dicts[\'North\'] + route_dicts[\'West\']\noutcome_dict = {}\n\nfor row, dict in enumerate(data_dict.values()):\n    for col, list in enumerate(dict):\n        if (row, col) in pipe_locations:\n            outcome = "Pipe"\n        else:\n            above = [row-1, col]\n            above_complete = False\n            below = [row+1, col]\n            below_complete = False\n            right = [row, col+1]\n            right_complete = False\n            left = [row, col-1]\n            left_complete = False\n            outcome = "Inside"\n\n            while above_complete == False:\n                if tuple(above) in pipe_locations:\n                    above_complete = True\n                    #print("Pipe Above")\n                elif above[0] <= 0:\n                    above_complete = True\n                    outcome = "Outside"\n                else:\n                    above[0] -= 1\n            while below_complete == False:\n                if tuple(below) in pipe_locations:\n                    below_complete = True\n                    #print("Pipe Below")\n                elif below[0] >= len(data_dict):\n                    below_complete = True\n                    outcome = "Outside"\n                else:\n                    below[0] += 1\n            while right_complete == False:\n                if tuple(right) in pipe_locations:\n                    right_complete = True\n                    #print("Pipe Right")\n                elif right[1] >= len(data_dict[0]):\n                    right_complete = True\n                    outcome = "Outside"\n                else:\n                    right[1] += 1\n            while left_complete == False:\n                if tuple(left) in pipe_locations:\n                    left_complete = True\n                    #print("Pipe Left")\n                elif left[1] <= 0:\n                    left_complete = True\n                    outcome = "Outside"\n                else:\n                    left[1] -= 1\n\n        print(f"Space at row {row}, column {col} is defined as {outcome}")\n        outcome_dict[(row, col)] = outcome'

# %%
from collections import Counter
#Counter(outcome_dict.values())

# %%
def spread_outside(row, col, outcome_dict):
    above = [row-1, col]
    below = [row+1, col]
    right = [row, col+1]
    left = [row, col-1]
    
    for dir in [above, below, right, left]:
        if (dir[0] >= 0) & (dir[1] >= 0) & (dir[0]<= 139) & (dir[1]<=139):
            if tuple(dir) not in outcome_dict:
                outcome_dict[tuple(dir)] = "Outside"
                print(f"Spreading from {row}, {col} to {dir[0]},{dir[1]} ")
                outcome_dict = spread_outside(dir[0], dir[1], outcome_dict)

    return outcome_dict

# %%
import sys
print(sys.getrecursionlimit())
#sys.setrecursionlimit(15000)
print(sys.getrecursionlimit())
# Out:
# 3000
# 3000

# %%
pipe_locations = route_dicts['North'] + route_dicts['West']
outcome_dict = {}

for row, dict in enumerate(data_dict.values()):
    for col, list in enumerate(dict):
        if (row == 0) | (row == len(data_dict)-1) | (col == 0) | (col == len(data_dict)-1):
            if (row, col) not in pipe_locations:
                outcome_dict[(row, col)] = "Outside"
            else:
                pass
        else:
            pass
for pipe in pipe_locations:
    outcome_dict[pipe] = "Pipe"

# %%
from collections import Counter
Counter(outcome_dict.values())
# Out:
# Counter({'Outside': 552, 'Pipe': 14059})

# %%
for attempt in range(10):
    print(f"Attempt number {attempt+1}")
    for i in range(138):
        for row, dict in enumerate(data_dict.values()):
            for col, list in enumerate(dict):
                if (row == i+1):
                    above = [row-1, col]
                    below = [row+1, col]
                    right = [row, col+1]
                    left = [row, col-1]
                    if (outcome_dict.get((row, col)) != "Outside")  & (outcome_dict.get((row, col)) != "Pipe"):     
                        if (outcome_dict.get(tuple(above)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {above}")
                        elif (outcome_dict.get(tuple(below)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {below}")
                        elif (outcome_dict.get(tuple(right)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {right}")
                        elif (outcome_dict.get(tuple(left)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {left}")
                        else:
                            outcome = "Inside"
                            print(f"{row}, {col} is assigned {outcome}")
                        outcome_dict[(row, col)] = outcome
    for i in range(138):
        for row, dict in enumerate(data_dict.values()):
            for col, list in enumerate(dict):
                if (col == i):
                    above = [row-1, col]
                    below = [row+1, col]
                    right = [row, col+1]
                    left = [row, col-1]
                    if (outcome_dict.get((row, col)) != "Outside")  & (outcome_dict.get((row, col)) != "Pipe"):              
                        if (outcome_dict.get(tuple(above)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {above}")
                        elif (outcome_dict.get(tuple(below)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {below}")
                        elif (outcome_dict.get(tuple(right)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {right}")
                        elif (outcome_dict.get(tuple(left)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {left}")
                        else:
                            outcome = "Inside"
                            print(f"{row}, {col} is assigned {outcome}")
                        outcome_dict[(row, col)] = outcome
    for i in range(138):
        for row, dict in enumerate(data_dict.values()):
            for col, list in enumerate(dict):
                if (row == len(data_dict)-i-2):
                    above = [row-1, col]
                    below = [row+1, col]
                    right = [row, col+1]
                    left = [row, col-1]
                    if (outcome_dict.get((row, col)) != "Outside")  & (outcome_dict.get((row, col)) != "Pipe"):
                        if (outcome_dict.get(tuple(above)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {above}")
                        elif (outcome_dict.get(tuple(below)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {below}")
                        elif (outcome_dict.get(tuple(right)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {right}")
                        elif (outcome_dict.get(tuple(left)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {left}")
                        else:
                            outcome = "Inside"
                            print(f"{row}, {col} is assigned {outcome}")
                        outcome_dict[(row, col)] = outcome
    for i in range(138):
        for row, dict in enumerate(data_dict.values()):
            for col, list in enumerate(dict):
                if (col == len(data_dict)-i-2):
                    above = [row-1, col]
                    below = [row+1, col]
                    right = [row, col+1]
                    left = [row, col-1]
                    #print(above)
                    #print(above not in outcome_dict)

                    if (outcome_dict.get((row, col)) != "Outside")  & (outcome_dict.get((row, col)) != "Pipe"):
                        if (outcome_dict.get(tuple(above)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {above}")
                        elif (outcome_dict.get(tuple(below)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {below}")
                        elif (outcome_dict.get(tuple(right)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {right}")
                        elif (outcome_dict.get(tuple(left)) == "Outside"):
                            outcome = "Outside"
                            print(f"{row}, {col} is assigned {outcome} based on {left}")
                        else:
                            outcome = "Inside"
                            print(f"{row}, {col} is assigned {outcome}")
                        outcome_dict[(row, col)] = outcome
# Out:
# Attempt number 1
# 1, 1 is assigned Outside based on [0, 1]
# 1, 2 is assigned Outside based on [0, 2]
# 1, 3 is assigned Outside based on [0, 3]
# 1, 4 is assigned Outside based on [0, 4]
# 1, 5 is assigned Outside based on [0, 5]
# 1, 6 is assigned Outside based on [0, 6]
# 1, 7 is assigned Outside based on [0, 7]
# 1, 8 is assigned Outside based on [0, 8]
# 1, 9 is assigned Outside based on [0, 9]
# 1, 10 is assigned Outside based on [0, 10]
# 1, 11 is assigned Outside based on [0, 11]
# 1, 12 is assigned Outside based on [0, 12]
# 1, 13 is assigned Outside based on [0, 13]
# 1, 14 is assigned Outside based on [0, 14]
# 1, 15 is assigned Outside based on [0, 15]
# 1, 16 is assigned Outside based on [0, 16]
# 1, 17 is assigned Outside based on [0, 17]
# 1, 18 is assigned Outside based on [0, 18]
# 1, 19 is assigned Outside based on [0, 19]
# 1, 20 is assigned Outside based on [0, 20]
# 1, 21 is assigned Outside based on [0, 21]
# 1, 22 is assigned Outside based on [0, 22]
# 1, 23 is assigned Outside based on [0, 23]
# 1, 24 is assigned Outside based on [0, 24]
# 1, 25 is assigned Outside based on [0, 25]
# 1, 26 is assigned Outside based on [0, 26]
# 1, 27 is assigned Outside based on [0, 27]
# 1, 28 is assigned Outside based on [0, 28]
# 1, 29 is assigned Outside based on [0, 29]
# 1, 30 is assigned Outside based on [0, 30]
# 1, 31 is assigned Outside based on [0, 31]
# 1, 32 is assigned Outside based on [0, 32]
# 1, 33 is assigned Outside based on [0, 33]
# 1, 34 is assigned Outside based on [0, 34]
# 1, 35 is assigned Outside based on [0, 35]
# 1, 36 is assigned Outside based on [0, 36]
# 1, 37 is assigned Outside based on [0, 37]
# 1, 38 is assigned Outside based on [0, 38]
# 1, 39 is assigned Outside based on [0, 39]
# 1, 40 is assigned Outside based on [0, 40]
# 1, 41 is assigned Outside based on [0, 41]
# 1, 42 is assigned Outside based on [0, 42]
# 1, 43 is assigned Outside based on [0, 43]
# 1, 44 is assigned Outside based on [0, 44]
# 1, 45 is assigned Outside based on [0, 45]
# 1, 46 is assigned Outside based on [0, 46]
# 1, 47 is assigned Outside based on [0, 47]
# 1, 48 is assigned Outside based on [0, 48]
# 1, 49 is assigned Outside based on [0, 49]
# 1, 50 is assigned Outside based on [0, 50]
# 1, 51 is assigned Outside based on [0, 51]
# 1, 52 is assigned Outside based on [0, 52]
# 1, 53 is assigned Outside based on [0, 53]
# 1, 54 is assigned Outside based on [0, 54]
# 1, 55 is assigned Outside based on [0, 55]
# 1, 56 is assigned Outside based on [0, 56]
# 1, 57 is assigned Outside based on [0, 57]
# 1, 58 is assigned Outside based on [0, 58]
# 1, 59 is assigned Outside based on [0, 59]
# 1, 60 is assigned Outside based on [0, 60]
# 1, 61 is assigned Outside based on [0, 61]
# 1, 62 is assigned Outside based on [0, 62]
# 1, 63 is assigned Outside based on [0, 63]
# 1, 64 is assigned Outside based on [0, 64]
# 1, 65 is assigned Outside based on [0, 65]
# 1, 66 is assigned Outside based on [0, 66]
# 1, 67 is assigned Outside based on [0, 67]
# 1, 68 is assigned Outside based on [0, 68]
# 1, 69 is assigned Outside based on [0, 69]
# 1, 70 is assigned Outside based on [0, 70]
# 1, 71 is assigned Outside based on [0, 71]
# 1, 72 is assigned Outside based on [0, 72]
# 1, 73 is assigned Outside based on [0, 73]
# 1, 74 is assigned Outside based on [0, 74]
# 1, 75 is assigned Outside based on [0, 75]
# 1, 76 is assigned Outside based on [0, 76]
# 1, 77 is assigned Outside based on [0, 77]
# 1, 78 is assigned Outside based on [0, 78]
# 1, 79 is assigned Outside based on [0, 79]
# 1, 80 is assigned Outside based on [0, 80]
# 1, 81 is assigned Outside based on [0, 81]
# 1, 82 is assigned Outside based on [0, 82]
# 1, 83 is assigned Outside based on [0, 83]
# 1, 84 is assigned Outside based on [0, 84]
# 1, 85 is assigned Outside based on [0, 85]
# 1, 86 is assigned Outside based on [0, 86]
# 1, 87 is assigned Outside based on [0, 87]
# 1, 88 is assigned Outside based on [0, 88]
# 1, 89 is assigned Outside based on [0, 89]
# 1, 90 is assigned Outside based on [0, 90]
# 1, 91 is assigned Outside based on [0, 91]
# 1, 92 is assigned Outside based on [0, 92]
# 1, 93 is assigned Outside based on [0, 93]
# 1, 94 is assigned Outside based on [0, 94]
# 1, 95 is assigned Outside based on [0, 95]
# 1, 96 is assigned Outside based on [0, 96]
# 1, 97 is assigned Outside based on [0, 97]
# 1, 98 is assigned Outside based on [0, 98]
# 1, 99 is assigned Outside based on [0, 99]
# 1, 100 is assigned Outside based on [0, 100]
# 1, 101 is assigned Outside based on [0, 101]
# 1, 102 is assigned Outside based on [0, 102]
# 1, 103 is assigned Outside based on [0, 103]
# 1, 104 is assigned Outside based on [0, 104]
# 1, 105 is assigned Outside based on [0, 105]
# 1, 106 is assigned Outside based on [0, 106]
# 1, 107 is assigned Outside based on [0, 107]
# 1, 108 is assigned Outside based on [0, 108]
# 1, 109 is assigned Outside based on [0, 109]
# 1, 110 is assigned Outside based on [0, 110]
# 1, 111 is assigned Outside based on [0, 111]
# 1, 112 is assigned Outside based on [0, 112]
# 1, 113 is assigned Outside based on [0, 113]
# 1, 114 is assigned Outside based on [0, 114]
# 1, 115 is assigned Outside based on [0, 115]
# 1, 116 is assigned Outside based on [0, 116]
# 1, 117 is assigned Outside based on [0, 117]
# 1, 118 is assigned Outside based on [0, 118]
# 1, 119 is assigned Outside based on [0, 119]
# 1, 120 is assigned Outside based on [0, 120]
# 1, 121 is assigned Outside based on [0, 121]
# 1, 122 is assigned Outside based on [0, 122]
# 1, 123 is assigned Outside based on [0, 123]
# 1, 124 is assigned Outside based on [0, 124]
# 1, 125 is assigned Outside based on [0, 125]
# 1, 126 is assigned Outside based on [0, 126]
# 1, 127 is assigned Outside based on [0, 127]
# 1, 128 is assigned Outside based on [0, 128]
# 1, 129 is assigned Outside based on [0, 129]
# 1, 130 is assigned Outside based on [0, 130]
# 1, 131 is assigned Outside based on [0, 131]
# 1, 132 is assigned Outside based on [0, 132]
# 1, 133 is assigned Outside based on [0, 133]
# 1, 134 is assigned Outside based on [0, 134]
# 1, 135 is assigned Outside based on [0, 135]
# 1, 136 is assigned Outside based on [0, 136]
# 1, 137 is assigned Outside based on [0, 137]
# 1, 138 is assigned Outside based on [0, 138]
# 2, 1 is assigned Outside based on [1, 1]
# 2, 2 is assigned Outside based on [1, 2]
# 2, 3 is assigned Outside based on [1, 3]
# 2, 4 is assigned Outside based on [1, 4]
# 2, 5 is assigned Outside based on [1, 5]
# 2, 6 is assigned Outside based on [1, 6]
# 2, 7 is assigned Outside based on [1, 7]
# 2, 8 is assigned Outside based on [1, 8]
# 2, 9 is assigned Outside based on [1, 9]
# 2, 10 is assigned Outside based on [1, 10]
# 2, 11 is assigned Outside based on [1, 11]
# 2, 12 is assigned Outside based on [1, 12]
# 2, 13 is assigned Outside based on [1, 13]
# 2, 14 is assigned Outside based on [1, 14]
# 2, 15 is assigned Outside based on [1, 15]
# 2, 16 is assigned Outside based on [1, 16]
# 2, 17 is assigned Outside based on [1, 17]
# 2, 18 is assigned Outside based on [1, 18]
# 2, 19 is assigned Outside based on [1, 19]
# 2, 20 is assigned Outside based on [1, 20]
# 2, 21 is assigned Outside based on [1, 21]
# 2, 22 is assigned Outside based on [1, 22]
# 2, 23 is assigned Outside based on [1, 23]
# 2, 24 is assigned Outside based on [1, 24]
# 2, 25 is assigned Outside based on [1, 25]
# 2, 26 is assigned Outside based on [1, 26]
# 2, 27 is assigned Outside based on [1, 27]
# 2, 28 is assigned Outside based on [1, 28]
# 2, 29 is assigned Outside based on [1, 29]
# 2, 30 is assigned Outside based on [1, 30]
# 2, 31 is assigned Outside based on [1, 31]
# 2, 32 is assigned Outside based on [1, 32]
# 2, 33 is assigned Outside based on [1, 33]
# 2, 34 is assigned Outside based on [1, 34]
# 2, 35 is assigned Outside based on [1, 35]
# 2, 36 is assigned Outside based on [1, 36]
# 2, 37 is assigned Outside based on [1, 37]
# 2, 38 is assigned Outside based on [1, 38]
# 2, 39 is assigned Outside based on [1, 39]
# 2, 40 is assigned Outside based on [1, 40]
# 2, 41 is assigned Outside based on [1, 41]
# 2, 42 is assigned Outside based on [1, 42]
# 2, 43 is assigned Outside based on [1, 43]
# 2, 44 is assigned Outside based on [1, 44]
# 2, 45 is assigned Outside based on [1, 45]
# 2, 46 is assigned Outside based on [1, 46]
# 2, 47 is assigned Outside based on [1, 47]
# 2, 48 is assigned Outside based on [1, 48]
# 2, 49 is assigned Outside based on [1, 49]
# 2, 50 is assigned Outside based on [1, 50]
# 2, 51 is assigned Outside based on [1, 51]
# 2, 52 is assigned Outside based on [1, 52]
# 2, 53 is assigned Outside based on [1, 53]
# 2, 54 is assigned Outside based on [1, 54]
# 2, 55 is assigned Outside based on [1, 55]
# 2, 56 is assigned Outside based on [1, 56]
# 2, 57 is assigned Outside based on [1, 57]
# 2, 58 is assigned Outside based on [1, 58]
# 2, 59 is assigned Outside based on [1, 59]
# 2, 60 is assigned Outside based on [1, 60]
# 2, 61 is assigned Outside based on [1, 61]
# 2, 62 is assigned Outside based on [1, 62]
# 2, 63 is assigned Outside based on [1, 63]
# 2, 64 is assigned Outside based on [1, 64]
# 2, 65 is assigned Outside based on [1, 65]
# 2, 66 is assigned Outside based on [1, 66]
# 2, 67 is assigned Outside based on [1, 67]
# 2, 68 is assigned Outside based on [1, 68]
# 2, 69 is assigned Outside based on [1, 69]
# 2, 70 is assigned Outside based on [1, 70]
# 2, 71 is assigned Outside based on [1, 71]
# 2, 72 is assigned Outside based on [1, 72]
# 2, 73 is assigned Outside based on [1, 73]
# 2, 74 is assigned Outside based on [1, 74]
# 2, 75 is assigned Outside based on [1, 75]
# 2, 76 is assigned Outside based on [1, 76]
# 2, 77 is assigned Outside based on [1, 77]
# 2, 78 is assigned Outside based on [1, 78]
# 2, 79 is assigned Outside based on [1, 79]
# 2, 80 is assigned Outside based on [1, 80]
# 2, 81 is assigned Outside based on [1, 81]
# 2, 82 is assigned Outside based on [1, 82]
# 2, 83 is assigned Outside based on [1, 83]
# 2, 84 is assigned Outside based on [1, 84]
# 2, 85 is assigned Outside based on [1, 85]
# 2, 86 is assigned Outside based on [1, 86]
# 2, 87 is assigned Outside based on [1, 87]
# 2, 88 is assigned Outside based on [1, 88]
# 2, 89 is assigned Outside based on [1, 89]
# 2, 90 is assigned Outside based on [1, 90]
# 2, 91 is assigned Outside based on [1, 91]
# 2, 94 is assigned Outside based on [1, 94]
# 2, 95 is assigned Outside based on [1, 95]
# 2, 96 is assigned Outside based on [1, 96]
# 2, 97 is assigned Outside based on [1, 97]
# 2, 98 is assigned Outside based on [1, 98]
# 2, 99 is assigned Outside based on [1, 99]
# 2, 100 is assigned Outside based on [1, 100]
# 2, 101 is assigned Outside based on [1, 101]
# 2, 102 is assigned Outside based on [1, 102]
# 2, 103 is assigned Outside based on [1, 103]
# 2, 104 is assigned Outside based on [1, 104]
# 2, 105 is assigned Outside based on [1, 105]
# 2, 106 is assigned Outside based on [1, 106]
# 2, 107 is assigned Outside based on [1, 107]
# 2, 108 is assigned Outside based on [1, 108]
# 2, 109 is assigned Outside based on [1, 109]
# 2, 110 is assigned Outside based on [1, 110]
# 2, 111 is assigned Outside based on [1, 111]
# 2, 112 is assigned Outside based on [1, 112]
# 2, 113 is assigned Outside based on [1, 113]
# 2, 114 is assigned Outside based on [1, 114]
# 2, 115 is assigned Outside based on [1, 115]
# 2, 116 is assigned Outside based on [1, 116]
# 2, 117 is assigned Outside based on [1, 117]
# 2, 118 is assigned Outside based on [1, 118]
# 2, 119 is assigned Outside based on [1, 119]
# 2, 120 is assigned Outside based on [1, 120]
# 2, 121 is assigned Outside based on [1, 121]
# 2, 122 is assigned Outside based on [1, 122]
# 2, 123 is assigned Outside based on [1, 123]
# 2, 124 is assigned Outside based on [1, 124]
# 2, 125 is assigned Outside based on [1, 125]
# 2, 126 is assigned Outside based on [1, 126]
# 2, 127 is assigned Outside based on [1, 127]
# 2, 128 is assigned Outside based on [1, 128]
# 2, 129 is assigned Outside based on [1, 129]
# 2, 130 is assigned Outside based on [1, 130]
# 2, 131 is assigned Outside based on [1, 131]
# 2, 132 is assigned Outside based on [1, 132]
# 2, 133 is assigned Outside based on [1, 133]
# 2, 134 is assigned Outside based on [1, 134]
# 2, 135 is assigned Outside based on [1, 135]
# 2, 136 is assigned Outside based on [1, 136]
# 2, 137 is assigned Outside based on [1, 137]
# 2, 138 is assigned Outside based on [1, 138]
# 3, 1 is assigned Outside based on [2, 1]
# 3, 2 is assigned Outside based on [2, 2]
# 3, 3 is assigned Outside based on [2, 3]
# 3, 4 is assigned Outside based on [2, 4]
# 3, 5 is assigned Outside based on [2, 5]
# 3, 6 is assigned Outside based on [2, 6]
# 3, 7 is assigned Outside based on [2, 7]
# 3, 8 is assigned Outside based on [2, 8]
# 3, 9 is assigned Outside based on [2, 9]
# 3, 10 is assigned Outside based on [2, 10]
# 3, 11 is assigned Outside based on [2, 11]
# 3, 12 is assigned Outside based on [2, 12]
# 3, 13 is assigned Outside based on [2, 13]
# 3, 14 is assigned Outside based on [2, 14]
# 3, 15 is assigned Outside based on [2, 15]
# 3, 16 is assigned Outside based on [2, 16]
# 3, 17 is assigned Outside based on [2, 17]
# 3, 18 is assigned Outside based on [2, 18]
# 3, 19 is assigned Outside based on [2, 19]
# 3, 20 is assigned Outside based on [2, 20]
# 3, 21 is assigned Outside based on [2, 21]
# 3, 22 is assigned Outside based on [2, 22]
# 3, 25 is assigned Outside based on [2, 25]
# 3, 26 is assigned Outside based on [2, 26]
# 3, 27 is assigned Outside based on [2, 27]
# 3, 28 is assigned Outside based on [2, 28]
# 3, 29 is assigned Outside based on [2, 29]
# 3, 30 is assigned Outside based on [2, 30]
# 3, 31 is assigned Outside based on [2, 31]
# 3, 32 is assigned Outside based on [2, 32]
# 3, 33 is assigned Outside based on [2, 33]
# 3, 34 is assigned Outside based on [2, 34]
# 3, 35 is assigned Outside based on [2, 35]
# 3, 36 is assigned Outside based on [2, 36]
# 3, 37 is assigned Outside based on [2, 37]
# 3, 38 is assigned Outside based on [2, 38]
# 3, 39 is assigned Outside based on [2, 39]
# 3, 40 is assigned Outside based on [2, 40]
# 3, 41 is assigned Outside based on [2, 41]
# 3, 42 is assigned Outside based on [2, 42]
# 3, 43 is assigned Outside based on [2, 43]
# 3, 44 is assigned Outside based on [2, 44]
# 3, 45 is assigned Outside based on [2, 45]
# 3, 46 is assigned Outside based on [2, 46]
# 3, 47 is assigned Outside based on [2, 47]
# 3, 48 is assigned Outside based on [2, 48]
# 3, 49 is assigned Outside based on [2, 49]
# 3, 50 is assigned Outside based on [2, 50]
# 3, 51 is assigned Outside based on [2, 51]
# 3, 52 is assigned Outside based on [2, 52]
# 3, 53 is assigned Outside based on [2, 53]
# 3, 54 is assigned Outside based on [2, 54]
# 3, 55 is assigned Outside based on [2, 55]
# 3, 56 is assigned Outside based on [2, 56]
# 3, 57 is assigned Outside based on [2, 57]
# 3, 58 is assigned Outside based on [2, 58]
# 3, 59 is assigned Outside based on [2, 59]
# 3, 60 is assigned Outside based on [2, 60]
# 3, 61 is assigned Outside based on [2, 61]
# 3, 62 is assigned Outside based on [2, 62]
# 3, 63 is assigned Outside based on [2, 63]
# 3, 64 is assigned Outside based on [2, 64]
# 3, 65 is assigned Outside based on [2, 65]
# 3, 66 is assigned Outside based on [2, 66]
# 3, 67 is assigned Outside based on [2, 67]
# 3, 68 is assigned Outside based on [2, 68]
# 3, 69 is assigned Outside based on [2, 69]
# 3, 70 is assigned Outside based on [2, 70]
# 3, 71 is assigned Outside based on [2, 71]
# 3, 72 is assigned Outside based on [2, 72]
# 3, 73 is assigned Outside based on [2, 73]
# 3, 74 is assigned Outside based on [2, 74]
# 3, 75 is assigned Outside based on [2, 75]
# 3, 76 is assigned Outside based on [2, 76]
# 3, 77 is assigned Outside based on [2, 77]
# 3, 78 is assigned Outside based on [2, 78]
# 3, 79 is assigned Outside based on [2, 79]
# 3, 80 is assigned Outside based on [2, 80]
# 3, 81 is assigned Outside based on [2, 81]
# 3, 82 is assigned Outside based on [2, 82]
# 3, 83 is assigned Outside based on [2, 83]
# 3, 84 is assigned Outside based on [2, 84]
# 3, 85 is assigned Outside based on [2, 85]
# 3, 86 is assigned Outside based on [2, 86]
# 3, 87 is assigned Outside based on [2, 87]
# 3, 88 is assigned Outside based on [2, 88]
# 3, 89 is assigned Outside based on [2, 89]
# 3, 95 is assigned Outside based on [2, 95]
# 3, 96 is assigned Outside based on [2, 96]
# 3, 97 is assigned Outside based on [2, 97]
# 3, 98 is assigned Outside based on [2, 98]
# 3, 99 is assigned Outside based on [2, 99]
# 3, 100 is assigned Outside based on [2, 100]
# 3, 101 is assigned Outside based on [2, 101]
# 3, 102 is assigned Outside based on [2, 102]
# 3, 103 is assigned Outside based on [2, 103]
# 3, 104 is assigned Outside based on [2, 104]
# 3, 105 is assigned Outside based on [2, 105]
# 3, 106 is assigned Outside based on [2, 106]
# 3, 107 is assigned Outside based on [2, 107]
# 3, 108 is assigned Outside based on [2, 108]
# 3, 109 is assigned Outside based on [2, 109]
# 3, 110 is assigned Outside based on [2, 110]
# 3, 111 is assigned Outside based on [2, 111]
# 3, 112 is assigned Outside based on [2, 112]
# 3, 113 is assigned Outside based on [2, 113]
# 3, 114 is assigned Outside based on [2, 114]
# 3, 115 is assigned Outside based on [2, 115]
# 3, 116 is assigned Outside based on [2, 116]
# 3, 117 is assigned Outside based on [2, 117]
# 3, 118 is assigned Outside based on [2, 118]
# 3, 119 is assigned Outside based on [2, 119]
# 3, 120 is assigned Outside based on [2, 120]
# 3, 121 is assigned Outside based on [2, 121]
# 3, 122 is assigned Outside based on [2, 122]
# 3, 123 is assigned Outside based on [2, 123]
# 3, 124 is assigned Outside based on [2, 124]
# 3, 125 is assigned Outside based on [2, 125]
# 3, 126 is assigned Outside based on [2, 126]
# 3, 127 is assigned Outside based on [2, 127]
# 3, 128 is assigned Outside based on [2, 128]
# 3, 129 is assigned Outside based on [2, 129]
# 3, 130 is assigned Outside based on [2, 130]
# 3, 131 is assigned Outside based on [2, 131]
# 3, 132 is assigned Outside based on [2, 132]
# 3, 133 is assigned Outside based on [2, 133]
# 3, 134 is assigned Outside based on [2, 134]
# 3, 135 is assigned Outside based on [2, 135]
# 3, 136 is assigned Outside based on [2, 136]
# 3, 137 is assigned Outside based on [2, 137]
# 3, 138 is assigned Outside based on [2, 138]
# 4, 1 is assigned Outside based on [3, 1]
# 4, 2 is assigned Outside based on [3, 2]
# 4, 3 is assigned Outside based on [3, 3]
# 4, 4 is assigned Outside based on [3, 4]
# 4, 5 is assigned Outside based on [3, 5]
# 4, 6 is assigned Outside based on [3, 6]
# 4, 7 is assigned Outside based on [3, 7]
# 4, 8 is assigned Outside based on [3, 8]
# 4, 9 is assigned Outside based on [3, 9]
# 4, 10 is assigned Outside based on [3, 10]
# 4, 11 is assigned Outside based on [3, 11]
# 4, 12 is assigned Outside based on [3, 12]
# 4, 13 is assigned Outside based on [3, 13]
# 4, 14 is assigned Outside based on [3, 14]
# 4, 15 is assigned Outside based on [3, 15]
# 4, 16 is assigned Outside based on [3, 16]
# 4, 17 is assigned Outside based on [3, 17]
# 4, 18 is assigned Outside based on [3, 18]
# 4, 19 is assigned Outside based on [3, 19]
# 4, 20 is assigned Outside based on [3, 20]
# 4, 21 is assigned Outside based on [3, 21]
# 4, 22 is assigned Outside based on [3, 22]
# 4, 29 is assigned Outside based on [3, 29]
# 4, 30 is assigned Outside based on [3, 30]
# 4, 31 is assigned Outside based on [3, 31]
# 4, 32 is assigned Outside based on [3, 32]
# 4, 33 is assigned Outside based on [3, 33]
# 4, 34 is assigned Outside based on [3, 34]
# 4, 35 is assigned Outside based on [3, 35]
# 4, 36 is assigned Outside based on [3, 36]
# 4, 37 is assigned Outside based on [3, 37]
# 4, 40 is assigned Outside based on [3, 40]
# 4, 41 is assigned Outside based on [3, 41]
# 4, 42 is assigned Outside based on [3, 42]
# 4, 43 is assigned Outside based on [3, 43]
# 4, 44 is assigned Outside based on [3, 44]
# 4, 45 is assigned Outside based on [3, 45]
# 4, 46 is assigned Outside based on [3, 46]
# 4, 47 is assigned Outside based on [3, 47]
# 4, 48 is assigned Outside based on [3, 48]
# 4, 49 is assigned Outside based on [3, 49]
# 4, 50 is assigned Outside based on [3, 50]
# 4, 51 is assigned Outside based on [3, 51]
# 4, 52 is assigned Outside based on [3, 52]
# 4, 53 is assigned Outside based on [3, 53]
# 4, 54 is assigned Outside based on [3, 54]
# 4, 55 is assigned Outside based on [3, 55]
# 4, 56 is assigned Outside based on [3, 56]
# 4, 57 is assigned Outside based on [3, 57]
# 4, 58 is assigned Outside based on [3, 58]
# 4, 59 is assigned Outside based on [3, 59]
# 4, 60 is assigned Outside based on [3, 60]
# 4, 61 is assigned Outside based on [3, 61]
# 4, 62 is assigned Outside based on [3, 62]
# 4, 63 is assigned Outside based on [3, 63]
# 4, 64 is assigned Outside based on [3, 64]
# 4, 65 is assigned Outside based on [3, 65]
# 4, 66 is assigned Outside based on [3, 66]
# 4, 67 is assigned Outside based on [3, 67]
# 4, 68 is assigned Outside based on [3, 68]
# 4, 69 is assigned Outside based on [3, 69]
# 4, 70 is assigned Outside based on [3, 70]
# 4, 71 is assigned Outside based on [3, 71]
# 4, 72 is assigned Outside based on [3, 72]
# 4, 73 is assigned Outside based on [3, 73]
# 4, 74 is assigned Outside based on [3, 74]
# 4, 75 is assigned Outside based on [3, 75]
# 4, 76 is assigned Outside based on [3, 76]
# 4, 77 is assigned Outside based on [3, 77]
# 4, 78 is assigned Outside based on [3, 78]
# 4, 79 is assigned Outside based on [3, 79]
# 4, 80 is assigned Outside based on [3, 80]
# 4, 81 is assigned Outside based on [3, 81]
# 4, 82 is assigned Outside based on [3, 82]
# 4, 83 is assigned Outside based on [3, 83]
# 4, 84 is assigned Outside based on [3, 84]
# 4, 85 is assigned Outside based on [3, 85]
# 4, 86 is assigned Outside based on [3, 86]
# 4, 87 is assigned Outside based on [3, 87]
# 4, 88 is assigned Outside based on [3, 88]
# 4, 89 is assigned Outside based on [3, 89]
# 4, 95 is assigned Outside based on [3, 95]
# 4, 96 is assigned Outside based on [3, 96]
# 4, 97 is assigned Outside based on [3, 97]
# 4, 98 is assigned Outside based on [3, 98]
# 4, 99 is assigned Outside based on [3, 99]
# 4, 100 is assigned Outside based on [3, 100]
# 4, 101 is assigned Outside based on [3, 101]
# 4, 102 is assigned Outside based on [3, 102]
# 4, 103 is assigned Outside based on [3, 103]
# 4, 104 is assigned Outside based on [3, 104]
# 4, 105 is assigned Outside based on [3, 105]
# 4, 106 is assigned Outside based on [3, 106]
# 4, 107 is assigned Outside based on [3, 107]
# 4, 108 is assigned Outside based on [3, 108]
# 4, 109 is assigned Outside based on [3, 109]
# 4, 110 is assigned Outside based on [3, 110]
# 4, 111 is assigned Outside based on [3, 111]
# 4, 112 is assigned Outside based on [3, 112]
# 4, 113 is assigned Outside based on [3, 113]
# 4, 114 is assigned Outside based on [3, 114]
# 4, 115 is assigned Outside based on [3, 115]
# 4, 116 is assigned Outside based on [3, 116]
# 4, 117 is assigned Outside based on [3, 117]
# 4, 118 is assigned Outside based on [3, 118]
# 4, 119 is assigned Outside based on [3, 119]
# 4, 120 is assigned Outside based on [3, 120]
# 4, 121 is assigned Outside based on [3, 121]
# 4, 122 is assigned Outside based on [3, 122]
# 4, 123 is assigned Outside based on [3, 123]
# 4, 124 is assigned Outside based on [3, 124]
# 4, 125 is assigned Outside based on [3, 125]
# 4, 126 is assigned Outside based on [3, 126]
# 4, 127 is assigned Outside based on [3, 127]
# 4, 128 is assigned Outside based on [3, 128]
# 4, 129 is assigned Outside based on [3, 129]
# 4, 130 is assigned Outside based on [3, 130]
# 4, 131 is assigned Outside based on [3, 131]
# 4, 132 is assigned Outside based on [3, 132]
# 4, 133 is assigned Outside based on [3, 133]
# 4, 134 is assigned Outside based on [3, 134]
# 4, 135 is assigned Outside based on [3, 135]
# 4, 136 is assigned Outside based on [3, 136]
# 4, 137 is assigned Outside based on [3, 137]
# 4, 138 is assigned Outside based on [3, 138]
# 5, 1 is assigned Outside based on [4, 1]
# 5, 2 is assigned Outside based on [4, 2]
# 5, 3 is assigned Outside based on [4, 3]
# 5, 4 is assigned Outside based on [4, 4]
# 5, 5 is assigned Outside based on [4, 5]
# 5, 6 is assigned Outside based on [4, 6]
# 5, 7 is assigned Outside based on [4, 7]
# 5, 8 is assigned Outside based on [4, 8]
# 5, 9 is assigned Outside based on [4, 9]
# 5, 10 is assigned Outside based on [4, 10]
# 5, 11 is assigned Outside based on [4, 11]
# 5, 12 is assigned Outside based on [4, 12]
# 5, 13 is assigned Outside based on [4, 13]
# 5, 14 is assigned Outside based on [4, 14]
# 5, 15 is assigned Outside based on [4, 15]
# 5, 16 is assigned Outside based on [4, 16]
# 5, 17 is assigned Outside based on [4, 17]
# 5, 18 is assigned Outside based on [4, 18]
# 5, 19 is assigned Outside based on [4, 19]
# 5, 20 is assigned Outside based on [4, 20]
# 5, 21 is assigned Outside based on [4, 21]
# 5, 22 is assigned Outside based on [4, 22]
# 5, 32 is assigned Outside based on [4, 32]
# 5, 33 is assigned Outside based on [4, 33]
# 5, 34 is assigned Outside based on [4, 34]
# 5, 37 is assigned Outside based on [4, 37]
# 5, 40 is assigned Outside based on [4, 40]
# 5, 41 is assigned Outside based on [4, 41]
# 5, 42 is assigned Outside based on [4, 42]
# 5, 43 is assigned Outside based on [4, 43]
# 5, 44 is assigned Outside based on [4, 44]
# 5, 45 is assigned Outside based on [4, 45]
# 5, 46 is assigned Outside based on [4, 46]
# 5, 47 is assigned Outside based on [4, 47]
# 5, 48 is assigned Outside based on [4, 48]
# 5, 49 is assigned Outside based on [4, 49]
# 5, 50 is assigned Outside based on [4, 50]
# 5, 51 is assigned Outside based on [4, 51]
# 5, 52 is assigned Outside based on [4, 52]
# 5, 53 is assigned Outside based on [4, 53]
# 5, 54 is assigned Outside based on [4, 54]
# 5, 55 is assigned Outside based on [4, 55]
# 5, 56 is assigned Outside based on [4, 56]
# 5, 57 is assigned Outside based on [4, 57]
# 5, 58 is assigned Outside based on [4, 58]
# 5, 59 is assigned Outside based on [4, 59]
# 5, 60 is assigned Outside based on [4, 60]
# 5, 61 is assigned Outside based on [4, 61]
# 5, 62 is assigned Outside based on [4, 62]
# 5, 63 is assigned Outside based on [4, 63]
# 5, 64 is assigned Outside based on [4, 64]
# 5, 65 is assigned Outside based on [4, 65]
# 5, 66 is assigned Outside based on [4, 66]
# 5, 67 is assigned Outside based on [4, 67]
# 5, 68 is assigned Outside based on [4, 68]
# 5, 69 is assigned Outside based on [4, 69]
# 5, 70 is assigned Outside based on [4, 70]
# 5, 71 is assigned Outside based on [4, 71]
# 5, 72 is assigned Outside based on [4, 72]
# 5, 73 is assigned Outside based on [4, 73]
# 5, 74 is assigned Outside based on [4, 74]
# 5, 77 is assigned Outside based on [4, 77]
# 5, 80 is assigned Outside based on [4, 80]
# 5, 81 is assigned Outside based on [4, 81]
# 5, 82 is assigned Outside based on [4, 82]
# 5, 83 is assigned Outside based on [4, 83]
# 5, 84 is assigned Outside based on [4, 84]
# 5, 85 is assigned Outside based on [4, 85]
# 5, 86 is assigned Outside based on [4, 86]
# 5, 94 is assigned Inside
# 5, 97 is assigned Outside based on [4, 97]
# 5, 100 is assigned Outside based on [4, 100]
# 5, 104 is assigned Outside based on [4, 104]
# 5, 105 is assigned Outside based on [4, 105]
# 5, 106 is assigned Outside based on [4, 106]
# 5, 107 is assigned Outside based on [4, 107]
# 5, 108 is assigned Outside based on [4, 108]
# 5, 109 is assigned Outside based on [4, 109]
# 5, 110 is assigned Outside based on [4, 110]
# 5, 111 is assigned Outside based on [4, 111]
# 5, 112 is assigned Outside based on [4, 112]
# 5, 113 is assigned Outside based on [4, 113]
# 5, 114 is assigned Outside based on [4, 114]
# 5, 115 is assigned Outside based on [4, 115]
# 5, 116 is assigned Outside based on [4, 116]
# 5, 117 is assigned Outside based on [4, 117]
# 5, 118 is assigned Outside based on [4, 118]
# 5, 119 is assigned Outside based on [4, 119]
# 5, 120 is assigned Outside based on [4, 120]
# 5, 121 is assigned Outside based on [4, 121]
# 5, 122 is assigned Outside based on [4, 122]
# 5, 123 is assigned Outside based on [4, 123]
# 5, 124 is assigned Outside based on [4, 124]
# 5, 125 is assigned Outside based on [4, 125]
# 5, 126 is assigned Outside based on [4, 126]
# 5, 127 is assigned Outside based on [4, 127]
# 5, 128 is assigned Outside based on [4, 128]
# 5, 129 is assigned Outside based on [4, 129]
# 5, 130 is assigned Outside based on [4, 130]
# 5, 131 is assigned Outside based on [4, 131]
# 5, 132 is assigned Outside based on [4, 132]
# 5, 133 is assigned Outside based on [4, 133]
# 5, 134 is assigned Outside based on [4, 134]
# 5, 135 is assigned Outside based on [4, 135]
# 5, 136 is assigned Outside based on [4, 136]
# 5, 137 is assigned Outside based on [4, 137]
# 5, 138 is assigned Outside based on [4, 138]
# 6, 1 is assigned Outside based on [5, 1]
# 6, 2 is assigned Outside based on [5, 2]
# 6, 3 is assigned Outside based on [5, 3]
# 6, 4 is assigned Outside based on [5, 4]
# 6, 5 is assigned Outside based on [5, 5]
# 6, 6 is assigned Outside based on [5, 6]
# 6, 7 is assigned Outside based on [5, 7]
# 6, 8 is assigned Outside based on [5, 8]
# 6, 9 is assigned Outside based on [5, 9]
# 6, 10 is assigned Outside based on [5, 10]
# 6, 11 is assigned Outside based on [5, 11]
# 6, 12 is assigned Outside based on [5, 12]
# 6, 13 is assigned Outside based on [5, 13]
# 6, 14 is assigned Outside based on [5, 14]
# 6, 15 is assigned Outside based on [5, 15]
# 6, 16 is assigned Outside based on [5, 16]
# 6, 17 is assigned Outside based on [5, 17]
# 6, 18 is assigned Outside based on [5, 18]
# 6, 19 is assigned Outside based on [5, 19]
# 6, 20 is assigned Outside based on [5, 20]
# 6, 37 is assigned Outside based on [5, 37]
# 6, 40 is assigned Outside based on [5, 40]
# 6, 41 is assigned Outside based on [5, 41]
# 6, 42 is assigned Outside based on [5, 42]
# 6, 43 is assigned Outside based on [5, 43]
# 6, 44 is assigned Outside based on [5, 44]
# 6, 45 is assigned Outside based on [5, 45]
# 6, 46 is assigned Outside based on [5, 46]
# 6, 47 is assigned Outside based on [5, 47]
# 6, 48 is assigned Outside based on [5, 48]
# 6, 49 is assigned Outside based on [5, 49]
# 6, 50 is assigned Outside based on [5, 50]
# 6, 51 is assigned Outside based on [5, 51]
# 6, 52 is assigned Outside based on [5, 52]
# 6, 53 is assigned Outside based on [5, 53]
# 6, 54 is assigned Outside based on [5, 54]
# 6, 55 is assigned Outside based on [5, 55]
# 6, 56 is assigned Outside based on [5, 56]
# 6, 57 is assigned Outside based on [5, 57]
# 6, 58 is assigned Outside based on [5, 58]
# 6, 61 is assigned Outside based on [5, 61]
# 6, 62 is assigned Outside based on [5, 62]
# 6, 63 is assigned Outside based on [5, 63]
# 6, 64 is assigned Outside based on [5, 64]
# 6, 65 is assigned Outside based on [5, 65]
# 6, 66 is assigned Outside based on [5, 66]
# 6, 67 is assigned Outside based on [5, 67]
# 6, 68 is assigned Outside based on [5, 68]
# 6, 69 is assigned Outside based on [5, 69]
# 6, 70 is assigned Outside based on [5, 70]
# 6, 71 is assigned Outside based on [5, 71]
# 6, 72 is assigned Outside based on [5, 72]
# 6, 73 is assigned Outside based on [5, 73]
# 6, 74 is assigned Outside based on [5, 74]
# 6, 80 is assigned Outside based on [5, 80]
# 6, 81 is assigned Outside based on [5, 81]
# 6, 82 is assigned Outside based on [5, 82]
# 6, 83 is assigned Outside based on [5, 83]
# 6, 84 is assigned Outside based on [5, 84]
# 6, 100 is assigned Outside based on [5, 100]
# 6, 106 is assigned Outside based on [5, 106]
# 6, 107 is assigned Outside based on [5, 107]
# 6, 108 is assigned Outside based on [5, 108]
# 6, 109 is assigned Outside based on [5, 109]
# 6, 110 is assigned Outside based on [5, 110]
# 6, 111 is assigned Outside based on [5, 111]
# 6, 112 is assigned Outside based on [5, 112]
# 6, 113 is assigned Outside based on [5, 113]
# 6, 114 is assigned Outside based on [5, 114]
# 6, 115 is assigned Outside based on [5, 115]
# 6, 116 is assigned Outside based on [5, 116]
# 6, 117 is assigned Outside based on [5, 117]
# 6, 118 is assigned Outside based on [5, 118]
# 6, 119 is assigned Outside based on [5, 119]
# 6, 120 is assigned Outside based on [5, 120]
# 6, 121 is assigned Outside based on [5, 121]
# 6, 122 is assigned Outside based on [5, 122]
# 6, 123 is assigned Outside based on [5, 123]
# 6, 124 is assigned Outside based on [5, 124]
# 6, 125 is assigned Outside based on [5, 125]
# 6, 126 is assigned Outside based on [5, 126]
# 6, 127 is assigned Outside based on [5, 127]
# 6, 128 is assigned Outside based on [5, 128]
# 6, 129 is assigned Outside based on [5, 129]
# 6, 130 is assigned Outside based on [5, 130]
# 6, 131 is assigned Outside based on [5, 131]
# 6, 132 is assigned Outside based on [5, 132]
# 6, 133 is assigned Outside based on [5, 133]
# 6, 134 is assigned Outside based on [5, 134]
# 6, 135 is assigned Outside based on [5, 135]
# 6, 136 is assigned Outside based on [5, 136]
# 6, 137 is assigned Outside based on [5, 137]
# 6, 138 is assigned Outside based on [5, 138]
# 7, 1 is assigned Outside based on [6, 1]
# 7, 2 is assigned Outside based on [6, 2]
# 7, 3 is assigned Outside based on [6, 3]
# 7, 4 is assigned Outside based on [6, 4]
# 7, 5 is assigned Outside based on [6, 5]
# 7, 6 is assigned Outside based on [6, 6]
# 7, 7 is assigned Outside based on [6, 7]
# 7, 8 is assigned Outside based on [6, 8]
# 7, 9 is assigned Outside based on [6, 9]
# 7, 10 is assigned Outside based on [6, 10]
# 7, 11 is assigned Outside based on [6, 11]
# 7, 12 is assigned Outside based on [6, 12]
# 7, 13 is assigned Outside based on [6, 13]
# 7, 14 is assigned Outside based on [6, 14]
# 7, 15 is assigned Outside based on [6, 15]
# 7, 16 is assigned Outside based on [6, 16]
# 7, 17 is assigned Outside based on [6, 17]
# 7, 18 is assigned Outside based on [6, 18]
# 7, 19 is assigned Outside based on [6, 19]
# 7, 20 is assigned Outside based on [6, 20]
# 7, 31 is assigned Inside
# 7, 37 is assigned Outside based on [6, 37]
# 7, 44 is assigned Outside based on [6, 44]
# 7, 45 is assigned Outside based on [6, 45]
# 7, 46 is assigned Outside based on [6, 46]
# 7, 47 is assigned Outside based on [6, 47]
# 7, 48 is assigned Outside based on [6, 48]
# 7, 49 is assigned Outside based on [6, 49]
# 7, 50 is assigned Outside based on [6, 50]
# 7, 51 is assigned Outside based on [6, 51]
# 7, 52 is assigned Outside based on [6, 52]
# 7, 55 is assigned Outside based on [6, 55]
# 7, 56 is assigned Outside based on [6, 56]
# 7, 61 is assigned Outside based on [6, 61]
# 7, 62 is assigned Outside based on [6, 62]
# 7, 63 is assigned Outside based on [6, 63]
# 7, 64 is assigned Outside based on [6, 64]
# 7, 65 is assigned Outside based on [6, 65]
# 7, 66 is assigned Outside based on [6, 66]
# 7, 67 is assigned Outside based on [6, 67]
# 7, 68 is assigned Outside based on [6, 68]
# 7, 69 is assigned Outside based on [6, 69]
# 7, 70 is assigned Outside based on [6, 70]
# 7, 71 is assigned Outside based on [6, 71]
# 7, 72 is assigned Outside based on [6, 72]
# 7, 73 is assigned Outside based on [6, 73]
# 7, 74 is assigned Outside based on [6, 74]
# 7, 84 is assigned Outside based on [6, 84]
# 7, 89 is assigned Inside
# 7, 106 is assigned Outside based on [6, 106]
# 7, 107 is assigned Outside based on [6, 107]
# 7, 108 is assigned Outside based on [6, 108]
# 7, 109 is assigned Outside based on [6, 109]
# 7, 110 is assigned Outside based on [6, 110]
# 7, 111 is assigned Outside based on [6, 111]
# 7, 112 is assigned Outside based on [6, 112]
# 7, 113 is assigned Outside based on [6, 113]
# 7, 114 is assigned Outside based on [6, 114]
# 7, 115 is assigned Outside based on [6, 115]
# 7, 116 is assigned Outside based on [6, 116]
# 7, 117 is assigned Outside based on [6, 117]
# 7, 118 is assigned Outside based on [6, 118]
# 7, 119 is assigned Outside based on [6, 119]
# 7, 120 is assigned Outside based on [6, 120]
# 7, 121 is assigned Outside based on [6, 121]
# 7, 122 is assigned Outside based on [6, 122]
# 7, 123 is assigned Outside based on [6, 123]
# 7, 124 is assigned Outside based on [6, 124]
# 7, 125 is assigned Outside based on [6, 125]
# 7, 126 is assigned Outside based on [6, 126]
# 7, 127 is assigned Outside based on [6, 127]
# 7, 128 is assigned Outside based on [6, 128]
# 7, 129 is assigned Outside based on [6, 129]
# 7, 130 is assigned Outside based on [6, 130]
# 7, 131 is assigned Outside based on [6, 131]
# 7, 132 is assigned Outside based on [6, 132]
# 7, 133 is assigned Outside based on [6, 133]
# 7, 134 is assigned Outside based on [6, 134]
# 7, 135 is assigned Outside based on [6, 135]
# 7, 136 is assigned Outside based on [6, 136]
# 7, 137 is assigned Outside based on [6, 137]
# 7, 138 is assigned Outside based on [6, 138]
# 8, 1 is assigned Outside based on [7, 1]
# 8, 2 is assigned Outside based on [7, 2]
# 8, 3 is assigned Outside based on [7, 3]
# 8, 4 is assigned Outside based on [7, 4]
# 8, 5 is assigned Outside based on [7, 5]
# 8, 6 is assigned Outside based on [7, 6]
# 8, 7 is assigned Outside based on [7, 7]
# 8, 8 is assigned Outside based on [7, 8]
# 8, 9 is assigned Outside based on [7, 9]
# 8, 10 is assigned Outside based on [7, 10]
# 8, 11 is assigned Outside based on [7, 11]
# 8, 12 is assigned Outside based on [7, 12]
# 8, 13 is assigned Outside based on [7, 13]
# 8, 14 is assigned Outside based on [7, 14]
# 8, 15 is assigned Outside based on [7, 15]
# 8, 16 is assigned Outside based on [7, 16]
# 8, 17 is assigned Outside based on [7, 17]
# 8, 18 is assigned Outside based on [7, 18]
# 8, 19 is assigned Outside based on [7, 19]
# 8, 20 is assigned Outside based on [7, 20]
# 8, 30 is assigned Inside
# 8, 46 is assigned Outside based on [7, 46]
# 8, 47 is assigned Outside based on [7, 47]
# 8, 48 is assigned Outside based on [7, 48]
# 8, 67 is assigned Outside based on [7, 67]
# 8, 68 is assigned Outside based on [7, 68]
# 8, 69 is assigned Outside based on [7, 69]
# 8, 70 is assigned Outside based on [7, 70]
# 8, 71 is assigned Outside based on [7, 71]
# 8, 72 is assigned Outside based on [7, 72]
# 8, 73 is assigned Outside based on [7, 73]
# 8, 74 is assigned Outside based on [7, 74]
# 8, 75 is assigned Outside based on [8, 74]
# 8, 84 is assigned Outside based on [7, 84]
# 8, 85 is assigned Outside based on [8, 84]
# 8, 86 is assigned Outside based on [8, 85]
# 8, 91 is assigned Inside
# 8, 102 is assigned Inside
# 8, 107 is assigned Outside based on [7, 107]
# 8, 108 is assigned Outside based on [7, 108]
# 8, 109 is assigned Outside based on [7, 109]
# 8, 110 is assigned Outside based on [7, 110]
# 8, 111 is assigned Outside based on [7, 111]
# 8, 112 is assigned Outside based on [7, 112]
# 8, 113 is assigned Outside based on [7, 113]
# 8, 114 is assigned Outside based on [7, 114]
# 8, 115 is assigned Outside based on [7, 115]
# 8, 116 is assigned Outside based on [7, 116]
# 8, 117 is assigned Outside based on [7, 117]
# 8, 118 is assigned Outside based on [7, 118]
# 8, 119 is assigned Outside based on [7, 119]
# 8, 120 is assigned Outside based on [7, 120]
# 8, 121 is assigned Outside based on [7, 121]
# 8, 122 is assigned Outside based on [7, 122]
# 8, 123 is assigned Outside based on [7, 123]
# 8, 124 is assigned Outside based on [7, 124]
# 8, 125 is assigned Outside based on [7, 125]
# 8, 126 is assigned Outside based on [7, 126]
# 8, 127 is assigned Outside based on [7, 127]
# 8, 128 is assigned Outside based on [7, 128]
# 8, 129 is assigned Outside based on [7, 129]
# 8, 130 is assigned Outside based on [7, 130]
# 8, 131 is assigned Outside based on [7, 131]
# 8, 132 is assigned Outside based on [7, 132]
# 8, 133 is assigned Outside based on [7, 133]
# 8, 134 is assigned Outside based on [7, 134]
# 8, 135 is assigned Outside based on [7, 135]
# 8, 136 is assigned Outside based on [7, 136]
# 8, 137 is assigned Outside based on [7, 137]
# 8, 138 is assigned Outside based on [7, 138]
# 9, 1 is assigned Outside based on [8, 1]
# 9, 2 is assigned Outside based on [8, 2]
# 9, 3 is assigned Outside based on [8, 3]
# 9, 4 is assigned Outside based on [8, 4]
# 9, 5 is assigned Outside based on [8, 5]
# 9, 6 is assigned Outside based on [8, 6]
# 9, 7 is assigned Outside based on [8, 7]
# 9, 8 is assigned Outside based on [8, 8]
# 9, 9 is assigned Outside based on [8, 9]
# 9, 10 is assigned Outside based on [8, 10]
# 9, 11 is assigned Outside based on [8, 11]
# 9, 12 is assigned Outside based on [8, 12]
# 9, 13 is assigned Outside based on [8, 13]
# 9, 14 is assigned Outside based on [8, 14]
# 9, 15 is assigned Outside based on [8, 15]
# 9, 16 is assigned Outside based on [8, 16]
# 9, 17 is assigned Outside based on [8, 17]
# 9, 30 is assigned Inside
# 9, 67 is assigned Outside based on [8, 67]
# 9, 70 is assigned Outside based on [8, 70]
# 9, 71 is assigned Outside based on [8, 71]
# 9, 72 is assigned Outside based on [8, 72]
# 9, 73 is assigned Outside based on [8, 73]
# 9, 74 is assigned Outside based on [8, 74]
# 9, 75 is assigned Outside based on [8, 75]
# 9, 109 is assigned Outside based on [8, 109]
# 9, 110 is assigned Outside based on [8, 110]
# 9, 111 is assigned Outside based on [8, 111]
# 9, 112 is assigned Outside based on [8, 112]
# 9, 113 is assigned Outside based on [8, 113]
# 9, 114 is assigned Outside based on [8, 114]
# 9, 115 is assigned Outside based on [8, 115]
# 9, 116 is assigned Outside based on [8, 116]
# 9, 117 is assigned Outside based on [8, 117]
# 9, 118 is assigned Outside based on [8, 118]
# 9, 119 is assigned Outside based on [8, 119]
# 9, 120 is assigned Outside based on [8, 120]
# 9, 121 is assigned Outside based on [8, 121]
# 9, 122 is assigned Outside based on [8, 122]
# 9, 123 is assigned Outside based on [8, 123]
# 9, 124 is assigned Outside based on [8, 124]
# 9, 125 is assigned Outside based on [8, 125]
# 9, 126 is assigned Outside based on [8, 126]
# 9, 127 is assigned Outside based on [8, 127]
# 9, 128 is assigned Outside based on [8, 128]
# 9, 129 is assigned Outside based on [8, 129]
# 9, 130 is assigned Outside based on [8, 130]
# 9, 131 is assigned Outside based on [8, 131]
# 9, 132 is assigned Outside based on [8, 132]
# 9, 133 is assigned Outside based on [8, 133]
# 9, 134 is assigned Outside based on [8, 134]
# 9, 135 is assigned Outside based on [8, 135]
# 9, 136 is assigned Outside based on [8, 136]
# 9, 137 is assigned Outside based on [8, 137]
# 9, 138 is assigned Outside based on [8, 138]
# 10, 1 is assigned Outside based on [9, 1]
# 10, 2 is assigned Outside based on [9, 2]
# 10, 3 is assigned Outside based on [9, 3]
# 10, 4 is assigned Outside based on [9, 4]
# 10, 5 is assigned Outside based on [9, 5]
# 10, 6 is assigned Outside based on [9, 6]
# 10, 7 is assigned Outside based on [9, 7]
# 10, 8 is assigned Outside based on [9, 8]
# 10, 9 is assigned Outside based on [9, 9]
# 10, 10 is assigned Outside based on [9, 10]
# 10, 11 is assigned Outside based on [9, 11]
# 10, 12 is assigned Outside based on [9, 12]
# 10, 13 is assigned Outside based on [9, 13]
# 10, 14 is assigned Outside based on [9, 14]
# 10, 15 is assigned Outside based on [9, 15]
# 10, 16 is assigned Outside based on [9, 16]
# 10, 17 is assigned Outside based on [9, 17]
# 10, 62 is assigned Inside
# 10, 63 is assigned Inside
# 10, 70 is assigned Outside based on [9, 70]
# 10, 71 is assigned Outside based on [9, 71]
# 10, 72 is assigned Outside based on [9, 72]
# 10, 73 is assigned Outside based on [9, 73]
# 10, 74 is assigned Outside based on [9, 74]
# 10, 92 is assigned Inside
# 10, 97 is assigned Inside
# 10, 109 is assigned Outside based on [9, 109]
# 10, 110 is assigned Outside based on [9, 110]
# 10, 111 is assigned Outside based on [9, 111]
# 10, 112 is assigned Outside based on [9, 112]
# 10, 113 is assigned Outside based on [9, 113]
# 10, 114 is assigned Outside based on [9, 114]
# 10, 115 is assigned Outside based on [9, 115]
# 10, 116 is assigned Outside based on [9, 116]
# 10, 117 is assigned Outside based on [9, 117]
# 10, 118 is assigned Outside based on [9, 118]
# 10, 119 is assigned Outside based on [9, 119]
# 10, 120 is assigned Outside based on [9, 120]
# 10, 121 is assigned Outside based on [9, 121]
# 10, 122 is assigned Outside based on [9, 122]
# 10, 123 is assigned Outside based on [9, 123]
# 10, 124 is assigned Outside based on [9, 124]
# 10, 125 is assigned Outside based on [9, 125]
# 10, 126 is assigned Outside based on [9, 126]
# 10, 127 is assigned Outside based on [9, 127]
# 10, 128 is assigned Outside based on [9, 128]
# 10, 129 is assigned Outside based on [9, 129]
# 10, 130 is assigned Outside based on [9, 130]
# 10, 131 is assigned Outside based on [9, 131]
# 10, 132 is assigned Outside based on [9, 132]
# 10, 133 is assigned Outside based on [9, 133]
# 10, 134 is assigned Outside based on [9, 134]
# 10, 135 is assigned Outside based on [9, 135]
# 10, 136 is assigned Outside based on [9, 136]
# 10, 137 is assigned Outside based on [9, 137]
# 10, 138 is assigned Outside based on [9, 138]
# 11, 1 is assigned Outside based on [10, 1]
# 11, 2 is assigned Outside based on [10, 2]
# 11, 3 is assigned Outside based on [10, 3]
# 11, 4 is assigned Outside based on [10, 4]
# 11, 5 is assigned Outside based on [10, 5]
# 11, 6 is assigned Outside based on [10, 6]
# 11, 7 is assigned Outside based on [10, 7]
# 11, 8 is assigned Outside based on [10, 8]
# 11, 9 is assigned Outside based on [10, 9]
# 11, 10 is assigned Outside based on [10, 10]
# 11, 11 is assigned Outside based on [10, 11]
# 11, 12 is assigned Outside based on [10, 12]
# 11, 13 is assigned Outside based on [10, 13]
# 11, 14 is assigned Outside based on [10, 14]
# 11, 17 is assigned Outside based on [10, 17]
# 11, 20 is assigned Inside
# 11, 62 is assigned Inside
# 11, 63 is assigned Inside
# 11, 72 is assigned Outside based on [10, 72]
# 11, 73 is assigned Outside based on [10, 73]
# 11, 93 is assigned Inside
# 11, 98 is assigned Inside
# 11, 108 is assigned Inside
# 11, 111 is assigned Outside based on [10, 111]
# 11, 112 is assigned Outside based on [10, 112]
# 11, 113 is assigned Outside based on [10, 113]
# 11, 114 is assigned Outside based on [10, 114]
# 11, 115 is assigned Outside based on [10, 115]
# 11, 116 is assigned Outside based on [10, 116]
# 11, 117 is assigned Outside based on [10, 117]
# 11, 118 is assigned Outside based on [10, 118]
# 11, 119 is assigned Outside based on [10, 119]
# 11, 120 is assigned Outside based on [10, 120]
# 11, 121 is assigned Outside based on [10, 121]
# 11, 122 is assigned Outside based on [10, 122]
# 11, 123 is assigned Outside based on [10, 123]
# 11, 124 is assigned Outside based on [10, 124]
# 11, 125 is assigned Outside based on [10, 125]
# 11, 126 is assigned Outside based on [10, 126]
# 11, 127 is assigned Outside based on [10, 127]
# 11, 128 is assigned Outside based on [10, 128]
# 11, 129 is assigned Outside based on [10, 129]
# 11, 130 is assigned Outside based on [10, 130]
# 11, 131 is assigned Outside based on [10, 131]
# 11, 132 is assigned Outside based on [10, 132]
# 11, 133 is assigned Outside based on [10, 133]
# 11, 134 is assigned Outside based on [10, 134]
# 11, 135 is assigned Outside based on [10, 135]
# 11, 136 is assigned Outside based on [10, 136]
# 11, 137 is assigned Outside based on [10, 137]
# 11, 138 is assigned Outside based on [10, 138]
# 12, 1 is assigned Outside based on [11, 1]
# 12, 2 is assigned Outside based on [11, 2]
# 12, 3 is assigned Outside based on [11, 3]
# 12, 4 is assigned Outside based on [11, 4]
# 12, 5 is assigned Outside based on [11, 5]
# 12, 6 is assigned Outside based on [11, 6]
# 12, 7 is assigned Outside based on [11, 7]
# 12, 8 is assigned Outside based on [11, 8]
# 12, 9 is assigned Outside based on [11, 9]
# 12, 10 is assigned Outside based on [11, 10]
# 12, 11 is assigned Outside based on [11, 11]
# 12, 12 is assigned Outside based on [11, 12]
# 12, 13 is assigned Outside based on [11, 13]
# 12, 14 is assigned Outside based on [11, 14]
# 12, 17 is assigned Outside based on [11, 17]
# 12, 18 is assigned Outside based on [12, 17]
# 12, 19 is assigned Outside based on [12, 18]
# 12, 20 is assigned Outside based on [12, 19]
# 12, 49 is assigned Inside
# 12, 63 is assigned Inside
# 12, 64 is assigned Inside
# 12, 72 is assigned Outside based on [11, 72]
# 12, 79 is assigned Inside
# 12, 108 is assigned Inside
# 12, 111 is assigned Outside based on [11, 111]
# 12, 112 is assigned Outside based on [11, 112]
# 12, 113 is assigned Outside based on [11, 113]
# 12, 114 is assigned Outside based on [11, 114]
# 12, 115 is assigned Outside based on [11, 115]
# 12, 116 is assigned Outside based on [11, 116]
# 12, 117 is assigned Outside based on [11, 117]
# 12, 118 is assigned Outside based on [11, 118]
# 12, 119 is assigned Outside based on [11, 119]
# 12, 120 is assigned Outside based on [11, 120]
# 12, 121 is assigned Outside based on [11, 121]
# 12, 122 is assigned Outside based on [11, 122]
# 12, 123 is assigned Outside based on [11, 123]
# 12, 124 is assigned Outside based on [11, 124]
# 12, 125 is assigned Outside based on [11, 125]
# 12, 126 is assigned Outside based on [11, 126]
# 12, 127 is assigned Outside based on [11, 127]
# 12, 128 is assigned Outside based on [11, 128]
# 12, 129 is assigned Outside based on [11, 129]
# 12, 130 is assigned Outside based on [11, 130]
# 12, 131 is assigned Outside based on [11, 131]
# 12, 132 is assigned Outside based on [11, 132]
# 12, 133 is assigned Outside based on [11, 133]
# 12, 134 is assigned Outside based on [11, 134]
# 12, 135 is assigned Outside based on [11, 135]
# 12, 136 is assigned Outside based on [11, 136]
# 12, 137 is assigned Outside based on [11, 137]
# 12, 138 is assigned Outside based on [11, 138]
# 13, 1 is assigned Outside based on [12, 1]
# 13, 2 is assigned Outside based on [12, 2]
# 13, 3 is assigned Outside based on [12, 3]
# 13, 4 is assigned Outside based on [12, 4]
# 13, 5 is assigned Outside based on [12, 5]
# 13, 6 is assigned Outside based on [12, 6]
# 13, 7 is assigned Outside based on [12, 7]
# 13, 8 is assigned Outside based on [12, 8]
# 13, 9 is assigned Outside based on [12, 9]
# ...
# 19, 99 is assigned Inside
# 18, 32 is assigned Inside
# 18, 71 is assigned Inside
# 18, 84 is assigned Inside
# 17, 68 is assigned Inside
# 17, 102 is assigned Inside
# 17, 107 is assigned Inside
# 16, 29 is assigned Inside
# 16, 94 is assigned Inside
# 15, 49 is assigned Inside
# 15, 74 is assigned Inside
# 14, 75 is assigned Inside
# 13, 76 is assigned Inside
# 13, 77 is assigned Inside
# 13, 84 is assigned Inside
# 13, 108 is assigned Inside
# 12, 49 is assigned Inside
# 12, 63 is assigned Inside
# 12, 64 is assigned Inside
# 12, 79 is assigned Inside
# 12, 108 is assigned Inside
# 11, 62 is assigned Inside
# 11, 63 is assigned Inside
# 11, 93 is assigned Inside
# 11, 98 is assigned Inside
# 11, 108 is assigned Inside
# 10, 62 is assigned Inside
# 10, 63 is assigned Inside
# 10, 92 is assigned Inside
# 10, 97 is assigned Inside
# 9, 30 is assigned Inside
# 8, 30 is assigned Inside
# 8, 91 is assigned Inside
# 8, 102 is assigned Inside
# 7, 31 is assigned Inside
# 7, 89 is assigned Inside
# 5, 94 is assigned Inside
# 52, 133 is assigned Inside
# 53, 133 is assigned Inside
# 58, 131 is assigned Inside
# 55, 130 is assigned Inside
# 56, 130 is assigned Inside
# 55, 129 is assigned Inside
# 95, 129 is assigned Inside
# 55, 128 is assigned Inside
# 58, 125 is assigned Inside
# 71, 125 is assigned Inside
# 92, 125 is assigned Inside
# 41, 124 is assigned Inside
# 52, 124 is assigned Inside
# 81, 124 is assigned Inside
# 99, 124 is assigned Inside
# 22, 123 is assigned Inside
# 23, 123 is assigned Inside
# 85, 123 is assigned Inside
# 99, 123 is assigned Inside
# 23, 122 is assigned Inside
# 58, 122 is assigned Inside
# 79, 122 is assigned Inside
# 87, 122 is assigned Inside
# 32, 121 is assigned Inside
# 33, 121 is assigned Inside
# 34, 121 is assigned Inside
# 119, 121 is assigned Inside
# 35, 120 is assigned Inside
# 42, 120 is assigned Inside
# 49, 120 is assigned Inside
# 76, 120 is assigned Inside
# 104, 120 is assigned Inside
# 105, 120 is assigned Inside
# 47, 119 is assigned Inside
# 66, 118 is assigned Inside
# 119, 118 is assigned Inside
# 26, 117 is assigned Inside
# 29, 117 is assigned Inside
# 35, 117 is assigned Inside
# 74, 117 is assigned Inside
# 79, 117 is assigned Inside
# 107, 117 is assigned Inside
# 67, 116 is assigned Inside
# 103, 116 is assigned Inside
# 62, 115 is assigned Inside
# 26, 114 is assigned Inside
# 109, 114 is assigned Inside
# 112, 114 is assigned Inside
# 58, 113 is assigned Inside
# 66, 113 is assigned Inside
# 67, 113 is assigned Inside
# 103, 113 is assigned Inside
# 113, 113 is assigned Inside
# 44, 112 is assigned Inside
# 80, 112 is assigned Inside
# 102, 112 is assigned Inside
# 42, 111 is assigned Inside
# 83, 111 is assigned Inside
# 114, 111 is assigned Inside
# 36, 110 is assigned Inside
# 50, 110 is assigned Inside
# 117, 109 is assigned Inside
# 11, 108 is assigned Inside
# 12, 108 is assigned Inside
# 13, 108 is assigned Inside
# 33, 108 is assigned Inside
# 37, 108 is assigned Inside
# 97, 108 is assigned Inside
# 116, 108 is assigned Inside
# 121, 108 is assigned Inside
# 17, 107 is assigned Inside
# 25, 107 is assigned Inside
# 30, 107 is assigned Inside
# 104, 107 is assigned Inside
# 112, 107 is assigned Inside
# 123, 107 is assigned Inside
# 126, 107 is assigned Inside
# 83, 106 is assigned Inside
# 22, 105 is assigned Inside
# 36, 104 is assigned Inside
# 39, 104 is assigned Inside
# 71, 104 is assigned Inside
# 95, 104 is assigned Inside
# 128, 103 is assigned Inside
# 8, 102 is assigned Inside
# 17, 102 is assigned Inside
# 79, 102 is assigned Inside
# 111, 102 is assigned Inside
# 123, 102 is assigned Inside
# 89, 101 is assigned Inside
# 121, 101 is assigned Inside
# 26, 100 is assigned Inside
# 29, 100 is assigned Inside
# 60, 100 is assigned Inside
# 86, 100 is assigned Inside
# 100, 100 is assigned Inside
# 114, 100 is assigned Inside
# 117, 100 is assigned Inside
# 130, 100 is assigned Inside
# 19, 99 is assigned Inside
# 47, 99 is assigned Inside
# 69, 99 is assigned Inside
# 77, 99 is assigned Inside
# 130, 99 is assigned Inside
# 131, 99 is assigned Inside
# 11, 98 is assigned Inside
# 21, 98 is assigned Inside
# 42, 98 is assigned Inside
# 55, 98 is assigned Inside
# 124, 98 is assigned Inside
# 127, 98 is assigned Inside
# 10, 97 is assigned Inside
# 39, 97 is assigned Inside
# 62, 97 is assigned Inside
# 49, 96 is assigned Inside
# 88, 96 is assigned Inside
# 112, 96 is assigned Inside
# 38, 95 is assigned Inside
# 59, 95 is assigned Inside
# 102, 95 is assigned Inside
# 132, 95 is assigned Inside
# 5, 94 is assigned Inside
# 16, 94 is assigned Inside
# 89, 94 is assigned Inside
# 98, 94 is assigned Inside
# 106, 94 is assigned Inside
# 124, 94 is assigned Inside
# 11, 93 is assigned Inside
# 46, 93 is assigned Inside
# 75, 93 is assigned Inside
# 10, 92 is assigned Inside
# 28, 92 is assigned Inside
# 44, 92 is assigned Inside
# 8, 91 is assigned Inside
# 22, 91 is assigned Inside
# 56, 91 is assigned Inside
# 62, 91 is assigned Inside
# 82, 91 is assigned Inside
# 91, 91 is assigned Inside
# 96, 91 is assigned Inside
# 106, 91 is assigned Inside
# 59, 90 is assigned Inside
# 98, 90 is assigned Inside
# 110, 90 is assigned Inside
# 7, 89 is assigned Inside
# 57, 89 is assigned Inside
# 90, 89 is assigned Inside
# 112, 89 is assigned Inside
# 128, 89 is assigned Inside
# 25, 88 is assigned Inside
# 37, 88 is assigned Inside
# 64, 88 is assigned Inside
# 82, 88 is assigned Inside
# 95, 88 is assigned Inside
# 117, 88 is assigned Inside
# 124, 88 is assigned Inside
# 130, 88 is assigned Inside
# 97, 87 is assigned Inside
# 115, 87 is assigned Inside
# 118, 87 is assigned Inside
# 130, 87 is assigned Inside
# 88, 86 is assigned Inside
# 25, 85 is assigned Inside
# 28, 85 is assigned Inside
# 39, 85 is assigned Inside
# 42, 85 is assigned Inside
# 78, 85 is assigned Inside
# 84, 85 is assigned Inside
# 13, 84 is assigned Inside
# 18, 84 is assigned Inside
# 40, 84 is assigned Inside
# 50, 84 is assigned Inside
# 87, 84 is assigned Inside
# 106, 84 is assigned Inside
# 111, 84 is assigned Inside
# 102, 83 is assigned Inside
# 82, 82 is assigned Inside
# 128, 82 is assigned Inside
# 25, 81 is assigned Inside
# 52, 81 is assigned Inside
# 58, 81 is assigned Inside
# 66, 81 is assigned Inside
# 120, 81 is assigned Inside
# 126, 81 is assigned Inside
# 130, 81 is assigned Inside
# 131, 81 is assigned Inside
# 22, 80 is assigned Inside
# 26, 80 is assigned Inside
# 57, 80 is assigned Inside
# 58, 80 is assigned Inside
# 130, 80 is assigned Inside
# 12, 79 is assigned Inside
# 53, 79 is assigned Inside
# 56, 79 is assigned Inside
# 57, 79 is assigned Inside
# 58, 79 is assigned Inside
# 59, 79 is assigned Inside
# 82, 79 is assigned Inside
# 115, 79 is assigned Inside
# 19, 78 is assigned Inside
# 31, 78 is assigned Inside
# 58, 78 is assigned Inside
# 70, 78 is assigned Inside
# 84, 78 is assigned Inside
# 13, 77 is assigned Inside
# 58, 77 is assigned Inside
# 70, 77 is assigned Inside
# 71, 77 is assigned Inside
# 72, 77 is assigned Inside
# 75, 77 is assigned Inside
# 76, 77 is assigned Inside
# 77, 77 is assigned Inside
# 87, 77 is assigned Inside
# 13, 76 is assigned Inside
# 46, 76 is assigned Inside
# 57, 76 is assigned Inside
# 58, 76 is assigned Inside
# 59, 76 is assigned Inside
# 62, 76 is assigned Inside
# 66, 76 is assigned Inside
# 67, 76 is assigned Inside
# 68, 76 is assigned Inside
# 69, 76 is assigned Inside
# 70, 76 is assigned Inside
# 71, 76 is assigned Inside
# 72, 76 is assigned Inside
# 73, 76 is assigned Inside
# 74, 76 is assigned Inside
# 75, 76 is assigned Inside
# 76, 76 is assigned Inside
# 77, 76 is assigned Inside
# 110, 76 is assigned Inside
# 115, 76 is assigned Inside
# 118, 76 is assigned Inside
# 121, 76 is assigned Inside
# 14, 75 is assigned Inside
# 34, 75 is assigned Inside
# 58, 75 is assigned Inside
# 61, 75 is assigned Inside
# 62, 75 is assigned Inside
# 66, 75 is assigned Inside
# 67, 75 is assigned Inside
# 68, 75 is assigned Inside
# 69, 75 is assigned Inside
# 70, 75 is assigned Inside
# 71, 75 is assigned Inside
# 72, 75 is assigned Inside
# 73, 75 is assigned Inside
# 74, 75 is assigned Inside
# 75, 75 is assigned Inside
# 76, 75 is assigned Inside
# 77, 75 is assigned Inside
# 102, 75 is assigned Inside
# 119, 75 is assigned Inside
# 15, 74 is assigned Inside
# 20, 74 is assigned Inside
# 40, 74 is assigned Inside
# 43, 74 is assigned Inside
# 58, 74 is assigned Inside
# 62, 74 is assigned Inside
# 65, 74 is assigned Inside
# 66, 74 is assigned Inside
# 67, 74 is assigned Inside
# 68, 74 is assigned Inside
# 69, 74 is assigned Inside
# 70, 74 is assigned Inside
# 71, 74 is assigned Inside
# 72, 74 is assigned Inside
# 73, 74 is assigned Inside
# 74, 74 is assigned Inside
# 77, 74 is assigned Inside
# 90, 74 is assigned Inside
# 26, 73 is assigned Inside
# 29, 73 is assigned Inside
# 62, 73 is assigned Inside
# 63, 73 is assigned Inside
# 64, 73 is assigned Inside
# 65, 73 is assigned Inside
# 66, 73 is assigned Inside
# 67, 73 is assigned Inside
# 68, 73 is assigned Inside
# 69, 73 is assigned Inside
# 70, 73 is assigned Inside
# 71, 73 is assigned Inside
# 72, 73 is assigned Inside
# 73, 73 is assigned Inside
# 74, 73 is assigned Inside
# 82, 73 is assigned Inside
# 23, 72 is assigned Inside
# 62, 72 is assigned Inside
# 63, 72 is assigned Inside
# 64, 72 is assigned Inside
# 65, 72 is assigned Inside
# 66, 72 is assigned Inside
# 67, 72 is assigned Inside
# 68, 72 is assigned Inside
# 69, 72 is assigned Inside
# 70, 72 is assigned Inside
# 71, 72 is assigned Inside
# 72, 72 is assigned Inside
# 73, 72 is assigned Inside
# 74, 72 is assigned Inside
# 101, 72 is assigned Inside
# 119, 72 is assigned Inside
# 18, 71 is assigned Inside
# 38, 71 is assigned Inside
# 41, 71 is assigned Inside
# 50, 71 is assigned Inside
# 62, 71 is assigned Inside
# 65, 71 is assigned Inside
# 66, 71 is assigned Inside
# 67, 71 is assigned Inside
# 68, 71 is assigned Inside
# 69, 71 is assigned Inside
# 70, 71 is assigned Inside
# 71, 71 is assigned Inside
# 72, 71 is assigned Inside
# 73, 71 is assigned Inside
# 74, 71 is assigned Inside
# 94, 71 is assigned Inside
# 28, 70 is assigned Inside
# 31, 70 is assigned Inside
# 34, 70 is assigned Inside
# 65, 70 is assigned Inside
# 66, 70 is assigned Inside
# 67, 70 is assigned Inside
# 68, 70 is assigned Inside
# 69, 70 is assigned Inside
# 70, 70 is assigned Inside
# 71, 70 is assigned Inside
# 72, 70 is assigned Inside
# 73, 70 is assigned Inside
# 115, 70 is assigned Inside
# 55, 69 is assigned Inside
# 65, 69 is assigned Inside
# 66, 69 is assigned Inside
# 67, 69 is assigned Inside
# 68, 69 is assigned Inside
# 69, 69 is assigned Inside
# 70, 69 is assigned Inside
# 71, 69 is assigned Inside
# 72, 69 is assigned Inside
# 73, 69 is assigned Inside
# 77, 69 is assigned Inside
# 84, 69 is assigned Inside
# 103, 69 is assigned Inside
# 17, 68 is assigned Inside
# 20, 68 is assigned Inside
# 45, 68 is assigned Inside
# 54, 68 is assigned Inside
# 69, 68 is assigned Inside
# 70, 68 is assigned Inside
# 71, 68 is assigned Inside
# 72, 68 is assigned Inside
# 103, 68 is assigned Inside
# 104, 68 is assigned Inside
# 69, 67 is assigned Inside
# 70, 67 is assigned Inside
# 104, 67 is assigned Inside
# 117, 67 is assigned Inside
# 30, 66 is assigned Inside
# 36, 66 is assigned Inside
# 75, 66 is assigned Inside
# 62, 65 is assigned Inside
# 75, 65 is assigned Inside
# 78, 65 is assigned Inside
# 88, 65 is assigned Inside
# 12, 64 is assigned Inside
# 52, 64 is assigned Inside
# 65, 64 is assigned Inside
# 78, 64 is assigned Inside
# 104, 64 is assigned Inside
# 126, 64 is assigned Inside
# 10, 63 is assigned Inside
# 11, 63 is assigned Inside
# 12, 63 is assigned Inside
# 56, 63 is assigned Inside
# 63, 63 is assigned Inside
# 64, 63 is assigned Inside
# 65, 63 is assigned Inside
# 76, 63 is assigned Inside
# 77, 63 is assigned Inside
# 78, 63 is assigned Inside
# 79, 63 is assigned Inside
# 95, 63 is assigned Inside
# 104, 63 is assigned Inside
# 10, 62 is assigned Inside
# 11, 62 is assigned Inside
# 61, 62 is assigned Inside
# 64, 62 is assigned Inside
# 67, 62 is assigned Inside
# 70, 62 is assigned Inside
# 86, 62 is assigned Inside
# 101, 61 is assigned Inside
# 77, 60 is assigned Inside
# 78, 60 is assigned Inside
# 100, 60 is assigned Inside
# 61, 59 is assigned Inside
# 65, 59 is assigned Inside
# 112, 59 is assigned Inside
# 121, 59 is assigned Inside
# 122, 59 is assigned Inside
# 123, 59 is assigned Inside
# 54, 58 is assigned Inside
# 116, 58 is assigned Inside
# 26, 57 is assigned Inside
# 88, 57 is assigned Inside
# 98, 57 is assigned Inside
# 39, 56 is assigned Inside
# 51, 56 is assigned Inside
# 61, 56 is assigned Inside
# 82, 56 is assigned Inside
# 43, 55 is assigned Inside
# 48, 55 is assigned Inside
# 54, 55 is assigned Inside
# 62, 55 is assigned Inside
# 72, 55 is assigned Inside
# 30, 54 is assigned Inside
# 65, 54 is assigned Inside
# 83, 54 is assigned Inside
# 90, 54 is assigned Inside
# 93, 54 is assigned Inside
# 100, 54 is assigned Inside
# 69, 53 is assigned Inside
# 95, 53 is assigned Inside
# 108, 53 is assigned Inside
# 120, 53 is assigned Inside
# 48, 52 is assigned Inside
# 87, 51 is assigned Inside
# 102, 51 is assigned Inside
# 113, 51 is assigned Inside
# 56, 50 is assigned Inside
# 95, 50 is assigned Inside
# 117, 50 is assigned Inside
# 12, 49 is assigned Inside
# 15, 49 is assigned Inside
# 61, 49 is assigned Inside
# 22, 48 is assigned Inside
# 27, 48 is assigned Inside
# 49, 48 is assigned Inside
# 80, 48 is assigned Inside
# 83, 48 is assigned Inside
# 20, 47 is assigned Inside
# 98, 47 is assigned Inside
# 52, 46 is assigned Inside
# 79, 46 is assigned Inside
# 102, 46 is assigned Inside
# 53, 45 is assigned Inside
# 110, 45 is assigned Inside
# 123, 45 is assigned Inside
# 40, 44 is assigned Inside
# 93, 44 is assigned Inside
# 114, 44 is assigned Inside
# 64, 43 is assigned Inside
# 117, 43 is assigned Inside
# 29, 42 is assigned Inside
# 37, 42 is assigned Inside
# 66, 42 is assigned Inside
# 100, 42 is assigned Inside
# 79, 41 is assigned Inside
# 28, 40 is assigned Inside
# 72, 40 is assigned Inside
# 22, 39 is assigned Inside
# 38, 39 is assigned Inside
# 50, 39 is assigned Inside
# 60, 39 is assigned Inside
# 85, 39 is assigned Inside
# 95, 39 is assigned Inside
# 101, 39 is assigned Inside
# 104, 39 is assigned Inside
# 34, 38 is assigned Inside
# 65, 38 is assigned Inside
# 93, 38 is assigned Inside
# 102, 38 is assigned Inside
# 106, 38 is assigned Inside
# 109, 38 is assigned Inside
# 130, 38 is assigned Inside
# 131, 38 is assigned Inside
# 82, 37 is assigned Inside
# 40, 36 is assigned Inside
# 58, 36 is assigned Inside
# 85, 36 is assigned Inside
# 88, 36 is assigned Inside
# 99, 36 is assigned Inside
# 118, 36 is assigned Inside
# 109, 35 is assigned Inside
# 73, 34 is assigned Inside
# 90, 34 is assigned Inside
# 112, 34 is assigned Inside
# 123, 34 is assigned Inside
# 30, 33 is assigned Inside
# 43, 33 is assigned Inside
# 18, 32 is assigned Inside
# 26, 32 is assigned Inside
# 103, 32 is assigned Inside
# 130, 32 is assigned Inside
# 7, 31 is assigned Inside
# 66, 31 is assigned Inside
# 75, 31 is assigned Inside
# 81, 31 is assigned Inside
# 132, 31 is assigned Inside
# 8, 30 is assigned Inside
# 9, 30 is assigned Inside
# 21, 30 is assigned Inside
# 45, 30 is assigned Inside
# 57, 30 is assigned Inside
# 62, 30 is assigned Inside
# 122, 30 is assigned Inside
# 125, 30 is assigned Inside
# 16, 29 is assigned Inside
# 46, 29 is assigned Inside
# 62, 29 is assigned Inside
# 69, 29 is assigned Inside
# 54, 28 is assigned Inside
# 77, 28 is assigned Inside
# 65, 27 is assigned Inside
# 112, 27 is assigned Inside
# 47, 25 is assigned Inside
# 122, 25 is assigned Inside
# 21, 24 is assigned Inside
# 24, 24 is assigned Inside
# 89, 24 is assigned Inside
# 104, 23 is assigned Inside
# 29, 22 is assigned Inside
# 53, 22 is assigned Inside
# 58, 22 is assigned Inside
# 88, 22 is assigned Inside
# 122, 22 is assigned Inside
# 55, 20 is assigned Inside
# 22, 19 is assigned Inside
# 25, 19 is assigned Inside
# 37, 19 is assigned Inside
# 54, 19 is assigned Inside
# 61, 19 is assigned Inside
# 62, 19 is assigned Inside
# 107, 19 is assigned Inside
# 25, 18 is assigned Inside
# 61, 18 is assigned Inside
# 94, 18 is assigned Inside
# 25, 17 is assigned Inside
# 73, 17 is assigned Inside
# 80, 17 is assigned Inside
# 32, 16 is assigned Inside
# 54, 16 is assigned Inside
# 64, 16 is assigned Inside
# 107, 16 is assigned Inside
# 44, 15 is assigned Inside
# 50, 15 is assigned Inside
# 70, 15 is assigned Inside
# 34, 13 is assigned Inside
# 49, 13 is assigned Inside
# 84, 13 is assigned Inside
# 37, 12 is assigned Inside
# 57, 12 is assigned Inside
# 58, 12 is assigned Inside
# 70, 12 is assigned Inside
# 31, 11 is assigned Inside
# 55, 11 is assigned Inside
# 56, 11 is assigned Inside
# 57, 11 is assigned Inside
# 58, 11 is assigned Inside
# 66, 11 is assigned Inside
# 69, 11 is assigned Inside
# 70, 11 is assigned Inside
# 31, 10 is assigned Inside
# 70, 10 is assigned Inside
# 81, 10 is assigned Inside
# 70, 9 is assigned Inside
# 38, 8 is assigned Inside
# 70, 8 is assigned Inside

# %%
from collections import Counter
Counter(outcome_dict.values())
# Out:
# Counter({'Outside': 4971, 'Pipe': 14059, 'Inside': 570})

# %%
140*140
# Out:
# 19600

# %%
4971+570+14059
# Out:
# 19600

# %%
outcome_dict[(132, 96)] #132, 95
# Out:
# 'Pipe'

# %%
inside_dict = {k: v for k, v in outcome_dict.items() if v == "Inside"}

# %%
inside_dict
# Out:
# {(5, 94): 'Inside',
#  (7, 31): 'Inside',
#  (7, 89): 'Inside',
#  (8, 30): 'Inside',
#  (8, 91): 'Inside',
#  (8, 102): 'Inside',
#  (9, 30): 'Inside',
#  (10, 62): 'Inside',
#  (10, 63): 'Inside',
#  (10, 92): 'Inside',
#  (10, 97): 'Inside',
#  (11, 62): 'Inside',
#  (11, 63): 'Inside',
#  (11, 93): 'Inside',
#  (11, 98): 'Inside',
#  (11, 108): 'Inside',
#  (12, 49): 'Inside',
#  (12, 63): 'Inside',
#  (12, 64): 'Inside',
#  (12, 79): 'Inside',
#  (12, 108): 'Inside',
#  (13, 76): 'Inside',
#  (13, 77): 'Inside',
#  (13, 84): 'Inside',
#  (13, 108): 'Inside',
#  (14, 75): 'Inside',
#  (15, 49): 'Inside',
#  (15, 74): 'Inside',
#  (16, 29): 'Inside',
#  (16, 94): 'Inside',
#  (17, 68): 'Inside',
#  (17, 102): 'Inside',
#  (17, 107): 'Inside',
#  (18, 32): 'Inside',
#  (18, 71): 'Inside',
#  (18, 84): 'Inside',
#  (19, 78): 'Inside',
#  (19, 99): 'Inside',
#  (20, 47): 'Inside',
#  (20, 68): 'Inside',
#  (20, 74): 'Inside',
#  (21, 24): 'Inside',
#  (21, 30): 'Inside',
#  (21, 98): 'Inside',
#  (22, 19): 'Inside',
#  (22, 39): 'Inside',
#  (22, 48): 'Inside',
#  (22, 80): 'Inside',
#  (22, 91): 'Inside',
#  (22, 105): 'Inside',
#  (22, 123): 'Inside',
#  (23, 72): 'Inside',
#  (23, 122): 'Inside',
#  (23, 123): 'Inside',
#  (24, 24): 'Inside',
#  (25, 17): 'Inside',
#  (25, 18): 'Inside',
#  (25, 19): 'Inside',
#  (25, 81): 'Inside',
#  (25, 85): 'Inside',
#  (25, 88): 'Inside',
#  (25, 107): 'Inside',
#  (26, 32): 'Inside',
#  (26, 57): 'Inside',
#  (26, 73): 'Inside',
#  (26, 80): 'Inside',
#  (26, 100): 'Inside',
#  (26, 114): 'Inside',
#  (26, 117): 'Inside',
#  (27, 48): 'Inside',
#  (28, 40): 'Inside',
#  (28, 70): 'Inside',
#  (28, 85): 'Inside',
#  (28, 92): 'Inside',
#  (29, 22): 'Inside',
#  (29, 42): 'Inside',
#  (29, 73): 'Inside',
#  (29, 100): 'Inside',
#  (29, 117): 'Inside',
#  (30, 33): 'Inside',
#  (30, 54): 'Inside',
#  (30, 66): 'Inside',
#  (30, 107): 'Inside',
#  (31, 10): 'Inside',
#  (31, 11): 'Inside',
#  (31, 70): 'Inside',
#  (31, 78): 'Inside',
#  (32, 16): 'Inside',
#  (32, 121): 'Inside',
#  (33, 108): 'Inside',
#  (33, 121): 'Inside',
#  (34, 13): 'Inside',
#  (34, 38): 'Inside',
#  (34, 70): 'Inside',
#  (34, 75): 'Inside',
#  (34, 121): 'Inside',
#  (35, 117): 'Inside',
#  (35, 120): 'Inside',
#  (36, 66): 'Inside',
#  (36, 104): 'Inside',
#  (36, 110): 'Inside',
#  (37, 12): 'Inside',
#  (37, 19): 'Inside',
#  (37, 42): 'Inside',
#  (37, 88): 'Inside',
#  (37, 108): 'Inside',
#  (38, 8): 'Inside',
#  (38, 39): 'Inside',
#  (38, 71): 'Inside',
#  (38, 95): 'Inside',
#  (39, 56): 'Inside',
#  (39, 85): 'Inside',
#  (39, 97): 'Inside',
#  (39, 104): 'Inside',
#  (40, 36): 'Inside',
#  (40, 44): 'Inside',
#  (40, 74): 'Inside',
#  (40, 84): 'Inside',
#  (41, 71): 'Inside',
#  (41, 124): 'Inside',
#  (42, 85): 'Inside',
#  (42, 98): 'Inside',
#  (42, 111): 'Inside',
#  (42, 120): 'Inside',
#  (43, 33): 'Inside',
#  (43, 55): 'Inside',
#  (43, 74): 'Inside',
#  (44, 15): 'Inside',
#  (44, 92): 'Inside',
#  (44, 112): 'Inside',
#  (45, 30): 'Inside',
#  (45, 68): 'Inside',
#  (46, 29): 'Inside',
#  (46, 76): 'Inside',
#  (46, 93): 'Inside',
#  (47, 25): 'Inside',
#  (47, 99): 'Inside',
#  (47, 119): 'Inside',
#  (48, 52): 'Inside',
#  (48, 55): 'Inside',
#  (49, 13): 'Inside',
#  (49, 48): 'Inside',
#  (49, 96): 'Inside',
#  (49, 120): 'Inside',
#  (50, 15): 'Inside',
#  (50, 39): 'Inside',
#  (50, 71): 'Inside',
#  (50, 84): 'Inside',
#  (50, 110): 'Inside',
#  (51, 56): 'Inside',
#  (52, 46): 'Inside',
#  (52, 64): 'Inside',
#  (52, 81): 'Inside',
#  (52, 124): 'Inside',
#  (52, 133): 'Inside',
#  (53, 22): 'Inside',
#  (53, 45): 'Inside',
#  (53, 79): 'Inside',
#  (53, 133): 'Inside',
#  (54, 16): 'Inside',
#  (54, 19): 'Inside',
#  (54, 28): 'Inside',
#  (54, 55): 'Inside',
#  (54, 58): 'Inside',
#  (54, 68): 'Inside',
#  (55, 11): 'Inside',
#  (55, 20): 'Inside',
#  (55, 69): 'Inside',
#  (55, 98): 'Inside',
#  (55, 128): 'Inside',
#  (55, 129): 'Inside',
#  (55, 130): 'Inside',
#  (56, 11): 'Inside',
#  (56, 50): 'Inside',
#  (56, 63): 'Inside',
#  (56, 79): 'Inside',
#  (56, 91): 'Inside',
#  (56, 130): 'Inside',
#  (57, 11): 'Inside',
#  (57, 12): 'Inside',
#  (57, 30): 'Inside',
#  (57, 76): 'Inside',
#  (57, 79): 'Inside',
#  (57, 80): 'Inside',
#  (57, 89): 'Inside',
#  (58, 11): 'Inside',
#  (58, 12): 'Inside',
#  (58, 22): 'Inside',
#  (58, 36): 'Inside',
#  (58, 74): 'Inside',
#  (58, 75): 'Inside',
#  (58, 76): 'Inside',
#  (58, 77): 'Inside',
#  (58, 78): 'Inside',
#  (58, 79): 'Inside',
#  (58, 80): 'Inside',
#  (58, 81): 'Inside',
#  (58, 113): 'Inside',
#  (58, 122): 'Inside',
#  (58, 125): 'Inside',
#  (58, 131): 'Inside',
#  (59, 76): 'Inside',
#  (59, 79): 'Inside',
#  (59, 90): 'Inside',
#  (59, 95): 'Inside',
#  (60, 39): 'Inside',
#  (60, 100): 'Inside',
#  (61, 18): 'Inside',
#  (61, 19): 'Inside',
#  (61, 49): 'Inside',
#  (61, 56): 'Inside',
#  (61, 59): 'Inside',
#  (61, 62): 'Inside',
#  (61, 75): 'Inside',
#  (62, 19): 'Inside',
#  (62, 29): 'Inside',
#  (62, 30): 'Inside',
#  (62, 55): 'Inside',
#  (62, 65): 'Inside',
#  (62, 71): 'Inside',
#  (62, 72): 'Inside',
#  (62, 73): 'Inside',
#  (62, 74): 'Inside',
#  (62, 75): 'Inside',
#  (62, 76): 'Inside',
#  (62, 91): 'Inside',
#  (62, 97): 'Inside',
#  (62, 115): 'Inside',
#  (63, 63): 'Inside',
#  (63, 72): 'Inside',
#  (63, 73): 'Inside',
#  (64, 16): 'Inside',
#  (64, 43): 'Inside',
#  (64, 62): 'Inside',
#  (64, 63): 'Inside',
#  (64, 72): 'Inside',
#  (64, 73): 'Inside',
#  (64, 88): 'Inside',
#  (65, 27): 'Inside',
#  (65, 38): 'Inside',
#  (65, 54): 'Inside',
#  (65, 59): 'Inside',
#  (65, 63): 'Inside',
#  (65, 64): 'Inside',
#  (65, 69): 'Inside',
#  (65, 70): 'Inside',
#  (65, 71): 'Inside',
#  (65, 72): 'Inside',
#  (65, 73): 'Inside',
#  (65, 74): 'Inside',
#  (66, 11): 'Inside',
#  (66, 31): 'Inside',
#  (66, 42): 'Inside',
#  (66, 69): 'Inside',
#  (66, 70): 'Inside',
#  (66, 71): 'Inside',
#  (66, 72): 'Inside',
#  (66, 73): 'Inside',
#  (66, 74): 'Inside',
#  (66, 75): 'Inside',
#  (66, 76): 'Inside',
#  (66, 81): 'Inside',
#  (66, 113): 'Inside',
#  (66, 118): 'Inside',
#  (67, 62): 'Inside',
#  (67, 69): 'Inside',
#  (67, 70): 'Inside',
#  (67, 71): 'Inside',
#  (67, 72): 'Inside',
#  (67, 73): 'Inside',
#  (67, 74): 'Inside',
#  (67, 75): 'Inside',
#  (67, 76): 'Inside',
#  (67, 113): 'Inside',
#  (67, 116): 'Inside',
#  (68, 69): 'Inside',
#  (68, 70): 'Inside',
#  (68, 71): 'Inside',
#  (68, 72): 'Inside',
#  (68, 73): 'Inside',
#  (68, 74): 'Inside',
#  (68, 75): 'Inside',
#  (68, 76): 'Inside',
#  (69, 11): 'Inside',
#  (69, 29): 'Inside',
#  (69, 53): 'Inside',
#  (69, 67): 'Inside',
#  (69, 68): 'Inside',
#  (69, 69): 'Inside',
#  (69, 70): 'Inside',
#  (69, 71): 'Inside',
#  (69, 72): 'Inside',
#  (69, 73): 'Inside',
#  (69, 74): 'Inside',
#  (69, 75): 'Inside',
#  (69, 76): 'Inside',
#  (69, 99): 'Inside',
#  (70, 8): 'Inside',
#  (70, 9): 'Inside',
#  (70, 10): 'Inside',
#  (70, 11): 'Inside',
#  (70, 12): 'Inside',
#  (70, 15): 'Inside',
#  (70, 62): 'Inside',
#  (70, 67): 'Inside',
#  (70, 68): 'Inside',
#  (70, 69): 'Inside',
#  (70, 70): 'Inside',
#  (70, 71): 'Inside',
#  (70, 72): 'Inside',
#  (70, 73): 'Inside',
#  (70, 74): 'Inside',
#  (70, 75): 'Inside',
#  (70, 76): 'Inside',
#  (70, 77): 'Inside',
#  (70, 78): 'Inside',
#  (71, 68): 'Inside',
#  (71, 69): 'Inside',
#  (71, 70): 'Inside',
#  (71, 71): 'Inside',
#  (71, 72): 'Inside',
#  (71, 73): 'Inside',
#  (71, 74): 'Inside',
#  (71, 75): 'Inside',
#  (71, 76): 'Inside',
#  (71, 77): 'Inside',
#  (71, 104): 'Inside',
#  (71, 125): 'Inside',
#  (72, 40): 'Inside',
#  (72, 55): 'Inside',
#  (72, 68): 'Inside',
#  (72, 69): 'Inside',
#  (72, 70): 'Inside',
#  (72, 71): 'Inside',
#  (72, 72): 'Inside',
#  (72, 73): 'Inside',
#  (72, 74): 'Inside',
#  (72, 75): 'Inside',
#  (72, 76): 'Inside',
#  (72, 77): 'Inside',
#  (73, 17): 'Inside',
#  (73, 34): 'Inside',
#  (73, 69): 'Inside',
#  (73, 70): 'Inside',
#  (73, 71): 'Inside',
#  (73, 72): 'Inside',
#  (73, 73): 'Inside',
#  (73, 74): 'Inside',
#  (73, 75): 'Inside',
#  (73, 76): 'Inside',
#  (74, 71): 'Inside',
#  (74, 72): 'Inside',
#  (74, 73): 'Inside',
#  (74, 74): 'Inside',
#  (74, 75): 'Inside',
#  (74, 76): 'Inside',
#  (74, 117): 'Inside',
#  (75, 31): 'Inside',
#  (75, 65): 'Inside',
#  (75, 66): 'Inside',
#  (75, 75): 'Inside',
#  (75, 76): 'Inside',
#  (75, 77): 'Inside',
#  (75, 93): 'Inside',
#  (76, 63): 'Inside',
#  (76, 75): 'Inside',
#  (76, 76): 'Inside',
#  (76, 77): 'Inside',
#  (76, 120): 'Inside',
#  (77, 28): 'Inside',
#  (77, 60): 'Inside',
#  (77, 63): 'Inside',
#  (77, 69): 'Inside',
#  (77, 74): 'Inside',
#  (77, 75): 'Inside',
#  (77, 76): 'Inside',
#  (77, 77): 'Inside',
#  (77, 99): 'Inside',
#  (78, 60): 'Inside',
#  (78, 63): 'Inside',
#  (78, 64): 'Inside',
#  (78, 65): 'Inside',
#  (78, 85): 'Inside',
#  (79, 41): 'Inside',
#  (79, 46): 'Inside',
#  (79, 63): 'Inside',
#  (79, 102): 'Inside',
#  (79, 117): 'Inside',
#  (79, 122): 'Inside',
#  (80, 17): 'Inside',
#  (80, 48): 'Inside',
#  (80, 112): 'Inside',
#  (81, 10): 'Inside',
#  (81, 31): 'Inside',
#  (81, 124): 'Inside',
#  (82, 37): 'Inside',
#  (82, 56): 'Inside',
#  (82, 73): 'Inside',
#  (82, 79): 'Inside',
#  (82, 82): 'Inside',
#  (82, 88): 'Inside',
#  (82, 91): 'Inside',
#  (83, 48): 'Inside',
#  (83, 54): 'Inside',
#  (83, 106): 'Inside',
#  (83, 111): 'Inside',
#  (84, 13): 'Inside',
#  (84, 69): 'Inside',
#  (84, 78): 'Inside',
#  (84, 85): 'Inside',
#  (85, 36): 'Inside',
#  (85, 39): 'Inside',
#  (85, 123): 'Inside',
#  (86, 62): 'Inside',
#  (86, 100): 'Inside',
#  (87, 51): 'Inside',
#  (87, 77): 'Inside',
#  (87, 84): 'Inside',
#  (87, 122): 'Inside',
#  (88, 22): 'Inside',
#  (88, 36): 'Inside',
#  (88, 57): 'Inside',
#  (88, 65): 'Inside',
#  (88, 86): 'Inside',
#  (88, 96): 'Inside',
#  (89, 24): 'Inside',
#  (89, 94): 'Inside',
#  (89, 101): 'Inside',
#  (90, 34): 'Inside',
#  (90, 54): 'Inside',
#  (90, 74): 'Inside',
#  (90, 89): 'Inside',
#  (91, 91): 'Inside',
#  (92, 125): 'Inside',
#  (93, 38): 'Inside',
#  (93, 44): 'Inside',
#  (93, 54): 'Inside',
#  (94, 18): 'Inside',
#  (94, 71): 'Inside',
#  (95, 39): 'Inside',
#  (95, 50): 'Inside',
#  (95, 53): 'Inside',
#  (95, 63): 'Inside',
#  (95, 88): 'Inside',
#  (95, 104): 'Inside',
#  (95, 129): 'Inside',
#  (96, 91): 'Inside',
#  (97, 87): 'Inside',
#  (97, 108): 'Inside',
#  (98, 47): 'Inside',
#  (98, 57): 'Inside',
#  (98, 90): 'Inside',
#  (98, 94): 'Inside',
#  (99, 36): 'Inside',
#  (99, 123): 'Inside',
#  (99, 124): 'Inside',
#  (100, 42): 'Inside',
#  (100, 54): 'Inside',
#  (100, 60): 'Inside',
#  (100, 100): 'Inside',
#  (101, 39): 'Inside',
#  (101, 61): 'Inside',
#  (101, 72): 'Inside',
#  (102, 38): 'Inside',
#  (102, 46): 'Inside',
#  (102, 51): 'Inside',
#  (102, 75): 'Inside',
#  (102, 83): 'Inside',
#  (102, 95): 'Inside',
#  (102, 112): 'Inside',
#  (103, 32): 'Inside',
#  (103, 68): 'Inside',
#  (103, 69): 'Inside',
#  (103, 113): 'Inside',
#  (103, 116): 'Inside',
#  (104, 23): 'Inside',
#  (104, 39): 'Inside',
#  (104, 63): 'Inside',
#  (104, 64): 'Inside',
#  (104, 67): 'Inside',
#  (104, 68): 'Inside',
#  (104, 107): 'Inside',
#  (104, 120): 'Inside',
#  (105, 120): 'Inside',
#  (106, 38): 'Inside',
#  (106, 84): 'Inside',
#  (106, 91): 'Inside',
#  (106, 94): 'Inside',
#  (107, 16): 'Inside',
#  (107, 19): 'Inside',
#  (107, 117): 'Inside',
#  (108, 53): 'Inside',
#  (109, 35): 'Inside',
#  (109, 38): 'Inside',
#  (109, 114): 'Inside',
#  (110, 45): 'Inside',
#  (110, 76): 'Inside',
#  (110, 90): 'Inside',
#  (111, 84): 'Inside',
#  (111, 102): 'Inside',
#  (112, 27): 'Inside',
#  (112, 34): 'Inside',
#  (112, 59): 'Inside',
#  (112, 89): 'Inside',
#  (112, 96): 'Inside',
#  (112, 107): 'Inside',
#  (112, 114): 'Inside',
#  (113, 51): 'Inside',
#  (113, 113): 'Inside',
#  (114, 44): 'Inside',
#  (114, 100): 'Inside',
#  (114, 111): 'Inside',
#  (115, 70): 'Inside',
#  (115, 76): 'Inside',
#  (115, 79): 'Inside',
#  (115, 87): 'Inside',
#  (116, 58): 'Inside',
#  (116, 108): 'Inside',
#  (117, 43): 'Inside',
#  (117, 50): 'Inside',
#  (117, 67): 'Inside',
#  (117, 88): 'Inside',
#  (117, 100): 'Inside',
#  (117, 109): 'Inside',
#  (118, 36): 'Inside',
#  (118, 76): 'Inside',
#  (118, 87): 'Inside',
#  (119, 72): 'Inside',
#  (119, 75): 'Inside',
#  (119, 118): 'Inside',
#  (119, 121): 'Inside',
#  (120, 53): 'Inside',
#  (120, 81): 'Inside',
#  (121, 59): 'Inside',
#  (121, 76): 'Inside',
#  (121, 101): 'Inside',
#  (121, 108): 'Inside',
#  (122, 22): 'Inside',
#  (122, 25): 'Inside',
#  (122, 30): 'Inside',
#  (122, 59): 'Inside',
#  (123, 34): 'Inside',
#  (123, 45): 'Inside',
#  (123, 59): 'Inside',
#  (123, 102): 'Inside',
#  (123, 107): 'Inside',
#  (124, 88): 'Inside',
#  (124, 94): 'Inside',
#  (124, 98): 'Inside',
#  (125, 30): 'Inside',
#  (126, 64): 'Inside',
#  (126, 81): 'Inside',
#  (126, 107): 'Inside',
#  (127, 98): 'Inside',
#  (128, 82): 'Inside',
#  (128, 89): 'Inside',
#  (128, 103): 'Inside',
#  (130, 32): 'Inside',
#  (130, 38): 'Inside',
#  (130, 80): 'Inside',
#  (130, 81): 'Inside',
#  (130, 87): 'Inside',
#  (130, 88): 'Inside',
#  (130, 99): 'Inside',
#  (130, 100): 'Inside',
#  (131, 38): 'Inside',
#  (131, 81): 'Inside',
#  (131, 99): 'Inside',
#  (132, 31): 'Inside',
#  (132, 95): 'Inside'}

# %%
for row in range(140):
    for col in range(140):
        if outcome_dict[(row, col)] == "Outside":
            outcome_dict = spread_outside(row, col, outcome_dict)
# Out:
# Spreading from 0, 1 to 1,1
# Spreading from 1, 1 to 2,1
# Spreading from 2, 1 to 3,1
# Spreading from 3, 1 to 4,1
# Spreading from 4, 1 to 5,1
# Spreading from 5, 1 to 6,1
# Spreading from 6, 1 to 7,1
# Spreading from 7, 1 to 8,1
# Spreading from 8, 1 to 9,1
# Spreading from 9, 1 to 10,1
# Spreading from 10, 1 to 11,1
# Spreading from 11, 1 to 12,1
# Spreading from 12, 1 to 13,1
# Spreading from 13, 1 to 14,1
# Spreading from 14, 1 to 15,1
# Spreading from 15, 1 to 16,1
# Spreading from 16, 1 to 17,1
# Spreading from 17, 1 to 18,1
# Spreading from 18, 1 to 19,1
# Spreading from 19, 1 to 20,1
# Spreading from 20, 1 to 21,1
# Spreading from 21, 1 to 22,1
# Spreading from 22, 1 to 23,1
# Spreading from 23, 1 to 24,1
# Spreading from 24, 1 to 25,1
# Spreading from 25, 1 to 26,1
# Spreading from 26, 1 to 27,1
# Spreading from 27, 1 to 28,1
# Spreading from 28, 1 to 29,1
# Spreading from 29, 1 to 30,1
# Spreading from 30, 1 to 31,1
# Spreading from 31, 1 to 32,1
# Spreading from 32, 1 to 33,1
# Spreading from 33, 1 to 34,1
# Spreading from 34, 1 to 35,1
# Spreading from 35, 1 to 36,1
# Spreading from 36, 1 to 37,1
# Spreading from 37, 1 to 37,2
# Spreading from 37, 2 to 36,2
# Spreading from 36, 2 to 36,3
# Spreading from 37, 2 to 38,2
# Spreading from 33, 1 to 33,2
# Spreading from 33, 2 to 32,2
# Spreading from 32, 2 to 31,2
# Spreading from 31, 2 to 30,2
# Spreading from 30, 2 to 29,2
# Spreading from 29, 2 to 28,2
# Spreading from 28, 2 to 27,2
# Spreading from 27, 2 to 26,2
# Spreading from 26, 2 to 25,2
# Spreading from 25, 2 to 24,2
# Spreading from 24, 2 to 23,2
# Spreading from 23, 2 to 22,2
# Spreading from 22, 2 to 21,2
# Spreading from 21, 2 to 20,2
# Spreading from 20, 2 to 19,2
# Spreading from 19, 2 to 18,2
# Spreading from 18, 2 to 17,2
# Spreading from 17, 2 to 16,2
# Spreading from 16, 2 to 15,2
# Spreading from 15, 2 to 14,2
# Spreading from 14, 2 to 13,2
# Spreading from 13, 2 to 12,2
# Spreading from 12, 2 to 11,2
# Spreading from 11, 2 to 10,2
# Spreading from 10, 2 to 9,2
# Spreading from 9, 2 to 8,2
# Spreading from 8, 2 to 7,2
# Spreading from 7, 2 to 6,2
# Spreading from 6, 2 to 5,2
# Spreading from 5, 2 to 4,2
# Spreading from 4, 2 to 3,2
# Spreading from 3, 2 to 2,2
# Spreading from 2, 2 to 1,2
# Spreading from 1, 2 to 1,3
# Spreading from 1, 3 to 2,3
# Spreading from 2, 3 to 3,3
# Spreading from 3, 3 to 4,3
# Spreading from 4, 3 to 5,3
# Spreading from 5, 3 to 6,3
# Spreading from 6, 3 to 7,3
# Spreading from 7, 3 to 8,3
# Spreading from 8, 3 to 9,3
# Spreading from 9, 3 to 10,3
# Spreading from 10, 3 to 11,3
# Spreading from 11, 3 to 12,3
# Spreading from 12, 3 to 13,3
# Spreading from 13, 3 to 14,3
# Spreading from 14, 3 to 15,3
# Spreading from 15, 3 to 16,3
# Spreading from 16, 3 to 17,3
# Spreading from 17, 3 to 18,3
# Spreading from 18, 3 to 19,3
# Spreading from 19, 3 to 20,3
# Spreading from 20, 3 to 21,3
# Spreading from 21, 3 to 22,3
# Spreading from 22, 3 to 23,3
# Spreading from 23, 3 to 24,3
# Spreading from 24, 3 to 25,3
# Spreading from 25, 3 to 26,3
# Spreading from 26, 3 to 27,3
# Spreading from 27, 3 to 28,3
# Spreading from 28, 3 to 29,3
# Spreading from 29, 3 to 30,3
# Spreading from 30, 3 to 31,3
# Spreading from 31, 3 to 32,3
# Spreading from 32, 3 to 33,3
# Spreading from 32, 3 to 32,4
# Spreading from 32, 4 to 31,4
# Spreading from 31, 4 to 30,4
# Spreading from 30, 4 to 29,4
# Spreading from 29, 4 to 28,4
# Spreading from 28, 4 to 27,4
# Spreading from 27, 4 to 26,4
# Spreading from 26, 4 to 25,4
# Spreading from 25, 4 to 24,4
# Spreading from 24, 4 to 23,4
# Spreading from 23, 4 to 22,4
# Spreading from 22, 4 to 21,4
# Spreading from 21, 4 to 20,4
# Spreading from 20, 4 to 19,4
# Spreading from 19, 4 to 18,4
# Spreading from 18, 4 to 17,4
# Spreading from 17, 4 to 16,4
# Spreading from 16, 4 to 15,4
# Spreading from 15, 4 to 14,4
# Spreading from 14, 4 to 13,4
# Spreading from 13, 4 to 12,4
# Spreading from 12, 4 to 11,4
# Spreading from 11, 4 to 10,4
# Spreading from 10, 4 to 9,4
# Spreading from 9, 4 to 8,4
# Spreading from 8, 4 to 7,4
# Spreading from 7, 4 to 6,4
# Spreading from 6, 4 to 5,4
# Spreading from 5, 4 to 4,4
# Spreading from 4, 4 to 3,4
# Spreading from 3, 4 to 2,4
# Spreading from 2, 4 to 1,4
# Spreading from 1, 4 to 1,5
# Spreading from 1, 5 to 2,5
# Spreading from 2, 5 to 3,5
# Spreading from 3, 5 to 4,5
# Spreading from 4, 5 to 5,5
# Spreading from 5, 5 to 6,5
# Spreading from 6, 5 to 7,5
# Spreading from 7, 5 to 8,5
# Spreading from 8, 5 to 9,5
# Spreading from 9, 5 to 10,5
# Spreading from 10, 5 to 11,5
# Spreading from 11, 5 to 12,5
# Spreading from 12, 5 to 13,5
# Spreading from 13, 5 to 14,5
# Spreading from 14, 5 to 15,5
# Spreading from 15, 5 to 16,5
# Spreading from 16, 5 to 17,5
# Spreading from 17, 5 to 18,5
# Spreading from 18, 5 to 19,5
# Spreading from 19, 5 to 20,5
# Spreading from 20, 5 to 21,5
# Spreading from 21, 5 to 22,5
# Spreading from 22, 5 to 23,5
# Spreading from 23, 5 to 24,5
# Spreading from 24, 5 to 25,5
# Spreading from 25, 5 to 26,5
# Spreading from 26, 5 to 27,5
# Spreading from 27, 5 to 28,5
# Spreading from 28, 5 to 29,5
# Spreading from 29, 5 to 30,5
# Spreading from 30, 5 to 31,5
# Spreading from 31, 5 to 32,5
# Spreading from 32, 5 to 32,6
# Spreading from 32, 6 to 31,6
# Spreading from 31, 6 to 30,6
# Spreading from 30, 6 to 29,6
# Spreading from 29, 6 to 28,6
# Spreading from 28, 6 to 27,6
# Spreading from 27, 6 to 26,6
# Spreading from 26, 6 to 25,6
# Spreading from 25, 6 to 24,6
# Spreading from 24, 6 to 23,6
# Spreading from 23, 6 to 22,6
# Spreading from 22, 6 to 21,6
# Spreading from 21, 6 to 20,6
# Spreading from 20, 6 to 19,6
# Spreading from 19, 6 to 18,6
# Spreading from 18, 6 to 17,6
# Spreading from 17, 6 to 16,6
# Spreading from 16, 6 to 15,6
# Spreading from 15, 6 to 14,6
# Spreading from 14, 6 to 13,6
# Spreading from 13, 6 to 12,6
# Spreading from 12, 6 to 11,6
# Spreading from 11, 6 to 10,6
# Spreading from 10, 6 to 9,6
# Spreading from 9, 6 to 8,6
# Spreading from 8, 6 to 7,6
# Spreading from 7, 6 to 6,6
# Spreading from 6, 6 to 5,6
# Spreading from 5, 6 to 4,6
# Spreading from 4, 6 to 3,6
# Spreading from 3, 6 to 2,6
# Spreading from 2, 6 to 1,6
# Spreading from 1, 6 to 1,7
# Spreading from 1, 7 to 2,7
# Spreading from 2, 7 to 3,7
# Spreading from 3, 7 to 4,7
# Spreading from 4, 7 to 5,7
# Spreading from 5, 7 to 6,7
# Spreading from 6, 7 to 7,7
# Spreading from 7, 7 to 8,7
# Spreading from 8, 7 to 9,7
# Spreading from 9, 7 to 10,7
# Spreading from 10, 7 to 11,7
# Spreading from 11, 7 to 12,7
# Spreading from 12, 7 to 13,7
# Spreading from 13, 7 to 14,7
# Spreading from 14, 7 to 15,7
# Spreading from 15, 7 to 16,7
# Spreading from 16, 7 to 17,7
# Spreading from 17, 7 to 18,7
# Spreading from 18, 7 to 19,7
# Spreading from 19, 7 to 20,7
# Spreading from 20, 7 to 21,7
# Spreading from 21, 7 to 22,7
# Spreading from 22, 7 to 23,7
# Spreading from 23, 7 to 24,7
# Spreading from 24, 7 to 25,7
# Spreading from 25, 7 to 26,7
# Spreading from 26, 7 to 27,7
# Spreading from 27, 7 to 28,7
# Spreading from 28, 7 to 28,8
# Spreading from 28, 8 to 27,8
# Spreading from 27, 8 to 26,8
# Spreading from 26, 8 to 25,8
# Spreading from 25, 8 to 24,8
# Spreading from 24, 8 to 23,8
# Spreading from 23, 8 to 22,8
# Spreading from 22, 8 to 21,8
# Spreading from 21, 8 to 20,8
# Spreading from 20, 8 to 19,8
# Spreading from 19, 8 to 18,8
# Spreading from 18, 8 to 17,8
# Spreading from 17, 8 to 16,8
# Spreading from 16, 8 to 15,8
# Spreading from 15, 8 to 14,8
# Spreading from 14, 8 to 13,8
# Spreading from 13, 8 to 12,8
# Spreading from 12, 8 to 11,8
# Spreading from 11, 8 to 10,8
# Spreading from 10, 8 to 9,8
# Spreading from 9, 8 to 8,8
# Spreading from 8, 8 to 7,8
# Spreading from 7, 8 to 6,8
# Spreading from 6, 8 to 5,8
# Spreading from 5, 8 to 4,8
# Spreading from 4, 8 to 3,8
# Spreading from 3, 8 to 2,8
# Spreading from 2, 8 to 1,8
# Spreading from 1, 8 to 1,9
# Spreading from 1, 9 to 2,9
# Spreading from 2, 9 to 3,9
# Spreading from 3, 9 to 4,9
# Spreading from 4, 9 to 5,9
# Spreading from 5, 9 to 6,9
# Spreading from 6, 9 to 7,9
# Spreading from 7, 9 to 8,9
# Spreading from 8, 9 to 9,9
# Spreading from 9, 9 to 10,9
# Spreading from 10, 9 to 11,9
# Spreading from 11, 9 to 12,9
# Spreading from 12, 9 to 13,9
# Spreading from 13, 9 to 14,9
# Spreading from 14, 9 to 15,9
# Spreading from 15, 9 to 16,9
# Spreading from 16, 9 to 17,9
# Spreading from 17, 9 to 18,9
# Spreading from 18, 9 to 19,9
# Spreading from 19, 9 to 20,9
# Spreading from 20, 9 to 21,9
# Spreading from 21, 9 to 22,9
# Spreading from 22, 9 to 23,9
# Spreading from 23, 9 to 24,9
# Spreading from 24, 9 to 25,9
# Spreading from 25, 9 to 26,9
# Spreading from 26, 9 to 27,9
# Spreading from 27, 9 to 27,10
# Spreading from 27, 10 to 26,10
# Spreading from 26, 10 to 25,10
# Spreading from 25, 10 to 24,10
# Spreading from 24, 10 to 23,10
# Spreading from 23, 10 to 22,10
# Spreading from 22, 10 to 21,10
# Spreading from 21, 10 to 20,10
# Spreading from 20, 10 to 19,10
# Spreading from 19, 10 to 18,10
# Spreading from 18, 10 to 17,10
# Spreading from 17, 10 to 16,10
# Spreading from 16, 10 to 15,10
# Spreading from 15, 10 to 14,10
# Spreading from 14, 10 to 13,10
# Spreading from 13, 10 to 12,10
# Spreading from 12, 10 to 11,10
# Spreading from 11, 10 to 10,10
# Spreading from 10, 10 to 9,10
# Spreading from 9, 10 to 8,10
# Spreading from 8, 10 to 7,10
# Spreading from 7, 10 to 6,10
# Spreading from 6, 10 to 5,10
# Spreading from 5, 10 to 4,10
# Spreading from 4, 10 to 3,10
# Spreading from 3, 10 to 2,10
# Spreading from 2, 10 to 1,10
# Spreading from 1, 10 to 1,11
# Spreading from 1, 11 to 2,11
# Spreading from 2, 11 to 3,11
# Spreading from 3, 11 to 4,11
# Spreading from 4, 11 to 5,11
# Spreading from 5, 11 to 6,11
# Spreading from 6, 11 to 7,11
# Spreading from 7, 11 to 8,11
# Spreading from 8, 11 to 9,11
# Spreading from 9, 11 to 10,11
# Spreading from 10, 11 to 11,11
# Spreading from 11, 11 to 12,11
# Spreading from 12, 11 to 13,11
# Spreading from 13, 11 to 14,11
# Spreading from 14, 11 to 15,11
# Spreading from 15, 11 to 16,11
# Spreading from 16, 11 to 17,11
# Spreading from 17, 11 to 18,11
# Spreading from 18, 11 to 19,11
# Spreading from 19, 11 to 20,11
# Spreading from 20, 11 to 21,11
# Spreading from 21, 11 to 22,11
# Spreading from 22, 11 to 23,11
# Spreading from 23, 11 to 24,11
# Spreading from 24, 11 to 25,11
# Spreading from 25, 11 to 26,11
# Spreading from 23, 11 to 23,12
# Spreading from 23, 12 to 22,12
# Spreading from 22, 12 to 21,12
# Spreading from 21, 12 to 20,12
# Spreading from 20, 12 to 19,12
# Spreading from 19, 12 to 18,12
# Spreading from 18, 12 to 17,12
# Spreading from 17, 12 to 16,12
# Spreading from 16, 12 to 16,13
# Spreading from 16, 13 to 17,13
# Spreading from 17, 13 to 18,13
# Spreading from 18, 13 to 19,13
# Spreading from 19, 13 to 20,13
# Spreading from 20, 13 to 21,13
# Spreading from 21, 13 to 22,13
# Spreading from 22, 13 to 22,14
# Spreading from 22, 14 to 21,14
# Spreading from 18, 13 to 18,14
# Spreading from 13, 11 to 13,12
# Spreading from 13, 12 to 12,12
# Spreading from 12, 12 to 11,12
# Spreading from 11, 12 to 10,12
# Spreading from 10, 12 to 9,12
# Spreading from 9, 12 to 8,12
# Spreading from 8, 12 to 7,12
# Spreading from 7, 12 to 6,12
# Spreading from 6, 12 to 5,12
# Spreading from 5, 12 to 4,12
# Spreading from 4, 12 to 3,12
# Spreading from 3, 12 to 2,12
# Spreading from 2, 12 to 1,12
# Spreading from 1, 12 to 1,13
# Spreading from 1, 13 to 2,13
# Spreading from 2, 13 to 3,13
# Spreading from 3, 13 to 4,13
# Spreading from 4, 13 to 5,13
# Spreading from 5, 13 to 6,13
# Spreading from 6, 13 to 7,13
# Spreading from 7, 13 to 8,13
# Spreading from 8, 13 to 9,13
# Spreading from 9, 13 to 10,13
# Spreading from 10, 13 to 11,13
# Spreading from 11, 13 to 12,13
# Spreading from 12, 13 to 12,14
# Spreading from 12, 14 to 11,14
# Spreading from 11, 14 to 10,14
# Spreading from 10, 14 to 9,14
# Spreading from 9, 14 to 8,14
# Spreading from 8, 14 to 7,14
# Spreading from 7, 14 to 6,14
# Spreading from 6, 14 to 5,14
# Spreading from 5, 14 to 4,14
# Spreading from 4, 14 to 3,14
# Spreading from 3, 14 to 2,14
# Spreading from 2, 14 to 1,14
# Spreading from 1, 14 to 1,15
# Spreading from 1, 15 to 2,15
# Spreading from 2, 15 to 3,15
# Spreading from 3, 15 to 4,15
# Spreading from 4, 15 to 5,15
# Spreading from 5, 15 to 6,15
# Spreading from 6, 15 to 7,15
# Spreading from 7, 15 to 8,15
# Spreading from 8, 15 to 9,15
# Spreading from 9, 15 to 10,15
# Spreading from 10, 15 to 10,16
# Spreading from 10, 16 to 9,16
# Spreading from 9, 16 to 8,16
# Spreading from 8, 16 to 7,16
# Spreading from 7, 16 to 6,16
# Spreading from 6, 16 to 5,16
# Spreading from 5, 16 to 4,16
# Spreading from 4, 16 to 3,16
# Spreading from 3, 16 to 2,16
# Spreading from 2, 16 to 1,16
# Spreading from 1, 16 to 1,17
# Spreading from 1, 17 to 2,17
# Spreading from 2, 17 to 3,17
# Spreading from 3, 17 to 4,17
# Spreading from 4, 17 to 5,17
# Spreading from 5, 17 to 6,17
# Spreading from 6, 17 to 7,17
# Spreading from 7, 17 to 8,17
# Spreading from 8, 17 to 9,17
# Spreading from 9, 17 to 10,17
# Spreading from 10, 17 to 11,17
# Spreading from 11, 17 to 12,17
# Spreading from 12, 17 to 13,17
# Spreading from 13, 17 to 13,18
# Spreading from 13, 18 to 12,18
# Spreading from 12, 18 to 12,19
# Spreading from 12, 19 to 13,19
# Spreading from 13, 19 to 14,19
# Spreading from 14, 19 to 15,19
# Spreading from 15, 19 to 15,20
# Spreading from 15, 20 to 16,20
# Spreading from 15, 19 to 15,18
# Spreading from 15, 18 to 14,18
# Spreading from 12, 19 to 12,20
# Spreading from 12, 20 to 11,20
# Spreading from 8, 17 to 8,18
# Spreading from 8, 18 to 7,18
# Spreading from 7, 18 to 6,18
# Spreading from 6, 18 to 5,18
# Spreading from 5, 18 to 4,18
# Spreading from 4, 18 to 3,18
# Spreading from 3, 18 to 2,18
# Spreading from 2, 18 to 1,18
# Spreading from 1, 18 to 1,19
# Spreading from 1, 19 to 2,19
# Spreading from 2, 19 to 3,19
# Spreading from 3, 19 to 4,19
# Spreading from 4, 19 to 5,19
# Spreading from 5, 19 to 6,19
# Spreading from 6, 19 to 7,19
# Spreading from 7, 19 to 8,19
# Spreading from 8, 19 to 8,20
# Spreading from 8, 20 to 7,20
# Spreading from 7, 20 to 6,20
# Spreading from 6, 20 to 5,20
# Spreading from 5, 20 to 4,20
# Spreading from 4, 20 to 3,20
# Spreading from 3, 20 to 2,20
# Spreading from 2, 20 to 1,20
# Spreading from 1, 20 to 1,21
# Spreading from 1, 21 to 2,21
# Spreading from 2, 21 to 3,21
# Spreading from 3, 21 to 4,21
# Spreading from 4, 21 to 5,21
# Spreading from 5, 21 to 5,22
# Spreading from 5, 22 to 4,22
# Spreading from 4, 22 to 3,22
# Spreading from 3, 22 to 2,22
# Spreading from 2, 22 to 1,22
# Spreading from 1, 22 to 1,23
# Spreading from 1, 23 to 2,23
# Spreading from 2, 23 to 2,24
# Spreading from 2, 24 to 1,24
# Spreading from 1, 24 to 1,25
# Spreading from 1, 25 to 2,25
# Spreading from 2, 25 to 3,25
# Spreading from 3, 25 to 3,26
# Spreading from 3, 26 to 2,26
# Spreading from 2, 26 to 1,26
# Spreading from 1, 26 to 1,27
# Spreading from 1, 27 to 2,27
# Spreading from 2, 27 to 3,27
# Spreading from 3, 27 to 3,28
# Spreading from 3, 28 to 2,28
# Spreading from 2, 28 to 1,28
# Spreading from 1, 28 to 1,29
# Spreading from 1, 29 to 2,29
# Spreading from 2, 29 to 3,29
# Spreading from 3, 29 to 4,29
# Spreading from 4, 29 to 4,30
# Spreading from 4, 30 to 3,30
# Spreading from 3, 30 to 2,30
# Spreading from 2, 30 to 1,30
# Spreading from 1, 30 to 1,31
# Spreading from 1, 31 to 2,31
# Spreading from 2, 31 to 3,31
# Spreading from 3, 31 to 4,31
# Spreading from 4, 31 to 4,32
# Spreading from 4, 32 to 3,32
# Spreading from 3, 32 to 2,32
# Spreading from 2, 32 to 1,32
# Spreading from 1, 32 to 1,33
# Spreading from 1, 33 to 2,33
# Spreading from 2, 33 to 3,33
# Spreading from 3, 33 to 4,33
# Spreading from 4, 33 to 5,33
# Spreading from 5, 33 to 5,34
# Spreading from 5, 34 to 4,34
# Spreading from 4, 34 to 3,34
# Spreading from 3, 34 to 2,34
# Spreading from 2, 34 to 1,34
# Spreading from 1, 34 to 1,35
# Spreading from 1, 35 to 2,35
# Spreading from 2, 35 to 3,35
# Spreading from 3, 35 to 4,35
# Spreading from 4, 35 to 4,36
# Spreading from 4, 36 to 3,36
# Spreading from 3, 36 to 2,36
# Spreading from 2, 36 to 1,36
# Spreading from 1, 36 to 1,37
# Spreading from 1, 37 to 2,37
# Spreading from 2, 37 to 3,37
# Spreading from 3, 37 to 4,37
# Spreading from 4, 37 to 5,37
# Spreading from 5, 37 to 6,37
# Spreading from 6, 37 to 7,37
# Spreading from 3, 37 to 3,38
# Spreading from 3, 38 to 2,38
# Spreading from 2, 38 to 1,38
# Spreading from 1, 38 to 1,39
# Spreading from 1, 39 to 2,39
# Spreading from 2, 39 to 3,39
# Spreading from 3, 39 to 3,40
# Spreading from 3, 40 to 2,40
# Spreading from 2, 40 to 1,40
# Spreading from 1, 40 to 1,41
# Spreading from 1, 41 to 2,41
# Spreading from 2, 41 to 3,41
# Spreading from 3, 41 to 4,41
# Spreading from 4, 41 to 5,41
# Spreading from 5, 41 to 6,41
# Spreading from 6, 41 to 6,42
# Spreading from 6, 42 to 5,42
# Spreading from 5, 42 to 4,42
# Spreading from 4, 42 to 3,42
# Spreading from 3, 42 to 2,42
# Spreading from 2, 42 to 1,42
# Spreading from 1, 42 to 1,43
# Spreading from 1, 43 to 2,43
# Spreading from 2, 43 to 3,43
# Spreading from 3, 43 to 4,43
# Spreading from 4, 43 to 5,43
# Spreading from 5, 43 to 6,43
# Spreading from 6, 43 to 6,44
# Spreading from 6, 44 to 5,44
# Spreading from 5, 44 to 4,44
# Spreading from 4, 44 to 3,44
# Spreading from 3, 44 to 2,44
# Spreading from 2, 44 to 1,44
# Spreading from 1, 44 to 1,45
# Spreading from 1, 45 to 2,45
# Spreading from 2, 45 to 3,45
# Spreading from 3, 45 to 4,45
# Spreading from 4, 45 to 5,45
# Spreading from 5, 45 to 6,45
# Spreading from 6, 45 to 7,45
# Spreading from 7, 45 to 7,46
# Spreading from 7, 46 to 6,46
# Spreading from 6, 46 to 5,46
# Spreading from 5, 46 to 4,46
# Spreading from 4, 46 to 3,46
# Spreading from 3, 46 to 2,46
# Spreading from 2, 46 to 1,46
# Spreading from 1, 46 to 1,47
# Spreading from 1, 47 to 2,47
# Spreading from 2, 47 to 3,47
# Spreading from 3, 47 to 4,47
# Spreading from 4, 47 to 5,47
# Spreading from 5, 47 to 6,47
# Spreading from 6, 47 to 7,47
# Spreading from 7, 47 to 8,47
# Spreading from 8, 47 to 8,48
# Spreading from 8, 48 to 7,48
# Spreading from 7, 48 to 6,48
# Spreading from 6, 48 to 5,48
# Spreading from 5, 48 to 4,48
# Spreading from 4, 48 to 3,48
# Spreading from 3, 48 to 2,48
# Spreading from 2, 48 to 1,48
# Spreading from 1, 48 to 1,49
# Spreading from 1, 49 to 2,49
# Spreading from 2, 49 to 3,49
# Spreading from 3, 49 to 4,49
# Spreading from 4, 49 to 5,49
# Spreading from 5, 49 to 6,49
# Spreading from 6, 49 to 7,49
# Spreading from 7, 49 to 7,50
# Spreading from 7, 50 to 6,50
# Spreading from 6, 50 to 5,50
# Spreading from 5, 50 to 4,50
# Spreading from 4, 50 to 3,50
# Spreading from 3, 50 to 2,50
# Spreading from 2, 50 to 1,50
# Spreading from 1, 50 to 1,51
# Spreading from 1, 51 to 2,51
# Spreading from 2, 51 to 3,51
# Spreading from 3, 51 to 4,51
# Spreading from 4, 51 to 5,51
# Spreading from 5, 51 to 6,51
# Spreading from 6, 51 to 7,51
# Spreading from 7, 51 to 7,52
# Spreading from 7, 52 to 6,52
# Spreading from 6, 52 to 5,52
# Spreading from 5, 52 to 4,52
# Spreading from 4, 52 to 3,52
# Spreading from 3, 52 to 2,52
# Spreading from 2, 52 to 1,52
# Spreading from 1, 52 to 1,53
# Spreading from 1, 53 to 2,53
# Spreading from 2, 53 to 3,53
# Spreading from 3, 53 to 4,53
# Spreading from 4, 53 to 5,53
# Spreading from 5, 53 to 6,53
# Spreading from 6, 53 to 6,54
# Spreading from 6, 54 to 5,54
# Spreading from 5, 54 to 4,54
# Spreading from 4, 54 to 3,54
# Spreading from 3, 54 to 2,54
# Spreading from 2, 54 to 1,54
# Spreading from 1, 54 to 1,55
# Spreading from 1, 55 to 2,55
# Spreading from 2, 55 to 3,55
# Spreading from 3, 55 to 4,55
# Spreading from 4, 55 to 5,55
# Spreading from 5, 55 to 6,55
# Spreading from 6, 55 to 7,55
# Spreading from 7, 55 to 7,56
# Spreading from 7, 56 to 6,56
# Spreading from 6, 56 to 5,56
# Spreading from 5, 56 to 4,56
# Spreading from 4, 56 to 3,56
# Spreading from 3, 56 to 2,56
# Spreading from 2, 56 to 1,56
# Spreading from 1, 56 to 1,57
# Spreading from 1, 57 to 2,57
# Spreading from 2, 57 to 3,57
# Spreading from 3, 57 to 4,57
# Spreading from 4, 57 to 5,57
# Spreading from 5, 57 to 6,57
# Spreading from 6, 57 to 6,58
# Spreading from 6, 58 to 5,58
# Spreading from 5, 58 to 4,58
# Spreading from 4, 58 to 3,58
# Spreading from 3, 58 to 2,58
# Spreading from 2, 58 to 1,58
# Spreading from 1, 58 to 1,59
# Spreading from 1, 59 to 2,59
# Spreading from 2, 59 to 3,59
# Spreading from 3, 59 to 4,59
# Spreading from 4, 59 to 5,59
# Spreading from 5, 59 to 5,60
# Spreading from 5, 60 to 4,60
# Spreading from 4, 60 to 3,60
# Spreading from 3, 60 to 2,60
# Spreading from 2, 60 to 1,60
# Spreading from 1, 60 to 1,61
# Spreading from 1, 61 to 2,61
# Spreading from 2, 61 to 3,61
# Spreading from 3, 61 to 4,61
# Spreading from 4, 61 to 5,61
# Spreading from 5, 61 to 6,61
# Spreading from 6, 61 to 7,61
# Spreading from 7, 61 to 7,62
# Spreading from 7, 62 to 6,62
# Spreading from 6, 62 to 5,62
# Spreading from 5, 62 to 4,62
# Spreading from 4, 62 to 3,62
# Spreading from 3, 62 to 2,62
# Spreading from 2, 62 to 1,62
# Spreading from 1, 62 to 1,63
# Spreading from 1, 63 to 2,63
# Spreading from 2, 63 to 3,63
# Spreading from 3, 63 to 4,63
# Spreading from 4, 63 to 5,63
# Spreading from 5, 63 to 6,63
# Spreading from 6, 63 to 7,63
# Spreading from 7, 63 to 7,64
# Spreading from 7, 64 to 6,64
# Spreading from 6, 64 to 5,64
# Spreading from 5, 64 to 4,64
# Spreading from 4, 64 to 3,64
# Spreading from 3, 64 to 2,64
# Spreading from 2, 64 to 1,64
# Spreading from 1, 64 to 1,65
# Spreading from 1, 65 to 2,65
# Spreading from 2, 65 to 3,65
# Spreading from 3, 65 to 4,65
# Spreading from 4, 65 to 5,65
# Spreading from 5, 65 to 6,65
# Spreading from 6, 65 to 7,65
# Spreading from 7, 65 to 7,66
# Spreading from 7, 66 to 6,66
# Spreading from 6, 66 to 5,66
# Spreading from 5, 66 to 4,66
# Spreading from 4, 66 to 3,66
# Spreading from 3, 66 to 2,66
# Spreading from 2, 66 to 1,66
# Spreading from 1, 66 to 1,67
# Spreading from 1, 67 to 2,67
# Spreading from 2, 67 to 3,67
# Spreading from 3, 67 to 4,67
# Spreading from 4, 67 to 5,67
# Spreading from 5, 67 to 6,67
# Spreading from 6, 67 to 7,67
# Spreading from 7, 67 to 8,67
# Spreading from 8, 67 to 9,67
# Spreading from 8, 67 to 8,68
# Spreading from 8, 68 to 7,68
# Spreading from 7, 68 to 6,68
# Spreading from 6, 68 to 5,68
# Spreading from 5, 68 to 4,68
# Spreading from 4, 68 to 3,68
# Spreading from 3, 68 to 2,68
# Spreading from 2, 68 to 1,68
# Spreading from 1, 68 to 1,69
# Spreading from 1, 69 to 2,69
# Spreading from 2, 69 to 3,69
# Spreading from 3, 69 to 4,69
# Spreading from 4, 69 to 5,69
# Spreading from 5, 69 to 6,69
# Spreading from 6, 69 to 7,69
# Spreading from 7, 69 to 8,69
# Spreading from 8, 69 to 8,70
# Spreading from 8, 70 to 7,70
# Spreading from 7, 70 to 6,70
# Spreading from 6, 70 to 5,70
# Spreading from 5, 70 to 4,70
# Spreading from 4, 70 to 3,70
# Spreading from 3, 70 to 2,70
# Spreading from 2, 70 to 1,70
# Spreading from 1, 70 to 1,71
# Spreading from 1, 71 to 2,71
# Spreading from 2, 71 to 3,71
# Spreading from 3, 71 to 4,71
# Spreading from 4, 71 to 5,71
# Spreading from 5, 71 to 6,71
# Spreading from 6, 71 to 7,71
# Spreading from 7, 71 to 8,71
# Spreading from 8, 71 to 9,71
# Spreading from 9, 71 to 10,71
# Spreading from 10, 71 to 10,72
# Spreading from 10, 72 to 9,72
# Spreading from 9, 72 to 8,72
# Spreading from 8, 72 to 7,72
# Spreading from 7, 72 to 6,72
# Spreading from 6, 72 to 5,72
# Spreading from 5, 72 to 4,72
# Spreading from 4, 72 to 3,72
# Spreading from 3, 72 to 2,72
# Spreading from 2, 72 to 1,72
# Spreading from 1, 72 to 1,73
# Spreading from 1, 73 to 2,73
# Spreading from 2, 73 to 3,73
# Spreading from 3, 73 to 4,73
# Spreading from 4, 73 to 5,73
# Spreading from 5, 73 to 6,73
# Spreading from 6, 73 to 7,73
# Spreading from 7, 73 to 8,73
# Spreading from 8, 73 to 9,73
# Spreading from 9, 73 to 10,73
# Spreading from 10, 73 to 11,73
# Spreading from 11, 73 to 11,72
# Spreading from 11, 72 to 12,72
# Spreading from 12, 72 to 13,72
# Spreading from 13, 72 to 14,72
# Spreading from 10, 73 to 10,74
# Spreading from 10, 74 to 9,74
# Spreading from 9, 74 to 8,74
# Spreading from 8, 74 to 7,74
# Spreading from 7, 74 to 6,74
# Spreading from 6, 74 to 5,74
# Spreading from 5, 74 to 4,74
# Spreading from 4, 74 to 3,74
# Spreading from 3, 74 to 2,74
# Spreading from 2, 74 to 1,74
# Spreading from 1, 74 to 1,75
# Spreading from 1, 75 to 2,75
# Spreading from 2, 75 to 3,75
# Spreading from 3, 75 to 4,75
# Spreading from 4, 75 to 4,76
# Spreading from 4, 76 to 3,76
# Spreading from 3, 76 to 2,76
# Spreading from 2, 76 to 1,76
# Spreading from 1, 76 to 1,77
# Spreading from 1, 77 to 2,77
# Spreading from 2, 77 to 3,77
# Spreading from 3, 77 to 4,77
# Spreading from 4, 77 to 5,77
# Spreading from 4, 77 to 4,78
# Spreading from 4, 78 to 3,78
# Spreading from 3, 78 to 2,78
# Spreading from 2, 78 to 1,78
# Spreading from 1, 78 to 1,79
# Spreading from 1, 79 to 2,79
# Spreading from 2, 79 to 3,79
# Spreading from 3, 79 to 4,79
# Spreading from 4, 79 to 4,80
# Spreading from 4, 80 to 3,80
# Spreading from 3, 80 to 2,80
# Spreading from 2, 80 to 1,80
# Spreading from 1, 80 to 1,81
# Spreading from 1, 81 to 2,81
# Spreading from 2, 81 to 3,81
# Spreading from 3, 81 to 4,81
# Spreading from 4, 81 to 5,81
# Spreading from 5, 81 to 6,81
# Spreading from 6, 81 to 6,82
# Spreading from 6, 82 to 5,82
# Spreading from 5, 82 to 4,82
# Spreading from 4, 82 to 3,82
# Spreading from 3, 82 to 2,82
# Spreading from 2, 82 to 1,82
# Spreading from 1, 82 to 1,83
# Spreading from 1, 83 to 2,83
# Spreading from 2, 83 to 3,83
# Spreading from 3, 83 to 4,83
# Spreading from 4, 83 to 5,83
# Spreading from 5, 83 to 6,83
# Spreading from 6, 83 to 6,84
# Spreading from 6, 84 to 5,84
# Spreading from 5, 84 to 4,84
# Spreading from 4, 84 to 3,84
# Spreading from 3, 84 to 2,84
# Spreading from 2, 84 to 1,84
# Spreading from 1, 84 to 1,85
# Spreading from 1, 85 to 2,85
# Spreading from 2, 85 to 3,85
# Spreading from 3, 85 to 4,85
# Spreading from 4, 85 to 5,85
# Spreading from 5, 85 to 5,86
# Spreading from 5, 86 to 4,86
# Spreading from 4, 86 to 3,86
# Spreading from 3, 86 to 2,86
# Spreading from 2, 86 to 1,86
# Spreading from 1, 86 to 1,87
# Spreading from 1, 87 to 2,87
# Spreading from 2, 87 to 3,87
# Spreading from 3, 87 to 4,87
# Spreading from 4, 87 to 4,88
# Spreading from 4, 88 to 3,88
# Spreading from 3, 88 to 2,88
# Spreading from 2, 88 to 1,88
# Spreading from 1, 88 to 1,89
# Spreading from 1, 89 to 2,89
# Spreading from 2, 89 to 3,89
# Spreading from 3, 89 to 4,89
# Spreading from 2, 89 to 2,90
# Spreading from 2, 90 to 1,90
# Spreading from 1, 90 to 1,91
# Spreading from 1, 91 to 2,91
# Spreading from 1, 91 to 1,92
# Spreading from 1, 92 to 1,93
# Spreading from 1, 93 to 1,94
# Spreading from 1, 94 to 2,94
# Spreading from 2, 94 to 2,95
# Spreading from 2, 95 to 1,95
# Spreading from 1, 95 to 1,96
# Spreading from 1, 96 to 2,96
# Spreading from 2, 96 to 3,96
# Spreading from 3, 96 to 4,96
# Spreading from 4, 96 to 4,97
# Spreading from 4, 97 to 3,97
# Spreading from 3, 97 to 2,97
# Spreading from 2, 97 to 1,97
# Spreading from 1, 97 to 1,98
# Spreading from 1, 98 to 2,98
# Spreading from 2, 98 to 3,98
# Spreading from 3, 98 to 4,98
# Spreading from 4, 98 to 4,99
# Spreading from 4, 99 to 3,99
# Spreading from 3, 99 to 2,99
# Spreading from 2, 99 to 1,99
# Spreading from 1, 99 to 1,100
# Spreading from 1, 100 to 2,100
# Spreading from 2, 100 to 3,100
# Spreading from 3, 100 to 4,100
# Spreading from 4, 100 to 5,100
# Spreading from 5, 100 to 6,100
# Spreading from 4, 100 to 4,101
# Spreading from 4, 101 to 3,101
# Spreading from 3, 101 to 2,101
# Spreading from 2, 101 to 1,101
# Spreading from 1, 101 to 1,102
# Spreading from 1, 102 to 2,102
# Spreading from 2, 102 to 3,102
# Spreading from 3, 102 to 4,102
# Spreading from 4, 102 to 4,103
# Spreading from 4, 103 to 3,103
# Spreading from 3, 103 to 2,103
# Spreading from 2, 103 to 1,103
# Spreading from 1, 103 to 1,104
# Spreading from 1, 104 to 2,104
# Spreading from 2, 104 to 3,104
# Spreading from 3, 104 to 4,104
# Spreading from 4, 104 to 5,104
# Spreading from 5, 104 to 5,105
# Spreading from 5, 105 to 4,105
# Spreading from 4, 105 to 3,105
# Spreading from 3, 105 to 2,105
# Spreading from 2, 105 to 1,105
# Spreading from 1, 105 to 1,106
# Spreading from 1, 106 to 2,106
# Spreading from 2, 106 to 3,106
# Spreading from 3, 106 to 4,106
# Spreading from 4, 106 to 5,106
# Spreading from 5, 106 to 6,106
# Spreading from 6, 106 to 7,106
# Spreading from 7, 106 to 7,107
# Spreading from 7, 107 to 6,107
# Spreading from 6, 107 to 5,107
# Spreading from 5, 107 to 4,107
# Spreading from 4, 107 to 3,107
# Spreading from 3, 107 to 2,107
# Spreading from 2, 107 to 1,107
# Spreading from 1, 107 to 1,108
# Spreading from 1, 108 to 2,108
# Spreading from 2, 108 to 3,108
# Spreading from 3, 108 to 4,108
# Spreading from 4, 108 to 5,108
# Spreading from 5, 108 to 6,108
# Spreading from 6, 108 to 7,108
# Spreading from 7, 108 to 8,108
# Spreading from 8, 108 to 8,109
# Spreading from 8, 109 to 7,109
# Spreading from 7, 109 to 6,109
# Spreading from 6, 109 to 5,109
# Spreading from 5, 109 to 4,109
# Spreading from 4, 109 to 3,109
# Spreading from 3, 109 to 2,109
# Spreading from 2, 109 to 1,109
# Spreading from 1, 109 to 1,110
# Spreading from 1, 110 to 2,110
# Spreading from 2, 110 to 3,110
# Spreading from 3, 110 to 4,110
# Spreading from 4, 110 to 5,110
# Spreading from 5, 110 to 6,110
# Spreading from 6, 110 to 7,110
# Spreading from 7, 110 to 8,110
# Spreading from 8, 110 to 9,110
# Spreading from 9, 110 to 10,110
# Spreading from 10, 110 to 10,111
# Spreading from 10, 111 to 9,111
# Spreading from 9, 111 to 8,111
# Spreading from 8, 111 to 7,111
# Spreading from 7, 111 to 6,111
# Spreading from 6, 111 to 5,111
# Spreading from 5, 111 to 4,111
# Spreading from 4, 111 to 3,111
# Spreading from 3, 111 to 2,111
# Spreading from 2, 111 to 1,111
# Spreading from 1, 111 to 1,112
# Spreading from 1, 112 to 2,112
# Spreading from 2, 112 to 3,112
# Spreading from 3, 112 to 4,112
# Spreading from 4, 112 to 5,112
# Spreading from 5, 112 to 6,112
# Spreading from 6, 112 to 7,112
# Spreading from 7, 112 to 8,112
# Spreading from 8, 112 to 9,112
# Spreading from 9, 112 to 10,112
# Spreading from 10, 112 to 11,112
# Spreading from 11, 112 to 12,112
# Spreading from 12, 112 to 12,113
# Spreading from 12, 113 to 11,113
# Spreading from 11, 113 to 10,113
# Spreading from 10, 113 to 9,113
# Spreading from 9, 113 to 8,113
# Spreading from 8, 113 to 7,113
# Spreading from 7, 113 to 6,113
# Spreading from 6, 113 to 5,113
# Spreading from 5, 113 to 4,113
# Spreading from 4, 113 to 3,113
# Spreading from 3, 113 to 2,113
# Spreading from 2, 113 to 1,113
# Spreading from 1, 113 to 1,114
# Spreading from 1, 114 to 2,114
# Spreading from 2, 114 to 3,114
# Spreading from 3, 114 to 4,114
# Spreading from 4, 114 to 5,114
# Spreading from 5, 114 to 6,114
# Spreading from 6, 114 to 7,114
# Spreading from 7, 114 to 8,114
# Spreading from 8, 114 to 9,114
# Spreading from 9, 114 to 10,114
# Spreading from 10, 114 to 11,114
# Spreading from 11, 114 to 12,114
# Spreading from 12, 114 to 13,114
# Spreading from 12, 114 to 12,115
# Spreading from 12, 115 to 11,115
# Spreading from 11, 115 to 10,115
# Spreading from 10, 115 to 9,115
# Spreading from 9, 115 to 8,115
# Spreading from 8, 115 to 7,115
# Spreading from 7, 115 to 6,115
# Spreading from 6, 115 to 5,115
# Spreading from 5, 115 to 4,115
# Spreading from 4, 115 to 3,115
# Spreading from 3, 115 to 2,115
# Spreading from 2, 115 to 1,115
# Spreading from 1, 115 to 1,116
# Spreading from 1, 116 to 2,116
# Spreading from 2, 116 to 3,116
# Spreading from 3, 116 to 4,116
# Spreading from 4, 116 to 5,116
# Spreading from 5, 116 to 6,116
# Spreading from 6, 116 to 7,116
# Spreading from 7, 116 to 8,116
# Spreading from 8, 116 to 9,116
# Spreading from 9, 116 to 10,116
# Spreading from 10, 116 to 11,116
# Spreading from 11, 116 to 12,116
# Spreading from 12, 116 to 12,117
# Spreading from 12, 117 to 11,117
# Spreading from 11, 117 to 10,117
# Spreading from 10, 117 to 9,117
# Spreading from 9, 117 to 8,117
# Spreading from 8, 117 to 7,117
# Spreading from 7, 117 to 6,117
# Spreading from 6, 117 to 5,117
# Spreading from 5, 117 to 4,117
# Spreading from 4, 117 to 3,117
# Spreading from 3, 117 to 2,117
# Spreading from 2, 117 to 1,117
# Spreading from 1, 117 to 1,118
# Spreading from 1, 118 to 2,118
# Spreading from 2, 118 to 3,118
# Spreading from 3, 118 to 4,118
# Spreading from 4, 118 to 5,118
# Spreading from 5, 118 to 6,118
# Spreading from 6, 118 to 7,118
# Spreading from 7, 118 to 8,118
# Spreading from 8, 118 to 9,118
# Spreading from 9, 118 to 10,118
# Spreading from 10, 118 to 11,118
# Spreading from 11, 118 to 12,118
# Spreading from 12, 118 to 13,118
# Spreading from 13, 118 to 14,118
# Spreading from 14, 118 to 15,118
# Spreading from 15, 118 to 16,118
# Spreading from 16, 118 to 17,118
# Spreading from 17, 118 to 18,118
# Spreading from 17, 118 to 17,119
# Spreading from 17, 119 to 16,119
# Spreading from 16, 119 to 15,119
# Spreading from 15, 119 to 14,119
# Spreading from 14, 119 to 13,119
# Spreading from 13, 119 to 12,119
# Spreading from 12, 119 to 11,119
# Spreading from 11, 119 to 10,119
# Spreading from 10, 119 to 9,119
# Spreading from 9, 119 to 8,119
# Spreading from 8, 119 to 7,119
# Spreading from 7, 119 to 6,119
# Spreading from 6, 119 to 5,119
# Spreading from 5, 119 to 4,119
# Spreading from 4, 119 to 3,119
# Spreading from 3, 119 to 2,119
# Spreading from 2, 119 to 1,119
# Spreading from 1, 119 to 1,120
# Spreading from 1, 120 to 2,120
# Spreading from 2, 120 to 3,120
# Spreading from 3, 120 to 4,120
# Spreading from 4, 120 to 5,120
# Spreading from 5, 120 to 6,120
# Spreading from 6, 120 to 7,120
# Spreading from 7, 120 to 8,120
# Spreading from 8, 120 to 9,120
# Spreading from 9, 120 to 10,120
# Spreading from 10, 120 to 11,120
# Spreading from 11, 120 to 12,120
# Spreading from 12, 120 to 13,120
# Spreading from 13, 120 to 14,120
# Spreading from 14, 120 to 15,120
# Spreading from 15, 120 to 16,120
# Spreading from 16, 120 to 17,120
# Spreading from 17, 120 to 17,121
# Spreading from 17, 121 to 16,121
# Spreading from 16, 121 to 15,121
# Spreading from 15, 121 to 14,121
# Spreading from 14, 121 to 13,121
# Spreading from 13, 121 to 12,121
# Spreading from 12, 121 to 11,121
# Spreading from 11, 121 to 10,121
# Spreading from 10, 121 to 9,121
# Spreading from 9, 121 to 8,121
# Spreading from 8, 121 to 7,121
# Spreading from 7, 121 to 6,121
# Spreading from 6, 121 to 5,121
# Spreading from 5, 121 to 4,121
# Spreading from 4, 121 to 3,121
# Spreading from 3, 121 to 2,121
# Spreading from 2, 121 to 1,121
# Spreading from 1, 121 to 1,122
# Spreading from 1, 122 to 2,122
# Spreading from 2, 122 to 3,122
# Spreading from 3, 122 to 4,122
# Spreading from 4, 122 to 5,122
# Spreading from 5, 122 to 6,122
# Spreading from 6, 122 to 7,122
# Spreading from 7, 122 to 8,122
# Spreading from 8, 122 to 9,122
# Spreading from 9, 122 to 10,122
# Spreading from 10, 122 to 11,122
# Spreading from 11, 122 to 12,122
# Spreading from 12, 122 to 13,122
# Spreading from 13, 122 to 14,122
# Spreading from 14, 122 to 15,122
# Spreading from 15, 122 to 16,122
# Spreading from 16, 122 to 17,122
# Spreading from 17, 122 to 18,122
# Spreading from 18, 122 to 18,123
# Spreading from 18, 123 to 17,123
# Spreading from 17, 123 to 16,123
# Spreading from 16, 123 to 15,123
# Spreading from 15, 123 to 14,123
# Spreading from 14, 123 to 13,123
# Spreading from 13, 123 to 12,123
# Spreading from 12, 123 to 11,123
# Spreading from 11, 123 to 10,123
# Spreading from 10, 123 to 9,123
# Spreading from 9, 123 to 8,123
# Spreading from 8, 123 to 7,123
# Spreading from 7, 123 to 6,123
# Spreading from 6, 123 to 5,123
# Spreading from 5, 123 to 4,123
# Spreading from 4, 123 to 3,123
# Spreading from 3, 123 to 2,123
# Spreading from 2, 123 to 1,123
# Spreading from 1, 123 to 1,124
# Spreading from 1, 124 to 2,124
# Spreading from 2, 124 to 3,124
# Spreading from 3, 124 to 4,124
# Spreading from 4, 124 to 5,124
# Spreading from 5, 124 to 6,124
# Spreading from 6, 124 to 7,124
# Spreading from 7, 124 to 8,124
# Spreading from 8, 124 to 9,124
# Spreading from 9, 124 to 10,124
# Spreading from 10, 124 to 11,124
# Spreading from 11, 124 to 12,124
# Spreading from 12, 124 to 13,124
# Spreading from 13, 124 to 14,124
# Spreading from 14, 124 to 15,124
# Spreading from 15, 124 to 16,124
# Spreading from 16, 124 to 17,124
# Spreading from 17, 124 to 18,124
# Spreading from 18, 124 to 19,124
# Spreading from 19, 124 to 19,125
# Spreading from 19, 125 to 18,125
# Spreading from 18, 125 to 17,125
# Spreading from 17, 125 to 16,125
# Spreading from 16, 125 to 15,125
# Spreading from 15, 125 to 14,125
# Spreading from 14, 125 to 13,125
# Spreading from 13, 125 to 12,125
# Spreading from 12, 125 to 11,125
# Spreading from 11, 125 to 10,125
# Spreading from 10, 125 to 9,125
# Spreading from 9, 125 to 8,125
# Spreading from 8, 125 to 7,125
# Spreading from 7, 125 to 6,125
# Spreading from 6, 125 to 5,125
# Spreading from 5, 125 to 4,125
# Spreading from 4, 125 to 3,125
# Spreading from 3, 125 to 2,125
# Spreading from 2, 125 to 1,125
# Spreading from 1, 125 to 1,126
# Spreading from 1, 126 to 2,126
# Spreading from 2, 126 to 3,126
# Spreading from 3, 126 to 4,126
# Spreading from 4, 126 to 5,126
# Spreading from 5, 126 to 6,126
# Spreading from 6, 126 to 7,126
# Spreading from 7, 126 to 8,126
# Spreading from 8, 126 to 9,126
# Spreading from 9, 126 to 10,126
# Spreading from 10, 126 to 11,126
# Spreading from 11, 126 to 12,126
# Spreading from 12, 126 to 13,126
# Spreading from 13, 126 to 14,126
# Spreading from 14, 126 to 15,126
# Spreading from 15, 126 to 16,126
# Spreading from 16, 126 to 17,126
# Spreading from 17, 126 to 18,126
# Spreading from 18, 126 to 19,126
# Spreading from 19, 126 to 20,126
# Spreading from 20, 126 to 21,126
# Spreading from 21, 126 to 22,126
# Spreading from 22, 126 to 23,126
# Spreading from 23, 126 to 24,126
# Spreading from 24, 126 to 24,127
# Spreading from 24, 127 to 23,127
# Spreading from 23, 127 to 22,127
# Spreading from 22, 127 to 21,127
# Spreading from 21, 127 to 20,127
# Spreading from 20, 127 to 19,127
# Spreading from 19, 127 to 18,127
# Spreading from 18, 127 to 17,127
# Spreading from 17, 127 to 16,127
# Spreading from 16, 127 to 15,127
# Spreading from 15, 127 to 14,127
# Spreading from 14, 127 to 13,127
# Spreading from 13, 127 to 12,127
# Spreading from 12, 127 to 11,127
# Spreading from 11, 127 to 10,127
# Spreading from 10, 127 to 9,127
# Spreading from 9, 127 to 8,127
# Spreading from 8, 127 to 7,127
# Spreading from 7, 127 to 6,127
# Spreading from 6, 127 to 5,127
# Spreading from 5, 127 to 4,127
# Spreading from 4, 127 to 3,127
# Spreading from 3, 127 to 2,127
# Spreading from 2, 127 to 1,127
# Spreading from 1, 127 to 1,128
# Spreading from 1, 128 to 2,128
# Spreading from 2, 128 to 3,128
# Spreading from 3, 128 to 4,128
# Spreading from 4, 128 to 5,128
# Spreading from 5, 128 to 6,128
# Spreading from 6, 128 to 7,128
# Spreading from 7, 128 to 8,128
# Spreading from 8, 128 to 9,128
# Spreading from 9, 128 to 10,128
# Spreading from 10, 128 to 11,128
# Spreading from 11, 128 to 12,128
# Spreading from 12, 128 to 13,128
# Spreading from 13, 128 to 14,128
# Spreading from 14, 128 to 15,128
# Spreading from 15, 128 to 16,128
# Spreading from 16, 128 to 17,128
# Spreading from 17, 128 to 18,128
# Spreading from 18, 128 to 19,128
# Spreading from 19, 128 to 20,128
# Spreading from 20, 128 to 21,128
# Spreading from 21, 128 to 22,128
# Spreading from 22, 128 to 23,128
# Spreading from 23, 128 to 24,128
# Spreading from 24, 128 to 25,128
# Spreading from 25, 128 to 26,128
# Spreading from 26, 128 to 26,129
# Spreading from 26, 129 to 25,129
# Spreading from 25, 129 to 24,129
# Spreading from 24, 129 to 23,129
# Spreading from 23, 129 to 22,129
# Spreading from 22, 129 to 21,129
# Spreading from 21, 129 to 20,129
# Spreading from 20, 129 to 19,129
# Spreading from 19, 129 to 18,129
# Spreading from 18, 129 to 17,129
# Spreading from 17, 129 to 16,129
# Spreading from 16, 129 to 15,129
# Spreading from 15, 129 to 14,129
# Spreading from 14, 129 to 13,129
# Spreading from 13, 129 to 12,129
# Spreading from 12, 129 to 11,129
# Spreading from 11, 129 to 10,129
# Spreading from 10, 129 to 9,129
# Spreading from 9, 129 to 8,129
# Spreading from 8, 129 to 7,129
# Spreading from 7, 129 to 6,129
# Spreading from 6, 129 to 5,129
# Spreading from 5, 129 to 4,129
# Spreading from 4, 129 to 3,129
# Spreading from 3, 129 to 2,129
# Spreading from 2, 129 to 1,129
# Spreading from 1, 129 to 1,130
# Spreading from 1, 130 to 2,130
# Spreading from 2, 130 to 3,130
# Spreading from 3, 130 to 4,130
# Spreading from 4, 130 to 5,130
# Spreading from 5, 130 to 6,130
# Spreading from 6, 130 to 7,130
# Spreading from 7, 130 to 8,130
# Spreading from 8, 130 to 9,130
# Spreading from 9, 130 to 10,130
# Spreading from 10, 130 to 11,130
# Spreading from 11, 130 to 12,130
# Spreading from 12, 130 to 13,130
# Spreading from 13, 130 to 14,130
# Spreading from 14, 130 to 15,130
# Spreading from 15, 130 to 16,130
# Spreading from 16, 130 to 17,130
# Spreading from 17, 130 to 18,130
# Spreading from 18, 130 to 19,130
# Spreading from 19, 130 to 20,130
# Spreading from 20, 130 to 21,130
# Spreading from 21, 130 to 22,130
# Spreading from 22, 130 to 23,130
# Spreading from 23, 130 to 24,130
# Spreading from 24, 130 to 25,130
# Spreading from 25, 130 to 26,130
# Spreading from 26, 130 to 27,130
# Spreading from 27, 130 to 28,130
# Spreading from 28, 130 to 28,131
# Spreading from 28, 131 to 27,131
# Spreading from 27, 131 to 26,131
# Spreading from 26, 131 to 25,131
# Spreading from 25, 131 to 24,131
# Spreading from 24, 131 to 23,131
# Spreading from 23, 131 to 22,131
# Spreading from 22, 131 to 21,131
# Spreading from 21, 131 to 20,131
# Spreading from 20, 131 to 19,131
# Spreading from 19, 131 to 18,131
# Spreading from 18, 131 to 17,131
# Spreading from 17, 131 to 16,131
# Spreading from 16, 131 to 15,131
# Spreading from 15, 131 to 14,131
# Spreading from 14, 131 to 13,131
# Spreading from 13, 131 to 12,131
# Spreading from 12, 131 to 11,131
# Spreading from 11, 131 to 10,131
# Spreading from 10, 131 to 9,131
# Spreading from 9, 131 to 8,131
# Spreading from 8, 131 to 7,131
# Spreading from 7, 131 to 6,131
# Spreading from 6, 131 to 5,131
# Spreading from 5, 131 to 4,131
# Spreading from 4, 131 to 3,131
# Spreading from 3, 131 to 2,131
# Spreading from 2, 131 to 1,131
# Spreading from 1, 131 to 1,132
# Spreading from 1, 132 to 2,132
# Spreading from 2, 132 to 3,132
# Spreading from 3, 132 to 4,132
# Spreading from 4, 132 to 5,132
# Spreading from 5, 132 to 6,132
# Spreading from 6, 132 to 7,132
# Spreading from 7, 132 to 8,132
# Spreading from 8, 132 to 9,132
# Spreading from 9, 132 to 10,132
# Spreading from 10, 132 to 11,132
# Spreading from 11, 132 to 12,132
# Spreading from 12, 132 to 13,132
# Spreading from 13, 132 to 14,132
# Spreading from 14, 132 to 15,132
# Spreading from 15, 132 to 16,132
# Spreading from 16, 132 to 17,132
# Spreading from 17, 132 to 18,132
# Spreading from 18, 132 to 19,132
# Spreading from 19, 132 to 20,132
# Spreading from 20, 132 to 21,132
# Spreading from 21, 132 to 22,132
# Spreading from 22, 132 to 23,132
# Spreading from 23, 132 to 24,132
# Spreading from 24, 132 to 25,132
# Spreading from 25, 132 to 26,132
# Spreading from 26, 132 to 27,132
# Spreading from 27, 132 to 28,132
# Spreading from 28, 132 to 29,132
# Spreading from 29, 132 to 30,132
# Spreading from 30, 132 to 31,132
# Spreading from 31, 132 to 32,132
# Spreading from 32, 132 to 33,132
# Spreading from 33, 132 to 34,132
# Spreading from 34, 132 to 35,132
# Spreading from 35, 132 to 36,132
# Spreading from 36, 132 to 37,132
# Spreading from 37, 132 to 38,132
# Spreading from 38, 132 to 39,132
# Spreading from 39, 132 to 40,132
# Spreading from 40, 132 to 41,132
# Spreading from 41, 132 to 42,132
# Spreading from 42, 132 to 43,132
# Spreading from 43, 132 to 44,132
# Spreading from 44, 132 to 45,132
# Spreading from 45, 132 to 45,133
# Spreading from 45, 133 to 44,133
# Spreading from 44, 133 to 43,133
# Spreading from 43, 133 to 42,133
# Spreading from 42, 133 to 41,133
# Spreading from 41, 133 to 40,133
# Spreading from 40, 133 to 39,133
# Spreading from 39, 133 to 38,133
# Spreading from 38, 133 to 37,133
# Spreading from 37, 133 to 36,133
# Spreading from 36, 133 to 35,133
# Spreading from 35, 133 to 34,133
# Spreading from 34, 133 to 33,133
# Spreading from 33, 133 to 32,133
# Spreading from 32, 133 to 31,133
# Spreading from 31, 133 to 30,133
# Spreading from 30, 133 to 29,133
# Spreading from 29, 133 to 28,133
# Spreading from 28, 133 to 27,133
# Spreading from 27, 133 to 26,133
# Spreading from 26, 133 to 25,133
# Spreading from 25, 133 to 24,133
# Spreading from 24, 133 to 23,133
# Spreading from 23, 133 to 22,133
# Spreading from 22, 133 to 21,133
# Spreading from 21, 133 to 20,133
# Spreading from 20, 133 to 19,133
# Spreading from 19, 133 to 18,133
# Spreading from 18, 133 to 17,133
# Spreading from 17, 133 to 16,133
# Spreading from 16, 133 to 15,133
# Spreading from 15, 133 to 14,133
# Spreading from 14, 133 to 13,133
# Spreading from 13, 133 to 12,133
# Spreading from 12, 133 to 11,133
# Spreading from 11, 133 to 10,133
# Spreading from 10, 133 to 9,133
# Spreading from 9, 133 to 8,133
# Spreading from 8, 133 to 7,133
# Spreading from 7, 133 to 6,133
# Spreading from 6, 133 to 5,133
# Spreading from 5, 133 to 4,133
# Spreading from 4, 133 to 3,133
# Spreading from 3, 133 to 2,133
# Spreading from 2, 133 to 1,133
# Spreading from 1, 133 to 1,134
# Spreading from 1, 134 to 2,134
# Spreading from 2, 134 to 3,134
# Spreading from 3, 134 to 4,134
# Spreading from 4, 134 to 5,134
# Spreading from 5, 134 to 6,134
# Spreading from 6, 134 to 7,134
# Spreading from 7, 134 to 8,134
# Spreading from 8, 134 to 9,134
# Spreading from 9, 134 to 10,134
# Spreading from 10, 134 to 11,134
# Spreading from 11, 134 to 12,134
# Spreading from 12, 134 to 13,134
# Spreading from 13, 134 to 14,134
# Spreading from 14, 134 to 15,134
# Spreading from 15, 134 to 16,134
# Spreading from 16, 134 to 17,134
# Spreading from 17, 134 to 18,134
# Spreading from 18, 134 to 19,134
# Spreading from 19, 134 to 20,134
# Spreading from 20, 134 to 21,134
# Spreading from 21, 134 to 22,134
# Spreading from 22, 134 to 23,134
# Spreading from 23, 134 to 24,134
# Spreading from 24, 134 to 25,134
# Spreading from 25, 134 to 26,134
# Spreading from 26, 134 to 27,134
# Spreading from 27, 134 to 28,134
# Spreading from 28, 134 to 29,134
# Spreading from 29, 134 to 30,134
# Spreading from 30, 134 to 31,134
# Spreading from 31, 134 to 32,134
# Spreading from 32, 134 to 33,134
# Spreading from 33, 134 to 34,134
# Spreading from 34, 134 to 35,134
# Spreading from 35, 134 to 36,134
# Spreading from 36, 134 to 37,134
# Spreading from 37, 134 to 38,134
# Spreading from 38, 134 to 39,134
# Spreading from 39, 134 to 40,134
# Spreading from 40, 134 to 41,134
# Spreading from 41, 134 to 42,134
# Spreading from 42, 134 to 43,134
# Spreading from 43, 134 to 44,134
# Spreading from 44, 134 to 45,134
# Spreading from 45, 134 to 46,134
# Spreading from 46, 134 to 47,134
# Spreading from 47, 134 to 48,134
# Spreading from 48, 134 to 49,134
# Spreading from 49, 134 to 49,133
# Spreading from 48, 134 to 48,135
# Spreading from 48, 135 to 47,135
# Spreading from 47, 135 to 46,135
# Spreading from 46, 135 to 45,135
# Spreading from 45, 135 to 44,135
# Spreading from 44, 135 to 43,135
# Spreading from 43, 135 to 42,135
# Spreading from 42, 135 to 41,135
# Spreading from 41, 135 to 40,135
# Spreading from 40, 135 to 39,135
# Spreading from 39, 135 to 38,135
# Spreading from 38, 135 to 37,135
# Spreading from 37, 135 to 36,135
# Spreading from 36, 135 to 35,135
# Spreading from 35, 135 to 34,135
# Spreading from 34, 135 to 33,135
# Spreading from 33, 135 to 32,135
# Spreading from 32, 135 to 31,135
# Spreading from 31, 135 to 30,135
# Spreading from 30, 135 to 29,135
# Spreading from 29, 135 to 28,135
# Spreading from 28, 135 to 27,135
# Spreading from 27, 135 to 26,135
# Spreading from 26, 135 to 25,135
# Spreading from 25, 135 to 24,135
# Spreading from 24, 135 to 23,135
# Spreading from 23, 135 to 22,135
# Spreading from 22, 135 to 21,135
# Spreading from 21, 135 to 20,135
# Spreading from 20, 135 to 19,135
# Spreading from 19, 135 to 18,135
# Spreading from 18, 135 to 17,135
# Spreading from 17, 135 to 16,135
# Spreading from 16, 135 to 15,135
# Spreading from 15, 135 to 14,135
# Spreading from 14, 135 to 13,135
# Spreading from 13, 135 to 12,135
# Spreading from 12, 135 to 11,135
# Spreading from 11, 135 to 10,135
# Spreading from 10, 135 to 9,135
# Spreading from 9, 135 to 8,135
# Spreading from 8, 135 to 7,135
# Spreading from 7, 135 to 6,135
# Spreading from 6, 135 to 5,135
# Spreading from 5, 135 to 4,135
# Spreading from 4, 135 to 3,135
# Spreading from 3, 135 to 2,135
# Spreading from 2, 135 to 1,135
# Spreading from 1, 135 to 1,136
# Spreading from 1, 136 to 2,136
# Spreading from 2, 136 to 3,136
# Spreading from 3, 136 to 4,136
# Spreading from 4, 136 to 5,136
# Spreading from 5, 136 to 6,136
# Spreading from 6, 136 to 7,136
# Spreading from 7, 136 to 8,136
# Spreading from 8, 136 to 9,136
# ...
# Spreading from 41, 137 to 40,137
# Spreading from 40, 137 to 39,137
# Spreading from 39, 137 to 38,137
# Spreading from 38, 137 to 37,137
# Spreading from 37, 137 to 36,137
# Spreading from 36, 137 to 35,137
# Spreading from 35, 137 to 34,137
# Spreading from 34, 137 to 33,137
# Spreading from 33, 137 to 32,137
# Spreading from 32, 137 to 31,137
# Spreading from 31, 137 to 30,137
# Spreading from 30, 137 to 29,137
# Spreading from 29, 137 to 28,137
# Spreading from 28, 137 to 27,137
# Spreading from 27, 137 to 26,137
# Spreading from 26, 137 to 25,137
# Spreading from 25, 137 to 24,137
# Spreading from 24, 137 to 23,137
# Spreading from 23, 137 to 22,137
# Spreading from 22, 137 to 21,137
# Spreading from 21, 137 to 20,137
# Spreading from 20, 137 to 19,137
# Spreading from 19, 137 to 18,137
# Spreading from 18, 137 to 17,137
# Spreading from 17, 137 to 16,137
# Spreading from 16, 137 to 15,137
# Spreading from 15, 137 to 14,137
# Spreading from 14, 137 to 13,137
# Spreading from 13, 137 to 12,137
# Spreading from 12, 137 to 11,137
# Spreading from 11, 137 to 10,137
# Spreading from 10, 137 to 9,137
# Spreading from 9, 137 to 8,137
# Spreading from 8, 137 to 7,137
# Spreading from 7, 137 to 6,137
# Spreading from 6, 137 to 5,137
# Spreading from 5, 137 to 4,137
# Spreading from 4, 137 to 3,137
# Spreading from 3, 137 to 2,137
# Spreading from 2, 137 to 1,137
# Spreading from 1, 137 to 1,138
# Spreading from 1, 138 to 2,138
# Spreading from 2, 138 to 3,138
# Spreading from 3, 138 to 4,138
# Spreading from 4, 138 to 5,138
# Spreading from 5, 138 to 6,138
# Spreading from 6, 138 to 7,138
# Spreading from 7, 138 to 8,138
# Spreading from 8, 138 to 9,138
# Spreading from 9, 138 to 10,138
# Spreading from 10, 138 to 11,138
# Spreading from 11, 138 to 12,138
# Spreading from 12, 138 to 13,138
# Spreading from 13, 138 to 14,138
# Spreading from 14, 138 to 15,138
# Spreading from 15, 138 to 16,138
# Spreading from 16, 138 to 17,138
# Spreading from 17, 138 to 18,138
# Spreading from 18, 138 to 19,138
# Spreading from 19, 138 to 20,138
# Spreading from 20, 138 to 21,138
# Spreading from 21, 138 to 22,138
# Spreading from 22, 138 to 23,138
# Spreading from 23, 138 to 24,138
# Spreading from 24, 138 to 25,138
# Spreading from 25, 138 to 26,138
# Spreading from 26, 138 to 27,138
# Spreading from 27, 138 to 28,138
# Spreading from 28, 138 to 29,138
# Spreading from 29, 138 to 30,138
# Spreading from 30, 138 to 31,138
# Spreading from 31, 138 to 32,138
# Spreading from 32, 138 to 33,138
# Spreading from 33, 138 to 34,138
# Spreading from 34, 138 to 35,138
# Spreading from 35, 138 to 36,138
# Spreading from 36, 138 to 37,138
# Spreading from 37, 138 to 38,138
# Spreading from 38, 138 to 39,138
# Spreading from 39, 138 to 40,138
# Spreading from 40, 138 to 41,138
# Spreading from 41, 138 to 42,138
# Spreading from 42, 138 to 43,138
# Spreading from 43, 138 to 44,138
# Spreading from 44, 138 to 45,138
# Spreading from 45, 138 to 46,138
# Spreading from 46, 138 to 47,138
# Spreading from 47, 138 to 48,138
# Spreading from 48, 138 to 49,138
# Spreading from 49, 138 to 50,138
# Spreading from 50, 138 to 51,138
# Spreading from 51, 138 to 52,138
# Spreading from 52, 138 to 53,138
# Spreading from 53, 138 to 54,138
# Spreading from 54, 138 to 55,138
# Spreading from 55, 138 to 56,138
# Spreading from 56, 138 to 57,138
# Spreading from 57, 138 to 58,138
# Spreading from 58, 138 to 59,138
# Spreading from 59, 138 to 60,138
# Spreading from 60, 138 to 61,138
# Spreading from 61, 138 to 62,138
# Spreading from 62, 138 to 63,138
# Spreading from 63, 138 to 64,138
# Spreading from 64, 138 to 65,138
# Spreading from 65, 138 to 66,138
# Spreading from 66, 138 to 67,138
# Spreading from 67, 138 to 68,138
# Spreading from 68, 138 to 69,138
# Spreading from 69, 138 to 70,138
# Spreading from 70, 138 to 71,138
# Spreading from 71, 138 to 72,138
# Spreading from 72, 138 to 73,138
# Spreading from 73, 138 to 74,138
# Spreading from 74, 138 to 75,138
# Spreading from 75, 138 to 76,138
# Spreading from 76, 138 to 77,138
# Spreading from 77, 138 to 78,138
# Spreading from 78, 138 to 79,138
# Spreading from 79, 138 to 80,138
# Spreading from 80, 138 to 81,138
# Spreading from 81, 138 to 82,138
# Spreading from 82, 138 to 83,138
# Spreading from 83, 138 to 84,138
# Spreading from 84, 138 to 85,138
# Spreading from 85, 138 to 86,138
# Spreading from 86, 138 to 87,138
# Spreading from 87, 138 to 88,138
# Spreading from 88, 138 to 89,138
# Spreading from 89, 138 to 90,138
# Spreading from 90, 138 to 91,138
# Spreading from 91, 138 to 92,138
# Spreading from 92, 138 to 93,138
# Spreading from 93, 138 to 94,138
# Spreading from 94, 138 to 95,138
# Spreading from 95, 138 to 96,138
# Spreading from 96, 138 to 97,138
# Spreading from 97, 138 to 98,138
# Spreading from 98, 138 to 99,138
# Spreading from 99, 138 to 100,138
# Spreading from 100, 138 to 101,138
# Spreading from 101, 138 to 102,138
# Spreading from 102, 138 to 103,138
# Spreading from 103, 138 to 104,138
# Spreading from 104, 138 to 105,138
# Spreading from 105, 138 to 106,138
# Spreading from 106, 138 to 107,138
# Spreading from 107, 138 to 108,138
# Spreading from 108, 138 to 109,138
# Spreading from 109, 138 to 110,138
# Spreading from 110, 138 to 111,138
# Spreading from 111, 138 to 112,138
# Spreading from 112, 138 to 113,138
# Spreading from 113, 138 to 114,138
# Spreading from 114, 138 to 115,138
# Spreading from 115, 138 to 116,138
# Spreading from 116, 138 to 117,138
# Spreading from 117, 138 to 118,138
# Spreading from 118, 138 to 119,138
# Spreading from 119, 138 to 120,138
# Spreading from 120, 138 to 121,138
# Spreading from 121, 138 to 122,138
# Spreading from 122, 138 to 123,138
# Spreading from 123, 138 to 124,138
# Spreading from 124, 138 to 125,138
# Spreading from 125, 138 to 126,138
# Spreading from 126, 138 to 127,138
# Spreading from 127, 138 to 128,138
# Spreading from 128, 138 to 129,138
# Spreading from 129, 138 to 130,138
# Spreading from 130, 138 to 131,138
# Spreading from 131, 138 to 132,138
# Spreading from 132, 138 to 133,138
# Spreading from 133, 138 to 134,138
# Spreading from 134, 138 to 135,138
# Spreading from 135, 138 to 136,138
# Spreading from 136, 138 to 137,138
# Spreading from 137, 138 to 138,138
# Spreading from 138, 138 to 138,137
# Spreading from 138, 137 to 137,137
# Spreading from 137, 137 to 136,137
# Spreading from 136, 137 to 135,137
# Spreading from 135, 137 to 134,137
# Spreading from 134, 137 to 133,137
# Spreading from 133, 137 to 132,137
# Spreading from 132, 137 to 131,137
# Spreading from 131, 137 to 130,137
# Spreading from 130, 137 to 129,137
# Spreading from 129, 137 to 128,137
# Spreading from 128, 137 to 127,137
# Spreading from 127, 137 to 126,137
# Spreading from 126, 137 to 125,137
# Spreading from 125, 137 to 124,137
# Spreading from 124, 137 to 123,137
# Spreading from 123, 137 to 122,137
# Spreading from 122, 137 to 121,137
# Spreading from 121, 137 to 120,137
# Spreading from 120, 137 to 119,137
# Spreading from 119, 137 to 118,137
# Spreading from 118, 137 to 117,137
# Spreading from 117, 137 to 116,137
# Spreading from 116, 137 to 115,137
# Spreading from 115, 137 to 114,137
# Spreading from 114, 137 to 113,137
# Spreading from 113, 137 to 112,137
# Spreading from 112, 137 to 111,137
# Spreading from 111, 137 to 110,137
# Spreading from 110, 137 to 109,137
# Spreading from 109, 137 to 108,137
# Spreading from 108, 137 to 107,137
# Spreading from 107, 137 to 106,137
# Spreading from 106, 137 to 105,137
# Spreading from 105, 137 to 104,137
# Spreading from 104, 137 to 103,137
# Spreading from 103, 137 to 102,137
# Spreading from 102, 137 to 101,137
# Spreading from 101, 137 to 100,137
# Spreading from 100, 137 to 99,137
# Spreading from 99, 137 to 98,137
# Spreading from 98, 137 to 97,137
# Spreading from 97, 137 to 96,137
# Spreading from 96, 137 to 95,137
# Spreading from 95, 137 to 94,137
# Spreading from 94, 137 to 93,137
# Spreading from 93, 137 to 92,137
# Spreading from 92, 137 to 91,137
# Spreading from 91, 137 to 90,137
# Spreading from 90, 137 to 89,137
# Spreading from 89, 137 to 88,137
# Spreading from 88, 137 to 87,137
# Spreading from 87, 137 to 86,137
# Spreading from 86, 137 to 85,137
# Spreading from 85, 137 to 84,137
# Spreading from 84, 137 to 83,137
# Spreading from 83, 137 to 82,137
# Spreading from 82, 137 to 81,137
# Spreading from 81, 137 to 80,137
# Spreading from 80, 137 to 79,137
# Spreading from 79, 137 to 78,137
# Spreading from 78, 137 to 77,137
# Spreading from 77, 137 to 76,137
# Spreading from 76, 137 to 75,137
# Spreading from 75, 137 to 74,137
# Spreading from 74, 137 to 73,137
# Spreading from 73, 137 to 72,137
# Spreading from 72, 137 to 71,137
# Spreading from 71, 137 to 70,137
# Spreading from 70, 137 to 69,137
# Spreading from 69, 137 to 68,137
# Spreading from 68, 137 to 67,137
# Spreading from 67, 137 to 66,137
# Spreading from 66, 137 to 65,137
# Spreading from 65, 137 to 64,137
# Spreading from 64, 137 to 63,137
# Spreading from 63, 137 to 62,137
# Spreading from 62, 137 to 61,137
# Spreading from 61, 137 to 60,137
# Spreading from 60, 137 to 59,137
# Spreading from 59, 137 to 58,137
# Spreading from 58, 137 to 57,137
# Spreading from 57, 137 to 56,137
# Spreading from 56, 137 to 55,137
# Spreading from 55, 137 to 54,137
# Spreading from 54, 137 to 53,137
# Spreading from 53, 137 to 52,137
# Spreading from 52, 137 to 51,137
# Spreading from 51, 137 to 50,137
# Spreading from 50, 137 to 49,137
# Spreading from 52, 137 to 52,136
# Spreading from 52, 136 to 53,136
# Spreading from 53, 136 to 54,136
# Spreading from 54, 136 to 55,136
# Spreading from 55, 136 to 56,136
# Spreading from 56, 136 to 57,136
# Spreading from 57, 136 to 58,136
# Spreading from 58, 136 to 59,136
# Spreading from 59, 136 to 60,136
# Spreading from 60, 136 to 61,136
# Spreading from 61, 136 to 62,136
# Spreading from 62, 136 to 63,136
# Spreading from 63, 136 to 64,136
# Spreading from 64, 136 to 65,136
# Spreading from 65, 136 to 66,136
# Spreading from 66, 136 to 67,136
# Spreading from 67, 136 to 68,136
# Spreading from 68, 136 to 69,136
# Spreading from 69, 136 to 70,136
# Spreading from 70, 136 to 71,136
# Spreading from 71, 136 to 72,136
# Spreading from 72, 136 to 73,136
# Spreading from 73, 136 to 74,136
# Spreading from 74, 136 to 75,136
# Spreading from 75, 136 to 76,136
# Spreading from 76, 136 to 77,136
# Spreading from 77, 136 to 78,136
# Spreading from 78, 136 to 79,136
# Spreading from 79, 136 to 80,136
# Spreading from 80, 136 to 81,136
# Spreading from 81, 136 to 82,136
# Spreading from 82, 136 to 83,136
# Spreading from 83, 136 to 84,136
# Spreading from 84, 136 to 85,136
# Spreading from 85, 136 to 86,136
# Spreading from 86, 136 to 87,136
# Spreading from 87, 136 to 88,136
# Spreading from 88, 136 to 89,136
# Spreading from 89, 136 to 90,136
# Spreading from 90, 136 to 91,136
# Spreading from 91, 136 to 92,136
# Spreading from 92, 136 to 93,136
# Spreading from 93, 136 to 94,136
# Spreading from 94, 136 to 95,136
# Spreading from 95, 136 to 96,136
# Spreading from 96, 136 to 97,136
# Spreading from 97, 136 to 98,136
# Spreading from 98, 136 to 99,136
# Spreading from 99, 136 to 100,136
# Spreading from 100, 136 to 101,136
# Spreading from 101, 136 to 102,136
# Spreading from 102, 136 to 103,136
# Spreading from 103, 136 to 104,136
# Spreading from 104, 136 to 105,136
# Spreading from 105, 136 to 106,136
# Spreading from 106, 136 to 107,136
# Spreading from 107, 136 to 108,136
# Spreading from 108, 136 to 109,136
# Spreading from 109, 136 to 110,136
# Spreading from 110, 136 to 111,136
# Spreading from 111, 136 to 112,136
# Spreading from 112, 136 to 113,136
# Spreading from 113, 136 to 114,136
# Spreading from 114, 136 to 115,136
# Spreading from 115, 136 to 116,136
# Spreading from 116, 136 to 117,136
# Spreading from 117, 136 to 118,136
# Spreading from 118, 136 to 119,136
# Spreading from 119, 136 to 120,136
# Spreading from 120, 136 to 121,136
# Spreading from 121, 136 to 122,136
# Spreading from 122, 136 to 123,136
# Spreading from 123, 136 to 124,136
# Spreading from 124, 136 to 125,136
# Spreading from 125, 136 to 126,136
# Spreading from 126, 136 to 127,136
# Spreading from 127, 136 to 128,136
# Spreading from 128, 136 to 129,136
# Spreading from 129, 136 to 130,136
# Spreading from 130, 136 to 131,136
# Spreading from 131, 136 to 132,136
# Spreading from 132, 136 to 133,136
# Spreading from 133, 136 to 134,136
# Spreading from 134, 136 to 135,136
# Spreading from 135, 136 to 136,136
# Spreading from 136, 136 to 137,136
# Spreading from 137, 136 to 138,136
# Spreading from 138, 136 to 138,135
# Spreading from 138, 135 to 137,135
# Spreading from 137, 135 to 136,135
# Spreading from 136, 135 to 135,135
# Spreading from 135, 135 to 134,135
# Spreading from 134, 135 to 133,135
# Spreading from 133, 135 to 132,135
# Spreading from 132, 135 to 131,135
# Spreading from 131, 135 to 130,135
# Spreading from 130, 135 to 129,135
# Spreading from 129, 135 to 128,135
# Spreading from 128, 135 to 127,135
# Spreading from 127, 135 to 126,135
# Spreading from 126, 135 to 125,135
# Spreading from 125, 135 to 124,135
# Spreading from 124, 135 to 123,135
# Spreading from 123, 135 to 122,135
# Spreading from 122, 135 to 121,135
# Spreading from 121, 135 to 120,135
# Spreading from 120, 135 to 119,135
# Spreading from 119, 135 to 118,135
# Spreading from 118, 135 to 117,135
# Spreading from 117, 135 to 116,135
# Spreading from 116, 135 to 115,135
# Spreading from 115, 135 to 114,135
# Spreading from 114, 135 to 113,135
# Spreading from 113, 135 to 112,135
# Spreading from 112, 135 to 111,135
# Spreading from 111, 135 to 110,135
# Spreading from 110, 135 to 109,135
# Spreading from 109, 135 to 108,135
# Spreading from 108, 135 to 107,135
# Spreading from 107, 135 to 106,135
# Spreading from 106, 135 to 105,135
# Spreading from 105, 135 to 104,135
# Spreading from 104, 135 to 103,135
# Spreading from 103, 135 to 102,135
# Spreading from 102, 135 to 101,135
# Spreading from 101, 135 to 100,135
# Spreading from 100, 135 to 99,135
# Spreading from 99, 135 to 98,135
# Spreading from 98, 135 to 97,135
# Spreading from 97, 135 to 96,135
# Spreading from 96, 135 to 95,135
# Spreading from 95, 135 to 94,135
# Spreading from 94, 135 to 93,135
# Spreading from 93, 135 to 92,135
# Spreading from 92, 135 to 91,135
# Spreading from 91, 135 to 90,135
# Spreading from 90, 135 to 89,135
# Spreading from 89, 135 to 88,135
# Spreading from 88, 135 to 87,135
# Spreading from 87, 135 to 86,135
# Spreading from 86, 135 to 85,135
# Spreading from 85, 135 to 84,135
# Spreading from 84, 135 to 83,135
# Spreading from 83, 135 to 82,135
# Spreading from 82, 135 to 81,135
# Spreading from 81, 135 to 80,135
# Spreading from 80, 135 to 79,135
# Spreading from 79, 135 to 78,135
# Spreading from 78, 135 to 77,135
# Spreading from 77, 135 to 76,135
# Spreading from 76, 135 to 75,135
# Spreading from 75, 135 to 74,135
# Spreading from 74, 135 to 73,135
# Spreading from 73, 135 to 72,135
# Spreading from 72, 135 to 71,135
# Spreading from 71, 135 to 70,135
# Spreading from 70, 135 to 69,135
# Spreading from 69, 135 to 68,135
# Spreading from 68, 135 to 67,135
# Spreading from 67, 135 to 66,135
# Spreading from 66, 135 to 65,135
# Spreading from 65, 135 to 64,135
# Spreading from 64, 135 to 63,135
# Spreading from 63, 135 to 62,135
# Spreading from 62, 135 to 61,135
# Spreading from 61, 135 to 60,135
# Spreading from 60, 135 to 59,135
# Spreading from 59, 135 to 58,135
# Spreading from 58, 135 to 57,135
# Spreading from 57, 135 to 56,135
# Spreading from 56, 135 to 55,135
# Spreading from 55, 135 to 54,135
# Spreading from 56, 135 to 56,134
# Spreading from 56, 134 to 57,134
# Spreading from 57, 134 to 58,134
# Spreading from 58, 134 to 59,134
# Spreading from 59, 134 to 60,134
# Spreading from 60, 134 to 61,134
# Spreading from 61, 134 to 62,134
# Spreading from 62, 134 to 63,134
# Spreading from 63, 134 to 64,134
# Spreading from 64, 134 to 65,134
# Spreading from 65, 134 to 66,134
# Spreading from 66, 134 to 67,134
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
Counter(outcome_dict.values())
# Out:
# Counter({'Outside': 4971, 'Pipe': 14059, 'Inside': 570})

# %%
### Unused below - was crashing

# %%
def check_for_pipes(row, col, direction):
    end = False
    outcome = "Inside"
    above = [row-1, col]
    below = [row+1, col]
    right = [row, col+1]
    left = [row, col-1]
    checked_list = []
    while end == False:
        if direction == "up":
            above[0] -= 1
            right[1] += 1
            left[1] -= 1

            if (outcome_dict[tuple(above)] == "Outside") | (outcome_dict[tuple(right)] == "Outside") | (outcome_dict[tuple(left)] == "Outside"):
                end = True
                outcome = "Outside"
            elif (outcome_dict[tuple(above)] in checked_list) & (outcome_dict[tuple(right)] in checked_list) & (outcome_dict[tuple(left)] in checked_list):
                end = True
            else:
                if (outcome_dict[tuple(above)] != "Pipe") & (outcome_dict[tuple(above)] not in checked_list):
                    outcome = check_for_pipes(above[0], above[1],"up")
                if (outcome_dict[tuple(left)] != "Pipe") & (outcome_dict[tuple(left)] not in checked_list):
                    outcome = check_for_pipes(left[0], left[1], "left")
                if (outcome_dict[tuple(right)] != "Pipe") & (outcome_dict[tuple(right)] not in checked_list):
                    outcome = check_for_pipes(right[0], right[1], "right")
                checked_list = checked_list + [tuple(above), tuple(right), tuple(left)]
        if direction == "down":
            below[0] -= 1
            right[1] += 1
            left[1] -= 1

            if (outcome_dict[tuple(below)] == "Outside") | (outcome_dict[tuple(right)] == "Outside") | (outcome_dict[tuple(left)] == "Outside"):
                end = True
                outcome = "Outside"
            elif (outcome_dict[tuple(below)] in checked_list) & (outcome_dict[tuple(right)] in checked_list) & (outcome_dict[tuple(left)] in checked_list):
                end = True
            else:
                if (outcome_dict[tuple(below)] != "Pipe") & (outcome_dict[tuple(below)] not in checked_list):
                    outcome = check_for_pipes(below[0], below[1], "down")
                if (outcome_dict[tuple(left)] != "Pipe") & (outcome_dict[tuple(left)] not in checked_list):
                    outcome = check_for_pipes(left[0],left[1],"left")
                if (outcome_dict[tuple(right)] != "Pipe") & (outcome_dict[tuple(right)] not in checked_list):
                    outcome = check_for_pipes(right[0], right[1], "right")
                checked_list = checked_list + [tuple(below), tuple(right), tuple(left)]
        if direction == "right":
            above[0] -= 1
            right[1] += 1
            below[0] += 1

            if (outcome_dict[tuple(above)] == "Outside") | (outcome_dict[tuple(right)] == "Outside") | (outcome_dict[tuple(below)] == "Outside"):
                end = True
                outcome = "Outside"
            elif (outcome_dict[tuple(above)] in checked_list) & (outcome_dict[tuple(right)] in checked_list) & (outcome_dict[tuple(below)] in checked_list):
                end = True
            else:
                if (outcome_dict[tuple(above)] != "Pipe") & (outcome_dict[tuple(above)] not in checked_list):
                    outcome = check_for_pipes(above[0], above[1],"up")
                if (outcome_dict[tuple(below)] != "Pipe") & (outcome_dict[tuple(below)] not in checked_list):
                    outcome = check_for_pipes(below[0], below[1], "down")
                if (outcome_dict[tuple(right)] != "Pipe") & (outcome_dict[tuple(right)] not in checked_list):
                    outcome = check_for_pipes(right[0], right[1], "right")
                checked_list = checked_list + [tuple(above), tuple(right), tuple(below)]
        if direction == "left":
            above[0] -= 1
            below[0] += 1
            left[1] -= 1

            if (outcome_dict[tuple(above)] == "Outside") | (outcome_dict[tuple(below)] == "Outside") | (outcome_dict[tuple(left)] == "Outside"):
                end = True
                outcome = "Outside"
            elif (outcome_dict[tuple(above)] in checked_list) & (outcome_dict[tuple(below)] in checked_list) & (outcome_dict[tuple(left)] in checked_list):
                end = True
            else:
                if (outcome_dict[tuple(above)] != "Pipe") & (outcome_dict[tuple(above)] not in checked_list):
                    outcome = check_for_pipes(above[0],above[1],"up")
                if (outcome_dict[tuple(below)] != "Pipe") & (outcome_dict[tuple(below)] not in checked_list):
                    outcome = check_for_pipes(below[0],below[1],"down")
                if (outcome_dict[tuple(left)] != "Pipe") & (outcome_dict[tuple(left)] not in checked_list):
                    outcome = check_for_pipes(left[0],left[1],"left")
                checked_list = checked_list + [tuple(above), tuple(below), tuple(left)]

    return outcome

# %%
"""for row, dict in enumerate(data_dict.values()):
    for col, list in enumerate(dict):
        if outcome_dict[(row, col)] == "Inside":
            above = [row-1, col]
            below = [row+1, col]
            right = [row, col+1]
            left = [row, col-1]

            if (outcome_dict[tuple(above)] == "Pipe") & (outcome_dict[tuple(left)] == "Pipe") & (outcome_dict[tuple(below)] == "Pipe") & (outcome_dict[tuple(right)] == "Pipe"):
                outcome = "Inside"
            else:
                up_outcome = check_for_pipes(row, col, "up")
                down_outcome = check_for_pipes(row, col, "down")
                right_outcome = check_for_pipes(row, col, "right")
                left_outcome = check_for_pipes(row, col, "left")

                if (up_outcome == "Outside") | (down_outcome == "Outside") | (right_outcome == "Outside") | (left_outcome == "Outside"):
                    outcome = "Outside"
                else:
                    outcome = "Inside"

            print(f"Space at row {row}, column {col} is defined as {outcome}")
            outcome_dict[(row, col)] = outcome"""
# Out:
# 'for row, dict in enumerate(data_dict.values()):\n    for col, list in enumerate(dict):\n        if outcome_dict[(row, col)] == "Inside":\n            above = [row-1, col]\n            below = [row+1, col]\n            right = [row, col+1]\n            left = [row, col-1]\n\n            if (outcome_dict[tuple(above)] == "Pipe") & (outcome_dict[tuple(left)] == "Pipe") & (outcome_dict[tuple(below)] == "Pipe") & (outcome_dict[tuple(right)] == "Pipe"):\n                outcome = "Inside"\n            else:\n                up_outcome = check_for_pipes(row, col, "up")\n                down_outcome = check_for_pipes(row, col, "down")\n                right_outcome = check_for_pipes(row, col, "right")\n                left_outcome = check_for_pipes(row, col, "left")\n\n                if (up_outcome == "Outside") | (down_outcome == "Outside") | (right_outcome == "Outside") | (left_outcome == "Outside"):\n                    outcome = "Outside"\n                else:\n                    outcome = "Inside"\n\n            print(f"Space at row {row}, column {col} is defined as {outcome}")\n            outcome_dict[(row, col)] = outcome'
